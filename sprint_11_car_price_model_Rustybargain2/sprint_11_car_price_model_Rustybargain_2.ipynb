# %% [markdown]
# ## Project Description: Car Price Model
#
#
# Rusty Bargain used car sales service is developing an app to attract new customers. In that app, you can quickly find out the market value of your car. You have access to historical data: technical specifications, trim versions, and prices. You need to build the model to determine the value.
#
# Rusty Bargain is interested in:
#
# - the quality of the prediction;
# - the speed of the prediction;
# - the time required for training
#
# ## Data description
#
# ### Features
#
# - `DateCrawled:` date profile was downloaded from the database
# - `VehicleType:` vehicle body type
# - `RegistrationYear:` vehicle registration year
# - `Gearbox:` gearbox type
# - `Power:` power (hp)
# - `Model:` vehicle model
# - `Mileage:` mileage (measured in km due to dataset's regional specifics)
# - `RegistrationMonth:` vehicle registration month
# - `FuelType:` fuel type
# - `Brand:` vehicle brand
# - `NotRepaired:`vehicle repaired or not
# - `DateCreated:` date of profile creation
# - `NumberOfPictures:` number of vehicle pictures
# - `PostalCode:` postal code of profile owner (user)
# - `LastSeen:` date of the last activity of the user
#
# ### Target
#
# - `Price:` price (Euro)
#
#
# ## Table of Contents
#
# 1. Data Preparation
# 2. Data Preprocessing
# 3. Model Training
# - Linear Regression
# - Decision Tree
# - Random Forest
# - CatBoost
# - LightGBM
# 4. Model Analysis
# 5. Conclusion

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Let us import our necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import make_scorer
random_state = 12345

# %% [markdown]
# Loading the dataset

# %%
data = pd.read_csv('/datasets/car_data.csv')

data.head()
# Out:
#         DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  24/03/2016 11:52    480         NaN              1993  manual      0
# 1  24/03/2016 10:58  18300       coupe              2011  manual    190
# 2  14/03/2016 12:52   9800         suv              2004    auto    163
# 3  17/03/2016 16:54   1500       small              2001  manual     75
# 4  31/03/2016 17:25   3600       small              2008  manual     69
#
#    Model  Mileage  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0   golf   150000                  0    petrol  volkswagen         NaN
# 1    NaN   125000                  5  gasoline        audi         yes
# 2  grand   125000                  8  gasoline        jeep         NaN
# 3   golf   150000                  6    petrol  volkswagen          no
# 4  fabia    90000                  7  gasoline       skoda          no
#
#         DateCreated  NumberOfPictures  PostalCode          LastSeen
# 0  24/03/2016 00:00                 0       70435  07/04/2016 03:16
# 1  24/03/2016 00:00                 0       66954  07/04/2016 01:46
# 2  14/03/2016 00:00                 0       90480  05/04/2016 12:47
# 3  17/03/2016 00:00                 0       91074  17/03/2016 17:40
# 4  31/03/2016 00:00                 0       60437  06/04/2016 10:17

# %% [markdown]
# Getting some info about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %% [markdown]
# The total number of rows for the dataset is 354369. Some columns have missing values which have to be dealt with. We will take a look at the description of the numerical columns

# %%
data.describe()
# Out:
#                Price  RegistrationYear          Power        Mileage  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %% [markdown]
# Taking a look at the dataset, we see that:
#
# - There are price values of zero. Considering the fact that we are looking at the market value of a car, the price cannot be zero. Therfore, we need to filter out the rows that have prices of zero.
# - There are registration years that date as far back as the year 1000, and far into the future as much as 9999. This is the year 2023. Therefore, those outlier values have to be filtered out .
# - Also, from the power column, there are cars with zero power. Those zero values will be filtered out also.
# - The number of Months goes from 1 to 12. However, we have values of 0 in the RegistrationMonth column. The zero values will be filtered out
# - Lastly, the  NumberOfPictures column is zero all through. The column is not of any significance. Therefore, it will be dropped.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Counting the number of duplicate rows

# %%
data.duplicated().sum()
# Out:
# 262

# %% [markdown]
# Next, we drop the 0 values from the columns

# %%
data = data.loc[data['Price'] != 0] #this code drops 0 values from the Price column

data = data.loc[data['RegistrationYear'] != 0] #this code drops 0 values from the RegistrationYear column

data = data.loc[data['Power'] != 0] #this code drops 0 values from the Power column

# %% [markdown]
# To filter out the outliers in "RegistrationYear" column, we need cars that have more recent registration dates.

# %% [markdown]
# Checking for the Registration dates older than 1990

# %%
old_registn = data.loc[data['RegistrationYear'] <= 1990].shape[0]
old_registn
# Out:
# 8842

# %%
tefy = old_registn/data.shape[0]
print(tefy)
# Out:
# 0.028779085852289926

# %% [markdown]
# Filtering out dates from 1990 takes out about 2.8% from our dataset, which is not much.

# %% [markdown]
# Also, to filter the outliers in the future dates, we take a look at the number of dates beyond 2023.

# %%
new_registn = data.loc[data['RegistrationYear'] >= 2023].shape[0]
new_registn
# Out:
# 24

# %% [markdown]
# There are 24 records of the Registration dates beyond 2023. Seeing that Rusty Bargain used car sales service is developing an app to attract new customers in the year 2023, then we will filter out Registration Years older than 1990, and beyond 2023

# %%
data = data.loc[(data['RegistrationYear'] >= 1990 ) & (data['RegistrationYear'] <= 2023)]
#registration Years between and including 1990 and 2023

# %% [markdown]
# Dropping the NumberofPictures Column

# %%
data = data.drop('NumberOfPictures', axis = 1)

# %% [markdown]
# Filling the missing values in 'NotRepaired' Column with empty values

# %%
data['NotRepaired'].fillna(value = 'unknown', inplace = True)

# %% [markdown]
# Dropping all other missing values and duplicate rows

# %%
data.dropna(inplace = True)

data.drop_duplicates(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258067 entries, 2 to 354368
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        258067 non-null  object
#  1   Price              258067 non-null  int64
#  2   VehicleType        258067 non-null  object
#  3   RegistrationYear   258067 non-null  int64
#  4   Gearbox            258067 non-null  object
#  5   Power              258067 non-null  int64
#  6   Model              258067 non-null  object
#  7   Mileage            258067 non-null  int64
#  8   RegistrationMonth  258067 non-null  int64
#  9   FuelType           258067 non-null  object
#  10  Brand              258067 non-null  object
#  11  NotRepaired        258067 non-null  object
#  12  DateCreated        258067 non-null  object
#  13  PostalCode         258067 non-null  int64
#  14  LastSeen           258067 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 31.5+ MB

# %% [markdown]
# The cleaning process is done. Next, we prepare the data splits.

# %% [markdown]
# ## Model training

# %% [markdown]
# We will be training Linear Regression (as a baseline), Decision Tree Regressor, Random Forest Regressor, CatBoost Regressor, and LightGBM Regressor models. For the first three models we will need to encode the categorical features prior to training. The last two models don't need prior encoding since they have built-in encoders. Therefore, we will make two copies of the cleaned data: one that isn't encoded (which will be used with CatBoost and LightGBM), and the other which will be encoded for the other models

# %% [markdown]
# Creating and preparing a copy of the cleaned data to use it with CatBoost and LightGBM

# %%
data_gbm = data.copy()#makes a copy of our cleaned data
data_gbm.drop(['DateCrawled', 'DateCreated', 'LastSeen'], axis=1, inplace=True)#drops the columns that are in time-date
#format 
data_gbm.reset_index(drop=True, inplace=True)#resets the index
features_gbm=data_gbm.drop('Price', axis=1)#defines our features
target_gbm=data_gbm['Price']#defines the price column as our target
f_train_gbm, f_test_gbm, t_train_gbm, t_test_gbm = train_test_split(features_gbm, target_gbm, test_size=0.2,
                                                                 random_state=random_state)
#splits our new data into training and test sets for our features and target

#prints the shapes of our splits
print(f_train_gbm.shape)
print(t_train_gbm.shape)
print(f_test_gbm.shape)
print(t_test_gbm.shape)
# Out:
# (206453, 11)
# (206453,)
# (51614, 11)
# (51614,)

# %% [markdown]
# For the models that need encoding, we will create a list that comprises the columns that we want encoded:

# %%
dat_features = ['VehicleType', 'RegistrationYear', 'Gearbox', 'Model', 'RegistrationMonth',
         'FuelType', 'Brand', 'NotRepaired', 'PostalCode']

# %%
#creating and preparing a copy of data to use with models requiring prior encoding
data_enc = data.copy() # creating a copy of cleaned data and putting it into the variable data_enc
encoder = OrdinalEncoder()#creates an instance of the ordinal encoder
data_enc[dat_features] = encoder.fit_transform(data_enc[dat_features]) #encodes the columns and saves the encoded values into
                                                                       # into a new table called data_enc[dat_features]

# %%
data_enc[dat_features]
# Out:
#         VehicleType  RegistrationYear  Gearbox  Model  RegistrationMonth  \
# 2               6.0              14.0      0.0  117.0                8.0
# 3               5.0              11.0      1.0  116.0                6.0
# 4               5.0              18.0      1.0  101.0                7.0
# 5               4.0               5.0      1.0   11.0               10.0
# 6               1.0              14.0      1.0    8.0                8.0
# ...             ...               ...      ...    ...                ...
# 354360          7.0              15.0      1.0   11.0                5.0
# 354362          4.0              14.0      1.0  140.0                5.0
# 354366          1.0              10.0      0.0  106.0                3.0
# 354367          0.0               6.0      1.0  221.0                3.0
# 354368          7.0              12.0      1.0  116.0                6.0
#
#         FuelType  Brand  NotRepaired  PostalCode
# 2            2.0   14.0          1.0      6935.0
# 3            6.0   37.0          0.0      6975.0
# 4            2.0   31.0          0.0      4167.0
# 5            6.0    2.0          2.0      2341.0
# 6            6.0   25.0          0.0      4591.0
# ...          ...    ...          ...         ...
# 354360       2.0    2.0          0.0      5861.0
# 354362       6.0   30.0          2.0      7719.0
# 354366       6.0   32.0          0.0      1793.0
# 354367       2.0   37.0          0.0      6580.0
# 354368       2.0   37.0          1.0      2933.0
#
# [258067 rows x 9 columns]

# %% [markdown]
# Preparing and splitting the encoded data

# %%
#preparation and splitting for encoded data

data_enc.drop(['DateCrawled', 'DateCreated', 'LastSeen'], axis = 1, inplace = True)

data_enc.reset_index(drop = True, inplace = True)

feat_enc = data_enc.drop('Price', axis = 1)
targ_enc = data_enc['Price']

feat_train_enc, feat_test_enc, targ_train_enc, targ_test_enc = train_test_split(feat_enc, targ_enc, test_size=0.2,
                                                                 random_state=random_state)

print(feat_train_enc.shape)
print(feat_test_enc.shape)
print(targ_train_enc.shape)
print(targ_test_enc.shape)
# Out:
# (206453, 11)
# (51614, 11)
# (206453,)
# (51614,)

# %% [markdown]
# Our dataset has been cleaned, and split into the training, and test sets for both the encoded and unencoded data

# %% [markdown]
# Next, we will create a function to calculate the RMSE and then make it our evaluation metric for our models. It takes as arguments the prediction and target data.

# %%
#create an rmse function and make it our scorer
def rmse(pred, target): #creates the rmse function that takes target and prediction values as arguments
    pred = np.array(pred) #turns the prediction into a vector
    target = np.array(target) #turns the target into a vector
    error = pred - target
    error_sq = error ** 2
    error_sq_mean = error_sq.mean() #this gives the mean of all errors
    score = error_sq_mean ** 0.5 #this code gives the Square Root Error
    return score #returns the value


scorer = make_scorer(rmse, greater_is_better = False) 
#makes our rmse function our scorer and specifies that a smaller value is better
#make_scorer calls the function rmse, with its arguments

# %% [markdown]
# Using Linear Regression as a Baseline

# %% [markdown]
# ## Linear Regression (Baseline)

# %% [markdown]
# The next step is to train a Linear Regression model as our baseline. We will feed the Linear Regression model with the encoded data. Let's get a cross-validation score:

# %%
LR = LinearRegression()
LR_score = cross_val_score(LR, feat_train_enc, targ_train_enc, scoring = scorer, cv=5) #++++++
#calculates the cross-validation scores for 5 folds of the training data
print(LR_score.mean()) #prints the mean of those scores
# Out:
# -3024.555600865481

# %% [markdown]
# Next, we train the model and take note of the wall time it takes to do so

# %%
# %time LR.fit(feat_train_enc, targ_train_enc) #trains the model with the encoded data and times the process
# Out:
# CPU times: user 71.7 ms, sys: 24.9 ms, total: 96.6 ms
# Wall time: 90.9 ms
# LinearRegression()

# %% [markdown]
# Next, we get the prediction

# %%
# %time lr_pred = LR.predict(feat_test_enc) #gets predictions and times the process
# Out:
# CPU times: user 4.7 ms, sys: 8.13 ms, total: 12.8 ms
# Wall time: 5.96 ms

# %%
#Calculating the RMSE

rmse_lin = rmse(lr_pred, targ_test_enc)
rmse_lin
# Out:
# 3025.5635552424487

# %% [markdown]
# So the RMSE score of the Linear Model is 3025.56. This is the baseline score that all other models must exceed.

# %% [markdown]
# ## Decision Tree Regressor

# %% [markdown]
# For this model we will perform hyperparameter tuning (with the max_depth hyperparameter). We want to find the best value to set it to when training the model. We will choose the hyperparameter which gets the best cross-validation score.

# %%
#Decision Tree Rgressor - hyperparameter tuning

for depth in range(1, 20):
    DTR = DecisionTreeRegressor(max_depth = depth, random_state=random_state)
    
    DTR_score = cross_val_score(DTR, feat_train_enc, targ_train_enc, scoring=scorer, cv=5)
    #gets cross-validation score
    
    print('Max_depth', depth, 'score:', DTR_score.mean())
    #prints max_depth value and the mean cross-validation score
# Out:
# Max_depth 1 score: -3521.978669523077
# Max_depth 2 score: -3069.033708414861
# Max_depth 3 score: -2682.365668080236
# Max_depth 4 score: -2439.3184454603615
# Max_depth 5 score: -2271.762077459454
# Max_depth 6 score: -2169.0729030836947
# Max_depth 7 score: -2076.1607854002673
# Max_depth 8 score: -2000.3913187802452
# Max_depth 9 score: -1925.2246002770867
# Max_depth 10 score: -1880.0420807615567
# Max_depth 11 score: -1838.190057993053
# Max_depth 12 score: -1812.7662955205255
# Max_depth 13 score: -1806.4749135845188
# Max_depth 14 score: -1817.3029310842855
# Max_depth 15 score: -1834.2969364040723
# Max_depth 16 score: -1856.2507639921885
# Max_depth 17 score: -1877.8910328720085
# Max_depth 18 score: -1899.289940839661
# Max_depth 19 score: -1921.3172146778893

# %% [markdown]
# The best score was gotten when the max_depth hyperparameter was 13. So this max_depth of 13 will be used to train our model and get predictions, and the processes will be timed.

# %%
#DTR Training

DTR = DecisionTreeRegressor(max_depth = 13, random_state = random_state)

# %time DTR.fit(feat_train_enc, targ_train_enc)
# Out:
# CPU times: user 1.13 s, sys: 3.82 ms, total: 1.13 s
# Wall time: 1.13 s
# DecisionTreeRegressor(max_depth=13, random_state=12345)

# %%
#DTR model prediction
# %time DTR_pred = DTR.predict(feat_test_enc)
# Out:
# CPU times: user 14.5 ms, sys: 64 µs, total: 14.5 ms
# Wall time: 12.9 ms

# %%
#DTR RMSE
DTR_rmse = rmse(targ_test_enc, DTR_pred)
DTR_rmse
# Out:
# 1741.9646827979418

# %% [markdown]
# The RMSE for the Decision Tree model is 1741.96 which is way better than our baseline

# %% [markdown]
# ## Random Forest Regressor

# %% [markdown]
# For this modelling, we would be calling the RandomForestRegressor() function. The hyperparameters that we will be dealing with are max_depth, which is the depth of each tree, and n_estimators, which is the number of trees.

# %%
#Random Forest Regressor - hyperparameter tuning
for depth in range(5, 20):
    RFR = RandomForestRegressor(n_estimators = 40, max_depth = depth, random_state = random_state)
    RFR_score = cross_val_score(RFR, feat_train_enc, targ_train_enc, scoring = scorer, cv = 5)
    print('Max_depth', depth, 'score:', RFR_score.mean())
# Out:
# Max_depth 5 score: -2242.7838215752417
# Max_depth 6 score: -2123.2738875063774
# Max_depth 7 score: -2017.4549151904678
# Max_depth 8 score: -1927.3379542957125
# Max_depth 9 score: -1843.111338657626
# Max_depth 10 score: -1770.4342461342865
# Max_depth 11 score: -1705.9164234292668
# Max_depth 12 score: -1652.6048068778769
# Max_depth 13 score: -1609.427899022185
# Max_depth 14 score: -1574.9250191060187
# Max_depth 15 score: -1549.3650093061883
# Max_depth 16 score: -1531.8121481561598
# Max_depth 17 score: -1518.0519262817368
# Max_depth 18 score: -1508.885344389258
# Max_depth 19 score: -1504.218039629033

# %% [markdown]
# Next we train and test our model, with the processes being timed

# %%
#Random Forest Regressor model training
model_RFR = RandomForestRegressor(n_estimators = 40, max_depth = 19, random_state = random_state)
# %time model_RFR.fit(feat_train_enc, targ_train_enc)
# Out:
# CPU times: user 40.4 s, sys: 128 ms, total: 40.6 s
# Wall time: 40.7 s
# RandomForestRegressor(max_depth=19, n_estimators=40, random_state=12345)

# %%
#Random Forest Regressor model predictions
# %time RFR_pred = model_RFR.predict(feat_test_enc)
# Out:
# CPU times: user 885 ms, sys: 19 µs, total: 885 ms
# Wall time: 886 ms

# %% [markdown]
# Calculating the RMSE

# %%
RFR_model_RMSE = rmse(targ_test_enc, RFR_pred)
RFR_model_RMSE
# Out:
# 1457.4614759314102

# %% [markdown]
# RMSE of 1457.456. Much better than our baseline

# %% [markdown]
# ## CatBoost Regressor

# %% [markdown]
# CatBoost regressor uses gradient boosting, so, we don't need prior encoding. We will be tuning using different hyperparameters this time, such as depth, learning rate, 12_lear_reg, iterations, loss functions, random_speed. We will find the best parameters using GridSearchCV.

# %%
CBR = CatBoostRegressor()
parameters={'depth': [6, 8, 10],
           'learning_rate': [0.5, 0.1],
           'l2_leaf_reg': [2, 4],
           'iterations': [10, 50],
           'loss_function': ['RMSE'],
           'random_seed': [random_state]} #our dictionary of hyperparameters that will be looped through when 
                                          #we feed them to GridSearch
grid = GridSearchCV(estimator = CBR, param_grid = parameters, scoring = scorer, cv = 3, n_jobs=-1, verbose=0)

grid.fit(f_train_gbm, t_train_gbm,  cat_features = dat_features) #fits our training unencoded data into our grid instance

best_par = grid.best_params_ #gets the best set of parameters for our model
# Out:
# 0:	learn: 3157.5838254	total: 180ms	remaining: 1.62s
# 1:	learn: 2464.3591891	total: 355ms	remaining: 1.42s
# 2:	learn: 2156.0403011	total: 530ms	remaining: 1.24s
# 3:	learn: 2006.3875119	total: 687ms	remaining: 1.03s
# 4:	learn: 1926.1073904	total: 849ms	remaining: 849ms
# 5:	learn: 1891.7555166	total: 1s	remaining: 669ms
# 6:	learn: 1862.9877756	total: 1.17s	remaining: 500ms
# 7:	learn: 1834.7744324	total: 1.32s	remaining: 331ms
# 8:	learn: 1819.1045177	total: 1.49s	remaining: 165ms
# 9:	learn: 1801.2861528	total: 1.64s	remaining: 0us
# 0:	learn: 3160.8208597	total: 189ms	remaining: 1.7s
# 1:	learn: 2486.2182110	total: 367ms	remaining: 1.47s
# 2:	learn: 2205.0192763	total: 545ms	remaining: 1.27s
# 3:	learn: 2020.3149201	total: 704ms	remaining: 1.05s
# 4:	learn: 1943.4368540	total: 862ms	remaining: 862ms
# 5:	learn: 1898.8838408	total: 1.01s	remaining: 677ms
# 6:	learn: 1868.5899521	total: 1.18s	remaining: 507ms
# 7:	learn: 1846.1523077	total: 1.34s	remaining: 334ms
# 8:	learn: 1817.6770620	total: 1.5s	remaining: 166ms
# 9:	learn: 1798.0647249	total: 1.65s	remaining: 0us
# 0:	learn: 3190.5607226	total: 179ms	remaining: 1.61s
# 1:	learn: 2482.3654185	total: 363ms	remaining: 1.45s
# 2:	learn: 2180.0692119	total: 532ms	remaining: 1.24s
# 3:	learn: 2023.0221271	total: 692ms	remaining: 1.04s
# 4:	learn: 1947.3742658	total: 852ms	remaining: 852ms
# 5:	learn: 1891.6450533	total: 1.01s	remaining: 672ms
# 6:	learn: 1853.3440935	total: 1.17s	remaining: 501ms
# 7:	learn: 1820.5098473	total: 1.32s	remaining: 330ms
# 8:	learn: 1803.6744873	total: 1.48s	remaining: 165ms
# 9:	learn: 1784.2294384	total: 1.64s	remaining: 0us
# 0:	learn: 4329.2224504	total: 175ms	remaining: 1.57s
# 1:	learn: 4038.3886626	total: 340ms	remaining: 1.36s
# 2:	learn: 3781.2281142	total: 511ms	remaining: 1.19s
# 3:	learn: 3550.7840993	total: 677ms	remaining: 1.01s
# 4:	learn: 3350.6093154	total: 835ms	remaining: 835ms
# 5:	learn: 3174.3886435	total: 993ms	remaining: 662ms
# 6:	learn: 3018.8793448	total: 1.16s	remaining: 496ms
# 7:	learn: 2877.4432448	total: 1.34s	remaining: 335ms
# 8:	learn: 2754.7444323	total: 1.51s	remaining: 167ms
# 9:	learn: 2644.1364460	total: 1.67s	remaining: 0us
# 0:	learn: 4323.1573717	total: 179ms	remaining: 1.61s
# 1:	learn: 4034.2121088	total: 343ms	remaining: 1.37s
# 2:	learn: 3778.3733104	total: 507ms	remaining: 1.18s
# 3:	learn: 3550.0966421	total: 677ms	remaining: 1.01s
# 4:	learn: 3351.3015285	total: 858ms	remaining: 858ms
# 5:	learn: 3177.8355138	total: 1.01s	remaining: 675ms
# 6:	learn: 3023.3150317	total: 1.17s	remaining: 502ms
# 7:	learn: 2884.0342315	total: 1.33s	remaining: 332ms
# 8:	learn: 2758.3916682	total: 1.49s	remaining: 166ms
# 9:	learn: 2647.3749733	total: 1.64s	remaining: 0us
# 0:	learn: 4343.8235713	total: 185ms	remaining: 1.67s
# 1:	learn: 4055.9834887	total: 353ms	remaining: 1.41s
# 2:	learn: 3790.1559379	total: 515ms	remaining: 1.2s
# 3:	learn: 3560.0166557	total: 675ms	remaining: 1.01s
# 4:	learn: 3353.6149085	total: 835ms	remaining: 835ms
# 5:	learn: 3173.3881878	total: 1.01s	remaining: 672ms
# 6:	learn: 3013.6534814	total: 1.17s	remaining: 501ms
# 7:	learn: 2876.1179490	total: 1.32s	remaining: 331ms
# 8:	learn: 2749.2529458	total: 1.48s	remaining: 165ms
# 9:	learn: 2638.7678292	total: 1.65s	remaining: 0us
# 0:	learn: 3158.3537058	total: 175ms	remaining: 1.57s
# 1:	learn: 2465.4654576	total: 335ms	remaining: 1.34s
# 2:	learn: 2156.9715450	total: 510ms	remaining: 1.19s
# 3:	learn: 2007.2083644	total: 664ms	remaining: 996ms
# 4:	learn: 1927.6246597	total: 843ms	remaining: 843ms
# 5:	learn: 1890.7680200	total: 1s	remaining: 668ms
# 6:	learn: 1866.2577803	total: 1.16s	remaining: 495ms
# 7:	learn: 1835.8752138	total: 1.31s	remaining: 328ms
# 8:	learn: 1810.5613826	total: 1.47s	remaining: 163ms
# 9:	learn: 1793.9450013	total: 1.63s	remaining: 0us
# 0:	learn: 3161.5635850	total: 179ms	remaining: 1.61s
# 1:	learn: 2487.0232485	total: 339ms	remaining: 1.36s
# 2:	learn: 2205.5964842	total: 515ms	remaining: 1.2s
# 3:	learn: 2020.8944232	total: 672ms	remaining: 1.01s
# 4:	learn: 1944.1834363	total: 830ms	remaining: 830ms
# 5:	learn: 1900.2124590	total: 985ms	remaining: 657ms
# 6:	learn: 1870.1809743	total: 1.16s	remaining: 498ms
# 7:	learn: 1847.9643776	total: 1.33s	remaining: 332ms
# 8:	learn: 1819.1538587	total: 1.49s	remaining: 165ms
# 9:	learn: 1792.8607394	total: 1.63s	remaining: 0us
# 0:	learn: 3191.5200125	total: 179ms	remaining: 1.61s
# 1:	learn: 2483.1695911	total: 346ms	remaining: 1.39s
# 2:	learn: 2180.7749092	total: 511ms	remaining: 1.19s
# 3:	learn: 2023.6667942	total: 678ms	remaining: 1.02s
# 4:	learn: 1948.0991511	total: 853ms	remaining: 853ms
# 5:	learn: 1892.4401428	total: 1.02s	remaining: 680ms
# 6:	learn: 1854.3686977	total: 1.19s	remaining: 510ms
# 7:	learn: 1825.1382679	total: 1.34s	remaining: 336ms
# 8:	learn: 1807.6823481	total: 1.5s	remaining: 166ms
# 9:	learn: 1782.9759112	total: 1.65s	remaining: 0us
# 0:	learn: 4329.4207103	total: 181ms	remaining: 1.63s
# 1:	learn: 4038.9226259	total: 357ms	remaining: 1.43s
# 2:	learn: 3781.8660002	total: 541ms	remaining: 1.26s
# 3:	learn: 3551.4830193	total: 701ms	remaining: 1.05s
# 4:	learn: 3351.4660203	total: 854ms	remaining: 854ms
# 5:	learn: 3175.2829003	total: 1.01s	remaining: 674ms
# 6:	learn: 3019.8211997	total: 1.17s	remaining: 500ms
# 7:	learn: 2878.3894228	total: 1.32s	remaining: 329ms
# 8:	learn: 2755.7993648	total: 1.48s	remaining: 164ms
# 9:	learn: 2645.1853736	total: 1.64s	remaining: 0us
# 0:	learn: 4323.3500201	total: 177ms	remaining: 1.59s
# 1:	learn: 4035.9176567	total: 337ms	remaining: 1.35s
# 2:	learn: 3781.5252065	total: 503ms	remaining: 1.17s
# 3:	learn: 3555.3912082	total: 669ms	remaining: 1s
# 4:	learn: 3356.8104641	total: 821ms	remaining: 821ms
# 5:	learn: 3177.7074221	total: 979ms	remaining: 652ms
# 6:	learn: 3018.8348284	total: 1.14s	remaining: 490ms
# 7:	learn: 2883.9725410	total: 1.3s	remaining: 324ms
# 8:	learn: 2759.2573201	total: 1.46s	remaining: 163ms
# 9:	learn: 2651.2527008	total: 1.63s	remaining: 0us
# 0:	learn: 4344.0740567	total: 176ms	remaining: 1.59s
# 1:	learn: 4056.4798444	total: 347ms	remaining: 1.39s
# 2:	learn: 3790.8112124	total: 510ms	remaining: 1.19s
# 3:	learn: 3560.7705590	total: 665ms	remaining: 997ms
# 4:	learn: 3354.4742340	total: 833ms	remaining: 833ms
# 5:	learn: 3174.3014075	total: 986ms	remaining: 658ms
# 6:	learn: 3014.5854651	total: 1.15s	remaining: 494ms
# 7:	learn: 2877.0747652	total: 1.31s	remaining: 329ms
# 8:	learn: 2750.2908120	total: 1.47s	remaining: 164ms
# 9:	learn: 2639.8087906	total: 1.63s	remaining: 0us
# 0:	learn: 3157.5838254	total: 179ms	remaining: 8.79s
# 1:	learn: 2464.3591891	total: 341ms	remaining: 8.17s
# 2:	learn: 2156.0403011	total: 512ms	remaining: 8.01s
# 3:	learn: 2006.3875119	total: 672ms	remaining: 7.73s
# 4:	learn: 1926.1073904	total: 837ms	remaining: 7.53s
# 5:	learn: 1891.7555166	total: 991ms	remaining: 7.26s
# 6:	learn: 1862.9877756	total: 1.16s	remaining: 7.1s
# 7:	learn: 1834.7744324	total: 1.31s	remaining: 6.87s
# 8:	learn: 1819.1045177	total: 1.47s	remaining: 6.69s
# 9:	learn: 1801.2861528	total: 1.6s	remaining: 6.41s
# 10:	learn: 1784.1044555	total: 1.76s	remaining: 6.25s
# 11:	learn: 1761.9664400	total: 1.92s	remaining: 6.07s
# 12:	learn: 1745.8953689	total: 2.07s	remaining: 5.9s
# 13:	learn: 1736.1745639	total: 2.23s	remaining: 5.73s
# 14:	learn: 1722.7310933	total: 2.38s	remaining: 5.57s
# 15:	learn: 1714.4162455	total: 2.54s	remaining: 5.4s
# 16:	learn: 1707.0553914	total: 2.7s	remaining: 5.25s
# 17:	learn: 1697.5312774	total: 2.87s	remaining: 5.09s
# 18:	learn: 1686.7102065	total: 3.03s	remaining: 4.94s
# 19:	learn: 1682.4415912	total: 3.19s	remaining: 4.78s
# 20:	learn: 1675.4806559	total: 3.35s	remaining: 4.62s
# 21:	learn: 1669.8873896	total: 3.51s	remaining: 4.47s
# 22:	learn: 1662.4530519	total: 3.67s	remaining: 4.3s
# 23:	learn: 1658.4018493	total: 3.82s	remaining: 4.14s
# 24:	learn: 1654.0140690	total: 3.97s	remaining: 3.97s
# 25:	learn: 1651.3679156	total: 4.12s	remaining: 3.81s
# 26:	learn: 1646.4673029	total: 4.28s	remaining: 3.65s
# 27:	learn: 1643.5734663	total: 4.44s	remaining: 3.49s
# 28:	learn: 1635.7761595	total: 4.61s	remaining: 3.33s
# 29:	learn: 1632.3852509	total: 4.76s	remaining: 3.17s
# 30:	learn: 1628.9905547	total: 4.93s	remaining: 3.02s
# 31:	learn: 1626.5119817	total: 5.08s	remaining: 2.86s
# 32:	learn: 1621.6105056	total: 5.25s	remaining: 2.7s
# 33:	learn: 1619.8492153	total: 5.4s	remaining: 2.54s
# 34:	learn: 1616.4245482	total: 5.56s	remaining: 2.38s
# 35:	learn: 1613.5747642	total: 5.71s	remaining: 2.22s
# 36:	learn: 1611.3449004	total: 5.87s	remaining: 2.06s
# 37:	learn: 1609.1400602	total: 6.02s	remaining: 1.9s
# 38:	learn: 1607.0014477	total: 6.17s	remaining: 1.74s
# 39:	learn: 1604.0478528	total: 6.33s	remaining: 1.58s
# 40:	learn: 1602.1362323	total: 6.47s	remaining: 1.42s
# 41:	learn: 1600.4442312	total: 6.63s	remaining: 1.26s
# 42:	learn: 1599.7926392	total: 6.8s	remaining: 1.11s
# 43:	learn: 1598.2112973	total: 6.95s	remaining: 948ms
# 44:	learn: 1595.4317868	total: 7.11s	remaining: 790ms
# 45:	learn: 1591.9162349	total: 7.27s	remaining: 632ms
# 46:	learn: 1589.8015860	total: 7.42s	remaining: 474ms
# 47:	learn: 1588.2265517	total: 7.58s	remaining: 316ms
# 48:	learn: 1586.2335500	total: 7.73s	remaining: 158ms
# 49:	learn: 1583.6327593	total: 7.89s	remaining: 0us
# 0:	learn: 3160.8208597	total: 173ms	remaining: 8.47s
# 1:	learn: 2486.2182110	total: 337ms	remaining: 8.08s
# 2:	learn: 2205.0192763	total: 505ms	remaining: 7.92s
# 3:	learn: 2020.3149201	total: 662ms	remaining: 7.61s
# 4:	learn: 1943.4368540	total: 813ms	remaining: 7.32s
# 5:	learn: 1898.8838408	total: 972ms	remaining: 7.13s
# 6:	learn: 1868.5899521	total: 1.13s	remaining: 6.96s
# 7:	learn: 1846.1523077	total: 1.28s	remaining: 6.74s
# 8:	learn: 1817.6770620	total: 1.44s	remaining: 6.55s
# 9:	learn: 1798.0647249	total: 1.58s	remaining: 6.34s
# 10:	learn: 1785.4641061	total: 1.75s	remaining: 6.21s
# 11:	learn: 1771.9701243	total: 1.91s	remaining: 6.04s
# 12:	learn: 1750.4489301	total: 2.06s	remaining: 5.86s
# 13:	learn: 1740.2370800	total: 2.21s	remaining: 5.67s
# 14:	learn: 1728.8704044	total: 2.36s	remaining: 5.51s
# 15:	learn: 1716.5963704	total: 2.51s	remaining: 5.33s
# 16:	learn: 1707.1351261	total: 2.68s	remaining: 5.2s
# 17:	learn: 1698.9015204	total: 2.85s	remaining: 5.07s
# 18:	learn: 1689.3453368	total: 3.01s	remaining: 4.91s
# 19:	learn: 1681.8199931	total: 3.15s	remaining: 4.73s
# 20:	learn: 1677.6193868	total: 3.31s	remaining: 4.58s
# 21:	learn: 1671.5304139	total: 3.49s	remaining: 4.44s
# 22:	learn: 1666.6149487	total: 3.64s	remaining: 4.27s
# 23:	learn: 1662.9019481	total: 3.81s	remaining: 4.13s
# 24:	learn: 1655.4891025	total: 3.98s	remaining: 3.98s
# 25:	learn: 1651.9578617	total: 4.13s	remaining: 3.81s
# 26:	learn: 1647.0762732	total: 4.29s	remaining: 3.65s
# 27:	learn: 1641.9326703	total: 4.44s	remaining: 3.49s
# 28:	learn: 1636.5516173	total: 4.59s	remaining: 3.33s
# 29:	learn: 1634.0055898	total: 4.74s	remaining: 3.16s
# 30:	learn: 1629.9898931	total: 4.9s	remaining: 3s
# 31:	learn: 1625.4559816	total: 5.06s	remaining: 2.85s
# 32:	learn: 1622.0096285	total: 5.21s	remaining: 2.69s
# 33:	learn: 1617.6999876	total: 5.38s	remaining: 2.53s
# 34:	learn: 1614.5975205	total: 5.54s	remaining: 2.37s
# 35:	learn: 1612.3992373	total: 5.7s	remaining: 2.22s
# 36:	learn: 1610.2428201	total: 5.87s	remaining: 2.06s
# 37:	learn: 1606.8858424	total: 6.02s	remaining: 1.9s
# 38:	learn: 1604.0537499	total: 6.18s	remaining: 1.74s
# 39:	learn: 1602.0535036	total: 6.33s	remaining: 1.58s
# 40:	learn: 1599.4175548	total: 6.49s	remaining: 1.42s
# 41:	learn: 1595.4294122	total: 6.64s	remaining: 1.26s
# 42:	learn: 1591.7202546	total: 6.79s	remaining: 1.1s
# 43:	learn: 1590.0595834	total: 6.94s	remaining: 947ms
# 44:	learn: 1588.2308301	total: 7.11s	remaining: 791ms
# 45:	learn: 1586.7182931	total: 7.27s	remaining: 632ms
# 46:	learn: 1584.3863714	total: 7.43s	remaining: 474ms
# 47:	learn: 1581.4920042	total: 7.59s	remaining: 316ms
# 48:	learn: 1580.1072300	total: 7.75s	remaining: 158ms
# 49:	learn: 1578.5292693	total: 7.91s	remaining: 0us
# 0:	learn: 3190.5607226	total: 173ms	remaining: 8.46s
# 1:	learn: 2482.3654185	total: 356ms	remaining: 8.55s
# 2:	learn: 2180.0692119	total: 520ms	remaining: 8.15s
# 3:	learn: 2023.0221271	total: 675ms	remaining: 7.77s
# 4:	learn: 1947.3742658	total: 831ms	remaining: 7.48s
# 5:	learn: 1891.6450533	total: 982ms	remaining: 7.2s
# 6:	learn: 1853.3440935	total: 1.16s	remaining: 7.15s
# 7:	learn: 1820.5098473	total: 1.32s	remaining: 6.91s
# 8:	learn: 1803.6744873	total: 1.48s	remaining: 6.72s
# 9:	learn: 1784.2294384	total: 1.63s	remaining: 6.51s
# 10:	learn: 1765.1218064	total: 1.79s	remaining: 6.34s
# 11:	learn: 1752.6898217	total: 1.93s	remaining: 6.1s
# 12:	learn: 1736.8108565	total: 2.09s	remaining: 5.94s
# 13:	learn: 1728.5283656	total: 2.25s	remaining: 5.78s
# 14:	learn: 1714.1327868	total: 2.4s	remaining: 5.61s
# 15:	learn: 1705.3924365	total: 2.56s	remaining: 5.44s
# 16:	learn: 1696.9709957	total: 2.72s	remaining: 5.27s
# 17:	learn: 1689.1720939	total: 2.87s	remaining: 5.1s
# 18:	learn: 1682.0582770	total: 3.03s	remaining: 4.94s
# 19:	learn: 1676.1117412	total: 3.19s	remaining: 4.78s
# 20:	learn: 1667.1964235	total: 3.35s	remaining: 4.63s
# 21:	learn: 1661.9061140	total: 3.51s	remaining: 4.46s
# 22:	learn: 1654.9997117	total: 3.67s	remaining: 4.3s
# 23:	learn: 1648.9533116	total: 3.83s	remaining: 4.15s
# 24:	learn: 1645.0686403	total: 3.99s	remaining: 3.99s
# 25:	learn: 1637.4403108	total: 4.14s	remaining: 3.82s
# 26:	learn: 1634.0224242	total: 4.29s	remaining: 3.66s
# 27:	learn: 1631.4505881	total: 4.45s	remaining: 3.49s
# 28:	learn: 1627.5894912	total: 4.6s	remaining: 3.33s
# 29:	learn: 1623.0659505	total: 4.75s	remaining: 3.17s
# 30:	learn: 1619.1336804	total: 4.91s	remaining: 3.01s
# 31:	learn: 1615.2696120	total: 5.08s	remaining: 2.85s
# 32:	learn: 1611.0173901	total: 5.23s	remaining: 2.7s
# 33:	learn: 1608.4568211	total: 5.4s	remaining: 2.54s
# 34:	learn: 1606.4513739	total: 5.57s	remaining: 2.39s
# 35:	learn: 1603.5893279	total: 5.71s	remaining: 2.22s
# 36:	learn: 1601.4122395	total: 5.87s	remaining: 2.06s
# 37:	learn: 1598.4266478	total: 6.02s	remaining: 1.9s
# 38:	learn: 1594.9867437	total: 6.18s	remaining: 1.74s
# 39:	learn: 1592.1402455	total: 6.34s	remaining: 1.58s
# 40:	learn: 1589.8627043	total: 6.5s	remaining: 1.43s
# 41:	learn: 1588.2655104	total: 6.66s	remaining: 1.27s
# 42:	learn: 1586.9709845	total: 6.82s	remaining: 1.11s
# 43:	learn: 1584.3577992	total: 6.97s	remaining: 950ms
# 44:	learn: 1582.9324573	total: 7.14s	remaining: 793ms
# 45:	learn: 1579.2958792	total: 7.29s	remaining: 634ms
# 46:	learn: 1576.4782303	total: 7.46s	remaining: 476ms
# 47:	learn: 1573.4922853	total: 7.62s	remaining: 317ms
# 48:	learn: 1571.7579758	total: 7.78s	remaining: 159ms
# 49:	learn: 1569.0799944	total: 7.93s	remaining: 0us
# 0:	learn: 4329.2224504	total: 190ms	remaining: 9.3s
# 1:	learn: 4038.3886626	total: 354ms	remaining: 8.5s
# 2:	learn: 3781.2281142	total: 508ms	remaining: 7.95s
# 3:	learn: 3550.7840993	total: 685ms	remaining: 7.87s
# 4:	learn: 3350.6093154	total: 842ms	remaining: 7.58s
# 5:	learn: 3174.3886435	total: 1s	remaining: 7.36s
# 6:	learn: 3018.8793448	total: 1.16s	remaining: 7.14s
# 7:	learn: 2877.4432448	total: 1.32s	remaining: 6.91s
# 8:	learn: 2754.7444323	total: 1.47s	remaining: 6.69s
# 9:	learn: 2644.1364460	total: 1.63s	remaining: 6.53s
# 10:	learn: 2545.7763919	total: 1.79s	remaining: 6.35s
# 11:	learn: 2463.1117666	total: 1.94s	remaining: 6.15s
# 12:	learn: 2388.3470952	total: 2.1s	remaining: 5.97s
# 13:	learn: 2322.3237482	total: 2.26s	remaining: 5.8s
# 14:	learn: 2263.9782035	total: 2.42s	remaining: 5.64s
# 15:	learn: 2210.4401352	total: 2.57s	remaining: 5.47s
# 16:	learn: 2164.4708407	total: 2.73s	remaining: 5.31s
# 17:	learn: 2123.3470745	total: 2.89s	remaining: 5.14s
# 18:	learn: 2090.7157957	total: 3.05s	remaining: 4.97s
# 19:	learn: 2058.2941444	total: 3.2s	remaining: 4.8s
# 20:	learn: 2028.6711902	total: 3.35s	remaining: 4.63s
# 21:	learn: 2003.9746416	total: 3.5s	remaining: 4.46s
# 22:	learn: 1983.0075948	total: 3.66s	remaining: 4.29s
# 23:	learn: 1963.4781224	total: 3.82s	remaining: 4.14s
# 24:	learn: 1945.7472654	total: 3.98s	remaining: 3.98s
# 25:	learn: 1930.4772717	total: 4.13s	remaining: 3.81s
# 26:	learn: 1914.6050217	total: 4.29s	remaining: 3.65s
# 27:	learn: 1901.1020438	total: 4.44s	remaining: 3.49s
# 28:	learn: 1889.5067658	total: 4.6s	remaining: 3.33s
# 29:	learn: 1879.7422014	total: 4.75s	remaining: 3.17s
# 30:	learn: 1870.1440406	total: 4.91s	remaining: 3.01s
# 31:	learn: 1860.7302622	total: 5.07s	remaining: 2.85s
# 32:	learn: 1851.8918957	total: 5.22s	remaining: 2.69s
# 33:	learn: 1844.0938117	total: 5.38s	remaining: 2.53s
# 34:	learn: 1837.6088625	total: 5.54s	remaining: 2.37s
# 35:	learn: 1829.6785406	total: 5.7s	remaining: 2.21s
# 36:	learn: 1824.6445287	total: 5.86s	remaining: 2.06s
# 37:	learn: 1817.0632964	total: 6.03s	remaining: 1.9s
# 38:	learn: 1810.3175366	total: 6.18s	remaining: 1.74s
# 39:	learn: 1803.6072208	total: 6.33s	remaining: 1.58s
# 40:	learn: 1798.6730673	total: 6.49s	remaining: 1.42s
# 41:	learn: 1791.7131011	total: 6.64s	remaining: 1.26s
# 42:	learn: 1785.2885086	total: 6.8s	remaining: 1.11s
# 43:	learn: 1780.6410490	total: 6.96s	remaining: 949ms
# 44:	learn: 1775.5940848	total: 7.11s	remaining: 790ms
# 45:	learn: 1770.8499492	total: 7.28s	remaining: 633ms
# 46:	learn: 1766.4587521	total: 7.41s	remaining: 473ms
# 47:	learn: 1763.3553322	total: 7.56s	remaining: 315ms
# 48:	learn: 1759.5310993	total: 7.73s	remaining: 158ms
# 49:	learn: 1756.7377517	total: 7.88s	remaining: 0us
# 0:	learn: 4323.1573717	total: 192ms	remaining: 9.42s
# 1:	learn: 4034.2121088	total: 336ms	remaining: 8.06s
# 2:	learn: 3778.3733104	total: 513ms	remaining: 8.03s
# 3:	learn: 3550.0966421	total: 673ms	remaining: 7.74s
# 4:	learn: 3351.3015285	total: 832ms	remaining: 7.49s
# 5:	learn: 3177.8355138	total: 986ms	remaining: 7.23s
# 6:	learn: 3023.3150317	total: 1.15s	remaining: 7.06s
# 7:	learn: 2884.0342315	total: 1.31s	remaining: 6.86s
# 8:	learn: 2758.3916682	total: 1.47s	remaining: 6.71s
# 9:	learn: 2647.3749733	total: 1.65s	remaining: 6.61s
# 10:	learn: 2550.2978585	total: 1.83s	remaining: 6.47s
# 11:	learn: 2461.5633899	total: 1.98s	remaining: 6.27s
# 12:	learn: 2387.0007520	total: 2.13s	remaining: 6.06s
# 13:	learn: 2321.9666093	total: 2.28s	remaining: 5.87s
# 14:	learn: 2263.4263710	total: 2.44s	remaining: 5.7s
# 15:	learn: 2212.3465973	total: 2.6s	remaining: 5.52s
# 16:	learn: 2166.1533972	total: 2.75s	remaining: 5.35s
# 17:	learn: 2121.9118640	total: 2.91s	remaining: 5.17s
# 18:	learn: 2085.7028840	total: 3.06s	remaining: 5s
# 19:	learn: 2054.7696391	total: 3.22s	remaining: 4.83s
# 20:	learn: 2026.6289974	total: 3.38s	remaining: 4.67s
# 21:	learn: 1999.9705029	total: 3.56s	remaining: 4.53s
# 22:	learn: 1974.9189297	total: 3.71s	remaining: 4.36s
# 23:	learn: 1955.9963824	total: 3.85s	remaining: 4.17s
# 24:	learn: 1937.9344359	total: 3.99s	remaining: 3.99s
# 25:	learn: 1919.6395611	total: 4.15s	remaining: 3.83s
# 26:	learn: 1903.9415451	total: 4.31s	remaining: 3.67s
# 27:	learn: 1890.2984483	total: 4.46s	remaining: 3.51s
# 28:	learn: 1879.6442510	total: 4.62s	remaining: 3.34s
# 29:	learn: 1868.5590805	total: 4.78s	remaining: 3.19s
# 30:	learn: 1855.0391421	total: 4.93s	remaining: 3.02s
# 31:	learn: 1846.2550733	total: 5.08s	remaining: 2.86s
# 32:	learn: 1836.9631894	total: 5.24s	remaining: 2.7s
# 33:	learn: 1829.3380077	total: 5.39s	remaining: 2.54s
# 34:	learn: 1822.7072072	total: 5.57s	remaining: 2.39s
# 35:	learn: 1815.9655873	total: 5.72s	remaining: 2.22s
# 36:	learn: 1806.0214256	total: 5.88s	remaining: 2.06s
# 37:	learn: 1798.5313851	total: 6.03s	remaining: 1.9s
# 38:	learn: 1793.2344318	total: 6.18s	remaining: 1.74s
# 39:	learn: 1787.0552306	total: 6.34s	remaining: 1.58s
# 40:	learn: 1781.7587745	total: 6.49s	remaining: 1.43s
# 41:	learn: 1777.5743973	total: 6.65s	remaining: 1.27s
# 42:	learn: 1772.7390515	total: 6.8s	remaining: 1.11s
# 43:	learn: 1768.7111942	total: 6.95s	remaining: 948ms
# 44:	learn: 1764.1720523	total: 7.11s	remaining: 790ms
# 45:	learn: 1760.8177817	total: 7.26s	remaining: 631ms
# 46:	learn: 1757.5233890	total: 7.42s	remaining: 474ms
# 47:	learn: 1753.4711313	total: 7.58s	remaining: 316ms
# 48:	learn: 1750.1856816	total: 7.75s	remaining: 158ms
# 49:	learn: 1746.1683593	total: 7.91s	remaining: 0us
# 0:	learn: 4343.8235713	total: 179ms	remaining: 8.77s
# 1:	learn: 4055.9834887	total: 345ms	remaining: 8.27s
# 2:	learn: 3790.1559379	total: 505ms	remaining: 7.91s
# 3:	learn: 3560.0166557	total: 670ms	remaining: 7.71s
# 4:	learn: 3353.6149085	total: 850ms	remaining: 7.65s
# 5:	learn: 3173.3881878	total: 1.02s	remaining: 7.49s
# 6:	learn: 3013.6534814	total: 1.18s	remaining: 7.24s
# 7:	learn: 2876.1179490	total: 1.33s	remaining: 6.98s
# 8:	learn: 2749.2529458	total: 1.49s	remaining: 6.78s
# 9:	learn: 2638.7678292	total: 1.64s	remaining: 6.55s
# 10:	learn: 2543.0152996	total: 1.8s	remaining: 6.38s
# 11:	learn: 2459.0703738	total: 1.95s	remaining: 6.19s
# 12:	learn: 2379.4667089	total: 2.11s	remaining: 6.01s
# 13:	learn: 2316.7929616	total: 2.26s	remaining: 5.82s
# 14:	learn: 2257.8160945	total: 2.43s	remaining: 5.67s
# 15:	learn: 2208.2018896	total: 2.58s	remaining: 5.48s
# 16:	learn: 2163.5923773	total: 2.74s	remaining: 5.32s
# 17:	learn: 2120.5326287	total: 2.89s	remaining: 5.14s
# 18:	learn: 2083.9662446	total: 3.05s	remaining: 4.97s
# 19:	learn: 2052.0542462	total: 3.21s	remaining: 4.81s
# 20:	learn: 2023.9057467	total: 3.36s	remaining: 4.64s
# 21:	learn: 1997.5793227	total: 3.51s	remaining: 4.47s
# 22:	learn: 1975.2762956	total: 3.67s	remaining: 4.3s
# 23:	learn: 1955.8273917	total: 3.81s	remaining: 4.13s
# 24:	learn: 1937.1926774	total: 3.96s	remaining: 3.96s
# 25:	learn: 1919.9161970	total: 4.12s	remaining: 3.8s
# 26:	learn: 1904.9907148	total: 4.29s	remaining: 3.65s
# 27:	learn: 1891.3641589	total: 4.44s	remaining: 3.49s
# 28:	learn: 1879.7378971	total: 4.6s	remaining: 3.33s
# 29:	learn: 1868.2283730	total: 4.75s	remaining: 3.17s
# 30:	learn: 1857.1609367	total: 4.91s	remaining: 3.01s
# 31:	learn: 1844.6380398	total: 5.07s	remaining: 2.85s
# 32:	learn: 1836.0027871	total: 5.22s	remaining: 2.69s
# 33:	learn: 1827.3765666	total: 5.38s	remaining: 2.53s
# 34:	learn: 1820.0394735	total: 5.54s	remaining: 2.37s
# 35:	learn: 1813.1890451	total: 5.69s	remaining: 2.21s
# 36:	learn: 1807.1491436	total: 5.84s	remaining: 2.05s
# 37:	learn: 1798.6968402	total: 6.01s	remaining: 1.9s
# 38:	learn: 1789.8035142	total: 6.18s	remaining: 1.74s
# 39:	learn: 1784.5943637	total: 6.34s	remaining: 1.58s
# 40:	learn: 1779.0871105	total: 6.48s	remaining: 1.42s
# 41:	learn: 1772.6198135	total: 6.64s	remaining: 1.26s
# 42:	learn: 1766.7346288	total: 6.8s	remaining: 1.11s
# 43:	learn: 1761.5383878	total: 6.97s	remaining: 950ms
# 44:	learn: 1757.0842552	total: 7.12s	remaining: 792ms
# 45:	learn: 1752.4569649	total: 7.28s	remaining: 633ms
# 46:	learn: 1748.6120985	total: 7.43s	remaining: 474ms
# 47:	learn: 1742.7227058	total: 7.58s	remaining: 316ms
# 48:	learn: 1739.3494871	total: 7.73s	remaining: 158ms
# 49:	learn: 1735.1494240	total: 7.88s	remaining: 0us
# 0:	learn: 3158.3537058	total: 203ms	remaining: 9.93s
# 1:	learn: 2465.4654576	total: 364ms	remaining: 8.74s
# 2:	learn: 2156.9715450	total: 543ms	remaining: 8.51s
# 3:	learn: 2007.2083644	total: 696ms	remaining: 8s
# 4:	learn: 1927.6246597	total: 855ms	remaining: 7.7s
# 5:	learn: 1890.7680200	total: 1s	remaining: 7.37s
# 6:	learn: 1866.2577803	total: 1.16s	remaining: 7.14s
# 7:	learn: 1835.8752138	total: 1.32s	remaining: 6.92s
# 8:	learn: 1810.5613826	total: 1.48s	remaining: 6.76s
# 9:	learn: 1793.9450013	total: 1.64s	remaining: 6.56s
# 10:	learn: 1781.7319083	total: 1.82s	remaining: 6.45s
# 11:	learn: 1772.9066999	total: 2.07s	remaining: 6.57s
# 12:	learn: 1746.7800789	total: 2.23s	remaining: 6.34s
# 13:	learn: 1736.8320454	total: 2.38s	remaining: 6.13s
# 14:	learn: 1728.2370173	total: 2.55s	remaining: 5.94s
# 15:	learn: 1719.5531552	total: 2.7s	remaining: 5.73s
# 16:	learn: 1712.6091985	total: 2.85s	remaining: 5.54s
# 17:	learn: 1704.9652841	total: 3.01s	remaining: 5.35s
# 18:	learn: 1696.0651054	total: 3.16s	remaining: 5.15s
# 19:	learn: 1687.5728830	total: 3.32s	remaining: 4.98s
# 20:	learn: 1680.4411271	total: 3.47s	remaining: 4.79s
# 21:	learn: 1676.1897163	total: 3.63s	remaining: 4.62s
# 22:	learn: 1671.9481968	total: 3.78s	remaining: 4.44s
# 23:	learn: 1665.1672161	total: 3.93s	remaining: 4.26s
# 24:	learn: 1659.8103252	total: 4.1s	remaining: 4.1s
# 25:	learn: 1657.0727329	total: 4.28s	remaining: 3.95s
# 26:	learn: 1652.9791574	total: 4.43s	remaining: 3.78s
# 27:	learn: 1649.9939325	total: 4.59s	remaining: 3.61s
# 28:	learn: 1645.3028747	total: 4.75s	remaining: 3.44s
# 29:	learn: 1637.4628792	total: 4.91s	remaining: 3.27s
# 30:	learn: 1635.2881566	total: 5.06s	remaining: 3.1s
# 31:	learn: 1630.1874328	total: 5.22s	remaining: 2.93s
# 32:	learn: 1627.0173790	total: 5.37s	remaining: 2.77s
# 33:	learn: 1622.1923202	total: 5.53s	remaining: 2.6s
# 34:	learn: 1618.6047760	total: 5.68s	remaining: 2.43s
# 35:	learn: 1615.4333265	total: 5.83s	remaining: 2.27s
# 36:	learn: 1612.6510236	total: 6s	remaining: 2.11s
# 37:	learn: 1610.0028851	total: 6.17s	remaining: 1.95s
# 38:	learn: 1607.0519805	total: 6.33s	remaining: 1.79s
# 39:	learn: 1606.1880585	total: 6.49s	remaining: 1.62s
# 40:	learn: 1602.1363167	total: 6.64s	remaining: 1.46s
# 41:	learn: 1599.6069608	total: 6.8s	remaining: 1.29s
# 42:	learn: 1597.2368995	total: 6.95s	remaining: 1.13s
# 43:	learn: 1594.9516649	total: 7.11s	remaining: 969ms
# 44:	learn: 1593.9805011	total: 7.26s	remaining: 806ms
# 45:	learn: 1592.6766055	total: 7.41s	remaining: 644ms
# 46:	learn: 1589.4547728	total: 7.56s	remaining: 483ms
# 47:	learn: 1587.4208742	total: 7.7s	remaining: 321ms
# 48:	learn: 1584.2612755	total: 7.85s	remaining: 160ms
# 49:	learn: 1582.1427887	total: 8.03s	remaining: 0us
# 0:	learn: 3161.5635850	total: 175ms	remaining: 8.59s
# 1:	learn: 2487.0232485	total: 339ms	remaining: 8.14s
# 2:	learn: 2205.5964842	total: 507ms	remaining: 7.94s
# 3:	learn: 2020.8944232	total: 674ms	remaining: 7.75s
# 4:	learn: 1944.1834363	total: 823ms	remaining: 7.41s
# 5:	learn: 1900.2124590	total: 977ms	remaining: 7.17s
# 6:	learn: 1870.1809743	total: 1.14s	remaining: 6.97s
# 7:	learn: 1847.9643776	total: 1.31s	remaining: 6.87s
# 8:	learn: 1819.1538587	total: 1.47s	remaining: 6.69s
# 9:	learn: 1792.8607394	total: 1.62s	remaining: 6.48s
# 10:	learn: 1776.8898815	total: 1.78s	remaining: 6.3s
# 11:	learn: 1767.8913501	total: 1.93s	remaining: 6.1s
# 12:	learn: 1755.8979558	total: 2.08s	remaining: 5.93s
# 13:	learn: 1743.5772546	total: 2.23s	remaining: 5.75s
# 14:	learn: 1727.6437167	total: 2.39s	remaining: 5.58s
# 15:	learn: 1717.5317751	total: 2.54s	remaining: 5.41s
# 16:	learn: 1710.3476621	total: 2.71s	remaining: 5.26s
# 17:	learn: 1698.4262671	total: 2.86s	remaining: 5.09s
# 18:	learn: 1690.2630729	total: 3.02s	remaining: 4.93s
# 19:	learn: 1685.8980289	total: 3.18s	remaining: 4.77s
# 20:	learn: 1679.4819749	total: 3.33s	remaining: 4.6s
# 21:	learn: 1673.5188272	total: 3.48s	remaining: 4.43s
# 22:	learn: 1667.7027219	total: 3.64s	remaining: 4.27s
# 23:	learn: 1664.3915338	total: 3.79s	remaining: 4.1s
# 24:	learn: 1658.8092255	total: 3.94s	remaining: 3.94s
# 25:	learn: 1652.8230278	total: 4.1s	remaining: 3.78s
# 26:	learn: 1648.6579582	total: 4.25s	remaining: 3.62s
# 27:	learn: 1645.3505786	total: 4.41s	remaining: 3.46s
# 28:	learn: 1643.4516314	total: 4.57s	remaining: 3.31s
# 29:	learn: 1639.1745071	total: 4.73s	remaining: 3.15s
# 30:	learn: 1634.5330963	total: 4.89s	remaining: 3s
# 31:	learn: 1631.1828428	total: 5.04s	remaining: 2.83s
# 32:	learn: 1628.7074794	total: 5.2s	remaining: 2.68s
# 33:	learn: 1623.8085367	total: 5.36s	remaining: 2.52s
# 34:	learn: 1621.1495118	total: 5.51s	remaining: 2.36s
# 35:	learn: 1617.9654469	total: 5.67s	remaining: 2.2s
# 36:	learn: 1614.7082237	total: 5.83s	remaining: 2.05s
# 37:	learn: 1611.8086206	total: 5.98s	remaining: 1.89s
# 38:	learn: 1607.1079499	total: 6.15s	remaining: 1.73s
# 39:	learn: 1605.4335430	total: 6.28s	remaining: 1.57s
# 40:	learn: 1603.4723821	total: 6.46s	remaining: 1.42s
# 41:	learn: 1601.0097351	total: 6.62s	remaining: 1.26s
# 42:	learn: 1598.8555636	total: 6.77s	remaining: 1.1s
# 43:	learn: 1595.5801148	total: 6.92s	remaining: 944ms
# 44:	learn: 1593.0664301	total: 7.08s	remaining: 786ms
# 45:	learn: 1591.2943023	total: 7.23s	remaining: 629ms
# 46:	learn: 1588.3751706	total: 7.39s	remaining: 472ms
# 47:	learn: 1585.5041484	total: 7.55s	remaining: 314ms
# 48:	learn: 1583.5097079	total: 7.69s	remaining: 157ms
# 49:	learn: 1581.0082632	total: 7.84s	remaining: 0us
# 0:	learn: 3191.5200125	total: 173ms	remaining: 8.49s
# 1:	learn: 2483.1695911	total: 337ms	remaining: 8.09s
# 2:	learn: 2180.7749092	total: 500ms	remaining: 7.84s
# 3:	learn: 2023.6667942	total: 656ms	remaining: 7.55s
# 4:	learn: 1948.0991511	total: 812ms	remaining: 7.3s
# 5:	learn: 1892.4401428	total: 971ms	remaining: 7.12s
# 6:	learn: 1854.3686977	total: 1.14s	remaining: 7.02s
# 7:	learn: 1825.1382679	total: 1.31s	remaining: 6.87s
# 8:	learn: 1807.6823481	total: 1.47s	remaining: 6.69s
# 9:	learn: 1782.9759112	total: 1.61s	remaining: 6.46s
# 10:	learn: 1770.0990813	total: 1.76s	remaining: 6.26s
# 11:	learn: 1752.9327720	total: 1.93s	remaining: 6.09s
# 12:	learn: 1742.7776114	total: 2.08s	remaining: 5.92s
# 13:	learn: 1730.5295051	total: 2.23s	remaining: 5.75s
# 14:	learn: 1718.1952869	total: 2.4s	remaining: 5.6s
# 15:	learn: 1711.6299168	total: 2.56s	remaining: 5.43s
# 16:	learn: 1704.4597062	total: 2.73s	remaining: 5.3s
# 17:	learn: 1699.3739498	total: 2.89s	remaining: 5.14s
# 18:	learn: 1688.0183497	total: 3.04s	remaining: 4.96s
# 19:	learn: 1681.3133663	total: 3.19s	remaining: 4.79s
# 20:	learn: 1677.3415734	total: 3.34s	remaining: 4.62s
# 21:	learn: 1670.2146970	total: 3.5s	remaining: 4.46s
# 22:	learn: 1664.2446826	total: 3.66s	remaining: 4.3s
# 23:	learn: 1661.1698357	total: 3.81s	remaining: 4.13s
# 24:	learn: 1656.1509454	total: 3.96s	remaining: 3.96s
# 25:	learn: 1649.5551780	total: 4.11s	remaining: 3.8s
# 26:	learn: 1643.4444715	total: 4.26s	remaining: 3.63s
# 27:	learn: 1639.5193643	total: 4.41s	remaining: 3.47s
# 28:	learn: 1637.4069379	total: 4.57s	remaining: 3.31s
# 29:	learn: 1632.5829709	total: 4.73s	remaining: 3.15s
# 30:	learn: 1628.9720857	total: 4.86s	remaining: 2.98s
# 31:	learn: 1626.3539587	total: 5.01s	remaining: 2.82s
# 32:	learn: 1622.3146652	total: 5.16s	remaining: 2.66s
# 33:	learn: 1616.8194479	total: 5.31s	remaining: 2.5s
# 34:	learn: 1611.2548377	total: 5.47s	remaining: 2.34s
# 35:	learn: 1609.0526739	total: 5.62s	remaining: 2.19s
# 36:	learn: 1605.2045534	total: 5.78s	remaining: 2.03s
# 37:	learn: 1601.7590015	total: 5.93s	remaining: 1.87s
# 38:	learn: 1597.8603804	total: 6.08s	remaining: 1.72s
# 39:	learn: 1595.8100602	total: 6.24s	remaining: 1.56s
# 40:	learn: 1591.5148547	total: 6.4s	remaining: 1.4s
# 41:	learn: 1587.5431127	total: 6.57s	remaining: 1.25s
# 42:	learn: 1584.8566699	total: 6.74s	remaining: 1.1s
# 43:	learn: 1581.1848062	total: 6.91s	remaining: 943ms
# 44:	learn: 1578.7787096	total: 7.07s	remaining: 786ms
# 45:	learn: 1576.8791847	total: 7.22s	remaining: 628ms
# 46:	learn: 1574.1247711	total: 7.38s	remaining: 471ms
# 47:	learn: 1573.3939087	total: 7.53s	remaining: 314ms
# 48:	learn: 1570.8477874	total: 7.68s	remaining: 157ms
# 49:	learn: 1570.0283423	total: 7.84s	remaining: 0us
# 0:	learn: 4329.4207103	total: 177ms	remaining: 8.67s
# 1:	learn: 4038.9226259	total: 334ms	remaining: 8.01s
# 2:	learn: 3781.8660002	total: 497ms	remaining: 7.79s
# 3:	learn: 3551.4830193	total: 659ms	remaining: 7.57s
# 4:	learn: 3351.4660203	total: 814ms	remaining: 7.32s
# 5:	learn: 3175.2829003	total: 970ms	remaining: 7.11s
# 6:	learn: 3019.8211997	total: 1.13s	remaining: 6.92s
# 7:	learn: 2878.3894228	total: 1.28s	remaining: 6.74s
# 8:	learn: 2755.7993648	total: 1.45s	remaining: 6.61s
# 9:	learn: 2645.1853736	total: 1.61s	remaining: 6.46s
# 10:	learn: 2546.8939122	total: 1.78s	remaining: 6.3s
# 11:	learn: 2464.2360028	total: 1.93s	remaining: 6.12s
# 12:	learn: 2389.4302089	total: 2.09s	remaining: 5.95s
# 13:	learn: 2323.4826104	total: 2.24s	remaining: 5.77s
# 14:	learn: 2265.0903022	total: 2.4s	remaining: 5.59s
# 15:	learn: 2211.5019810	total: 2.55s	remaining: 5.43s
# 16:	learn: 2165.5331277	total: 2.71s	remaining: 5.27s
# 17:	learn: 2124.3701394	total: 2.87s	remaining: 5.1s
# 18:	learn: 2091.7419695	total: 3.03s	remaining: 4.94s
# 19:	learn: 2059.3792635	total: 3.18s	remaining: 4.77s
# 20:	learn: 2029.7047843	total: 3.35s	remaining: 4.62s
# 21:	learn: 2004.9917823	total: 3.5s	remaining: 4.46s
# 22:	learn: 1984.0842253	total: 3.66s	remaining: 4.29s
# 23:	learn: 1964.5158691	total: 3.82s	remaining: 4.14s
# 24:	learn: 1946.8316239	total: 3.98s	remaining: 3.98s
# 25:	learn: 1931.5498471	total: 4.13s	remaining: 3.82s
# 26:	learn: 1915.6765619	total: 4.29s	remaining: 3.66s
# 27:	learn: 1902.1748075	total: 4.45s	remaining: 3.49s
# 28:	learn: 1890.5178197	total: 4.61s	remaining: 3.34s
# 29:	learn: 1880.7367411	total: 4.76s	remaining: 3.17s
# 30:	learn: 1871.1323863	total: 4.91s	remaining: 3.01s
# 31:	learn: 1862.2397772	total: 5.07s	remaining: 2.85s
# 32:	learn: 1854.8113401	total: 5.22s	remaining: 2.69s
# 33:	learn: 1844.1385840	total: 5.37s	remaining: 2.53s
# 34:	learn: 1836.7181387	total: 5.53s	remaining: 2.37s
# 35:	learn: 1828.8494900	total: 5.68s	remaining: 2.21s
# 36:	learn: 1821.3921246	total: 5.84s	remaining: 2.05s
# 37:	learn: 1815.2129234	total: 6s	remaining: 1.89s
# 38:	learn: 1808.9176988	total: 6.15s	remaining: 1.73s
# 39:	learn: 1802.2643983	total: 6.3s	remaining: 1.57s
# 40:	learn: 1796.4312747	total: 6.45s	remaining: 1.42s
# 41:	learn: 1790.4710087	total: 6.61s	remaining: 1.26s
# 42:	learn: 1785.2479547	total: 6.77s	remaining: 1.1s
# 43:	learn: 1781.6476512	total: 6.92s	remaining: 944ms
# 44:	learn: 1777.8493921	total: 7.08s	remaining: 786ms
# 45:	learn: 1773.5704682	total: 7.23s	remaining: 629ms
# 46:	learn: 1769.8968535	total: 7.38s	remaining: 471ms
# 47:	learn: 1766.1491582	total: 7.54s	remaining: 314ms
# 48:	learn: 1762.5923790	total: 7.71s	remaining: 157ms
# 49:	learn: 1758.5344060	total: 7.88s	remaining: 0us
# 0:	learn: 4323.3500201	total: 175ms	remaining: 8.56s
# 1:	learn: 4035.9176567	total: 339ms	remaining: 8.13s
# 2:	learn: 3781.5252065	total: 503ms	remaining: 7.88s
# 3:	learn: 3555.3912082	total: 661ms	remaining: 7.6s
# 4:	learn: 3356.8104641	total: 820ms	remaining: 7.38s
# 5:	learn: 3177.7074221	total: 984ms	remaining: 7.22s
# 6:	learn: 3018.8348284	total: 1.15s	remaining: 7.04s
# 7:	learn: 2883.9725410	total: 1.31s	remaining: 6.88s
# 8:	learn: 2759.2573201	total: 1.48s	remaining: 6.72s
# 9:	learn: 2651.2527008	total: 1.63s	remaining: 6.52s
# 10:	learn: 2554.5845511	total: 1.78s	remaining: 6.33s
# 11:	learn: 2469.8284882	total: 1.94s	remaining: 6.14s
# 12:	learn: 2394.2031397	total: 2.09s	remaining: 5.96s
# 13:	learn: 2325.6523079	total: 2.24s	remaining: 5.77s
# 14:	learn: 2266.7946846	total: 2.4s	remaining: 5.6s
# 15:	learn: 2214.6600102	total: 2.57s	remaining: 5.46s
# 16:	learn: 2168.7646476	total: 2.73s	remaining: 5.3s
# 17:	learn: 2125.7418676	total: 2.89s	remaining: 5.13s
# 18:	learn: 2088.9975571	total: 3.05s	remaining: 4.97s
# 19:	learn: 2056.7965988	total: 3.19s	remaining: 4.78s
# 20:	learn: 2028.4894344	total: 3.34s	remaining: 4.61s
# 21:	learn: 2003.5450449	total: 3.5s	remaining: 4.45s
# 22:	learn: 1979.9414239	total: 3.65s	remaining: 4.29s
# 23:	learn: 1959.2992745	total: 3.81s	remaining: 4.13s
# 24:	learn: 1941.2405083	total: 3.96s	remaining: 3.96s
# 25:	learn: 1924.8804564	total: 4.12s	remaining: 3.8s
# 26:	learn: 1910.0779060	total: 4.28s	remaining: 3.64s
# 27:	learn: 1898.0322450	total: 4.44s	remaining: 3.49s
# 28:	learn: 1886.0073560	total: 4.59s	remaining: 3.32s
# 29:	learn: 1875.7066306	total: 4.74s	remaining: 3.16s
# 30:	learn: 1865.9219969	total: 4.9s	remaining: 3s
# 31:	learn: 1853.4736864	total: 5.06s	remaining: 2.84s
# 32:	learn: 1845.0287162	total: 5.21s	remaining: 2.69s
# 33:	learn: 1836.5620915	total: 5.37s	remaining: 2.52s
# 34:	learn: 1828.9932636	total: 5.52s	remaining: 2.37s
# 35:	learn: 1821.6931761	total: 5.67s	remaining: 2.21s
# 36:	learn: 1814.7587845	total: 5.83s	remaining: 2.05s
# 37:	learn: 1807.6045311	total: 5.98s	remaining: 1.89s
# 38:	learn: 1799.7197107	total: 6.14s	remaining: 1.73s
# 39:	learn: 1793.1102355	total: 6.3s	remaining: 1.58s
# 40:	learn: 1787.2760850	total: 6.46s	remaining: 1.42s
# 41:	learn: 1782.0440247	total: 6.62s	remaining: 1.26s
# 42:	learn: 1777.5936742	total: 6.78s	remaining: 1.1s
# 43:	learn: 1773.0315413	total: 6.94s	remaining: 946ms
# 44:	learn: 1769.3432528	total: 7.1s	remaining: 789ms
# 45:	learn: 1763.7094952	total: 7.24s	remaining: 630ms
# 46:	learn: 1759.4392596	total: 7.4s	remaining: 472ms
# 47:	learn: 1754.9994494	total: 7.55s	remaining: 315ms
# 48:	learn: 1751.4019560	total: 7.71s	remaining: 157ms
# 49:	learn: 1748.1981019	total: 7.86s	remaining: 0us
# 0:	learn: 4344.0740567	total: 183ms	remaining: 8.98s
# 1:	learn: 4056.4798444	total: 358ms	remaining: 8.6s
# 2:	learn: 3790.8112124	total: 520ms	remaining: 8.15s
# 3:	learn: 3560.7705590	total: 682ms	remaining: 7.85s
# 4:	learn: 3354.4742340	total: 842ms	remaining: 7.58s
# 5:	learn: 3174.3014075	total: 999ms	remaining: 7.33s
# 6:	learn: 3014.5854651	total: 1.16s	remaining: 7.14s
# 7:	learn: 2877.0747652	total: 1.33s	remaining: 7s
# 8:	learn: 2750.2908120	total: 1.5s	remaining: 6.82s
# 9:	learn: 2639.8087906	total: 1.66s	remaining: 6.63s
# 10:	learn: 2544.0279130	total: 1.81s	remaining: 6.42s
# 11:	learn: 2460.1218189	total: 1.97s	remaining: 6.23s
# 12:	learn: 2380.5927101	total: 2.13s	remaining: 6.06s
# 13:	learn: 2317.8813072	total: 2.28s	remaining: 5.87s
# 14:	learn: 2258.8923623	total: 2.45s	remaining: 5.71s
# 15:	learn: 2208.2195348	total: 2.6s	remaining: 5.53s
# 16:	learn: 2163.2195934	total: 2.77s	remaining: 5.37s
# 17:	learn: 2121.2910235	total: 2.93s	remaining: 5.21s
# 18:	learn: 2085.3607570	total: 3.08s	remaining: 5.03s
# 19:	learn: 2052.6316799	total: 3.25s	remaining: 4.88s
# 20:	learn: 2024.3384796	total: 3.42s	remaining: 4.73s
# 21:	learn: 1998.9786243	total: 3.58s	remaining: 4.56s
# 22:	learn: 1976.2038358	total: 3.74s	remaining: 4.39s
# 23:	learn: 1955.4011056	total: 3.88s	remaining: 4.21s
# 24:	learn: 1935.4785330	total: 4.04s	remaining: 4.04s
# 25:	learn: 1918.9593013	total: 4.2s	remaining: 3.88s
# 26:	learn: 1904.0882282	total: 4.36s	remaining: 3.71s
# 27:	learn: 1889.9192345	total: 4.52s	remaining: 3.55s
# 28:	learn: 1874.6133792	total: 4.67s	remaining: 3.38s
# 29:	learn: 1863.9451026	total: 4.84s	remaining: 3.23s
# 30:	learn: 1854.0203448	total: 5s	remaining: 3.06s
# 31:	learn: 1844.4989264	total: 5.17s	remaining: 2.91s
# 32:	learn: 1836.6628030	total: 5.33s	remaining: 2.75s
# 33:	learn: 1829.6392718	total: 5.49s	remaining: 2.58s
# 34:	learn: 1822.6251236	total: 5.65s	remaining: 2.42s
# 35:	learn: 1814.8955806	total: 5.8s	remaining: 2.26s
# 36:	learn: 1807.8585787	total: 5.96s	remaining: 2.09s
# 37:	learn: 1799.2740443	total: 6.12s	remaining: 1.93s
# 38:	learn: 1791.7271876	total: 6.29s	remaining: 1.77s
# 39:	learn: 1783.4110976	total: 6.45s	remaining: 1.61s
# 40:	learn: 1778.6216857	total: 6.61s	remaining: 1.45s
# 41:	learn: 1773.6845929	total: 6.78s	remaining: 1.29s
# 42:	learn: 1768.3468334	total: 6.95s	remaining: 1.13s
# 43:	learn: 1763.2993342	total: 7.11s	remaining: 970ms
# 44:	learn: 1759.5777496	total: 7.27s	remaining: 808ms
# 45:	learn: 1756.2448165	total: 7.42s	remaining: 645ms
# 46:	learn: 1751.5629768	total: 7.58s	remaining: 484ms
# 47:	learn: 1748.5263247	total: 7.74s	remaining: 322ms
# 48:	learn: 1743.8983679	total: 7.89s	remaining: 161ms
# 49:	learn: 1740.7240948	total: 8.05s	remaining: 0us
# 0:	learn: 3060.6439806	total: 226ms	remaining: 2.04s
# 1:	learn: 2352.4336263	total: 439ms	remaining: 1.76s
# 2:	learn: 2034.6720069	total: 640ms	remaining: 1.49s
# 3:	learn: 1892.7391829	total: 848ms	remaining: 1.27s
# 4:	learn: 1830.8013377	total: 1.03s	remaining: 1.03s
# 5:	learn: 1791.1906901	total: 1.24s	remaining: 825ms
# 6:	learn: 1765.6068802	total: 1.45s	remaining: 623ms
# 7:	learn: 1744.4806198	total: 1.68s	remaining: 421ms
# 8:	learn: 1724.4019335	total: 1.89s	remaining: 210ms
# 9:	learn: 1710.0607769	total: 2.09s	remaining: 0us
# 0:	learn: 3065.2491896	total: 225ms	remaining: 2.02s
# 1:	learn: 2362.9103792	total: 402ms	remaining: 1.61s
# 2:	learn: 2051.9483985	total: 633ms	remaining: 1.48s
# 3:	learn: 1913.4711751	total: 838ms	remaining: 1.26s
# 4:	learn: 1844.3096409	total: 1.03s	remaining: 1.03s
# 5:	learn: 1804.1934344	total: 1.24s	remaining: 826ms
# 6:	learn: 1778.1491018	total: 1.44s	remaining: 617ms
# 7:	learn: 1749.2836259	total: 1.64s	remaining: 409ms
# 8:	learn: 1716.3226677	total: 1.85s	remaining: 205ms
# 9:	learn: 1703.2513215	total: 2.05s	remaining: 0us
# 0:	learn: 3080.0102944	total: 228ms	remaining: 2.05s
# 1:	learn: 2354.0926999	total: 449ms	remaining: 1.8s
# 2:	learn: 2045.9225238	total: 660ms	remaining: 1.54s
# 3:	learn: 1885.5951345	total: 861ms	remaining: 1.29s
# 4:	learn: 1823.3966618	total: 1.05s	remaining: 1.05s
# 5:	learn: 1777.8056284	total: 1.25s	remaining: 832ms
# 6:	learn: 1743.3099571	total: 1.46s	remaining: 626ms
# 7:	learn: 1718.4921092	total: 1.67s	remaining: 416ms
# 8:	learn: 1702.0269041	total: 1.86s	remaining: 207ms
# 9:	learn: 1682.9349308	total: 2.06s	remaining: 0us
# 0:	learn: 4311.7232108	total: 226ms	remaining: 2.03s
# 1:	learn: 4004.2015560	total: 435ms	remaining: 1.74s
# 2:	learn: 3731.7333632	total: 640ms	remaining: 1.49s
# 3:	learn: 3491.0833685	total: 842ms	remaining: 1.26s
# 4:	learn: 3280.6586847	total: 1.03s	remaining: 1.03s
# 5:	learn: 3086.2147919	total: 1.24s	remaining: 824ms
# 6:	learn: 2919.7371204	total: 1.43s	remaining: 614ms
# 7:	learn: 2777.6583764	total: 1.62s	remaining: 405ms
# 8:	learn: 2644.7774576	total: 1.82s	remaining: 203ms
# 9:	learn: 2532.2449488	total: 2.03s	remaining: 0us
# 0:	learn: 4305.8444853	total: 223ms	remaining: 2s
# 1:	learn: 3999.3826376	total: 436ms	remaining: 1.74s
# 2:	learn: 3730.1675338	total: 634ms	remaining: 1.48s
# 3:	learn: 3489.4600077	total: 833ms	remaining: 1.25s
# 4:	learn: 3277.2928066	total: 1.03s	remaining: 1.03s
# 5:	learn: 3094.5828837	total: 1.25s	remaining: 832ms
# 6:	learn: 2927.3227784	total: 1.44s	remaining: 619ms
# 7:	learn: 2780.7744773	total: 1.64s	remaining: 409ms
# 8:	learn: 2650.1737873	total: 1.82s	remaining: 202ms
# 9:	learn: 2538.1810277	total: 2.02s	remaining: 0us
# 0:	learn: 4323.6445211	total: 224ms	remaining: 2.02s
# 1:	learn: 4014.2674091	total: 432ms	remaining: 1.73s
# 2:	learn: 3743.2202324	total: 640ms	remaining: 1.49s
# 3:	learn: 3501.0465222	total: 827ms	remaining: 1.24s
# 4:	learn: 3288.2386738	total: 1.03s	remaining: 1.03s
# 5:	learn: 3096.3741482	total: 1.23s	remaining: 823ms
# 6:	learn: 2929.2513179	total: 1.44s	remaining: 616ms
# 7:	learn: 2779.6532452	total: 1.64s	remaining: 411ms
# 8:	learn: 2645.7084707	total: 1.84s	remaining: 205ms
# 9:	learn: 2528.8665320	total: 2.05s	remaining: 0us
# 0:	learn: 3063.7619815	total: 234ms	remaining: 2.1s
# 1:	learn: 2355.6093025	total: 444ms	remaining: 1.77s
# 2:	learn: 2037.5888994	total: 647ms	remaining: 1.51s
# 3:	learn: 1895.3197615	total: 853ms	remaining: 1.28s
# 4:	learn: 1833.6729403	total: 1.05s	remaining: 1.05s
# 5:	learn: 1794.9034962	total: 1.26s	remaining: 838ms
# 6:	learn: 1764.6251917	total: 1.46s	remaining: 625ms
# 7:	learn: 1748.5687328	total: 1.68s	remaining: 419ms
# 8:	learn: 1725.2606419	total: 1.89s	remaining: 210ms
# 9:	learn: 1705.4506354	total: 2.08s	remaining: 0us
# 0:	learn: 3068.0945499	total: 228ms	remaining: 2.05s
# 1:	learn: 2365.3060571	total: 432ms	remaining: 1.73s
# 2:	learn: 2054.8254343	total: 629ms	remaining: 1.47s
# 3:	learn: 1916.2560681	total: 847ms	remaining: 1.27s
# 4:	learn: 1847.2419277	total: 1.05s	remaining: 1.05s
# 5:	learn: 1807.6701232	total: 1.25s	remaining: 837ms
# 6:	learn: 1767.6681123	total: 1.46s	remaining: 627ms
# 7:	learn: 1749.2524196	total: 1.66s	remaining: 416ms
# 8:	learn: 1730.1053104	total: 1.88s	remaining: 209ms
# 9:	learn: 1716.3342213	total: 2.09s	remaining: 0us
# 0:	learn: 3082.0994051	total: 227ms	remaining: 2.04s
# 1:	learn: 2356.3293547	total: 436ms	remaining: 1.74s
# 2:	learn: 2048.7209603	total: 631ms	remaining: 1.47s
# 3:	learn: 1888.4341661	total: 849ms	remaining: 1.27s
# 4:	learn: 1825.9369858	total: 1.05s	remaining: 1.05s
# 5:	learn: 1780.6966605	total: 1.27s	remaining: 846ms
# 6:	learn: 1746.6140027	total: 1.48s	remaining: 633ms
# 7:	learn: 1721.8687472	total: 1.68s	remaining: 419ms
# 8:	learn: 1705.2272343	total: 1.87s	remaining: 208ms
# 9:	learn: 1687.3201352	total: 2.09s	remaining: 0us
# 0:	learn: 4312.4830077	total: 227ms	remaining: 2.04s
# 1:	learn: 4005.6167739	total: 435ms	remaining: 1.74s
# 2:	learn: 3733.6242796	total: 636ms	remaining: 1.49s
# 3:	learn: 3493.4086698	total: 839ms	remaining: 1.26s
# 4:	learn: 3283.1906226	total: 1.05s	remaining: 1.05s
# 5:	learn: 3090.0263470	total: 1.24s	remaining: 826ms
# 6:	learn: 2923.6483874	total: 1.42s	remaining: 611ms
# 7:	learn: 2777.9393720	total: 1.6s	remaining: 401ms
# 8:	learn: 2647.5623423	total: 1.82s	remaining: 203ms
# 9:	learn: 2531.8267858	total: 2.02s	remaining: 0us
# 0:	learn: 4306.5551823	total: 261ms	remaining: 2.35s
# 1:	learn: 4000.7660240	total: 470ms	remaining: 1.88s
# 2:	learn: 3731.9380340	total: 682ms	remaining: 1.59s
# 3:	learn: 3491.5085305	total: 887ms	remaining: 1.33s
# 4:	learn: 3279.5922440	total: 1.09s	remaining: 1.09s
# 5:	learn: 3097.0948172	total: 1.29s	remaining: 857ms
# 6:	learn: 2929.9111173	total: 1.49s	remaining: 639ms
# 7:	learn: 2783.4774746	total: 1.69s	remaining: 422ms
# 8:	learn: 2652.9481953	total: 1.89s	remaining: 210ms
# 9:	learn: 2540.9351524	total: 2.1s	remaining: 0us
# 0:	learn: 4324.1667172	total: 229ms	remaining: 2.06s
# 1:	learn: 4015.2535381	total: 449ms	remaining: 1.79s
# 2:	learn: 3743.9299620	total: 654ms	remaining: 1.53s
# 3:	learn: 3502.3138547	total: 863ms	remaining: 1.29s
# 4:	learn: 3289.2565597	total: 1.03s	remaining: 1.03s
# 5:	learn: 3102.6785463	total: 1.27s	remaining: 847ms
# 6:	learn: 2936.5267111	total: 1.47s	remaining: 632ms
# 7:	learn: 2782.6939729	total: 1.69s	remaining: 421ms
# 8:	learn: 2647.5079343	total: 1.89s	remaining: 211ms
# 9:	learn: 2532.3151863	total: 2.11s	remaining: 0us
# 0:	learn: 3060.6439806	total: 239ms	remaining: 11.7s
# 1:	learn: 2352.4336263	total: 454ms	remaining: 10.9s
# 2:	learn: 2034.6720069	total: 661ms	remaining: 10.4s
# 3:	learn: 1892.7391829	total: 870ms	remaining: 10s
# 4:	learn: 1830.8013377	total: 1.07s	remaining: 9.66s
# 5:	learn: 1791.1906901	total: 1.27s	remaining: 9.32s
# 6:	learn: 1765.6068802	total: 1.48s	remaining: 9.11s
# 7:	learn: 1744.4806198	total: 1.68s	remaining: 8.84s
# 8:	learn: 1724.4019335	total: 1.89s	remaining: 8.61s
# 9:	learn: 1710.0607769	total: 2.09s	remaining: 8.38s
# 10:	learn: 1697.2783492	total: 2.29s	remaining: 8.13s
# 11:	learn: 1680.9424951	total: 2.48s	remaining: 7.87s
# 12:	learn: 1671.6333515	total: 2.68s	remaining: 7.64s
# 13:	learn: 1658.1391310	total: 2.88s	remaining: 7.42s
# 14:	learn: 1648.4577676	total: 3.09s	remaining: 7.22s
# 15:	learn: 1639.0428013	total: 3.29s	remaining: 7s
# 16:	learn: 1634.6924178	total: 3.5s	remaining: 6.8s
# 17:	learn: 1625.0775528	total: 3.69s	remaining: 6.55s
# 18:	learn: 1621.0823884	total: 3.88s	remaining: 6.33s
# 19:	learn: 1615.0883887	total: 4.08s	remaining: 6.13s
# 20:	learn: 1608.8525344	total: 4.29s	remaining: 5.93s
# 21:	learn: 1602.3965814	total: 4.5s	remaining: 5.72s
# 22:	learn: 1597.2582100	total: 4.69s	remaining: 5.51s
# 23:	learn: 1588.5027676	total: 4.92s	remaining: 5.32s
# 24:	learn: 1585.0092792	total: 5.12s	remaining: 5.12s
# 25:	learn: 1581.0030454	total: 5.32s	remaining: 4.91s
# 26:	learn: 1571.6426759	total: 5.52s	remaining: 4.7s
# 27:	learn: 1568.9136971	total: 5.72s	remaining: 4.49s
# 28:	learn: 1563.9594112	total: 5.91s	remaining: 4.28s
# 29:	learn: 1559.7193084	total: 6.12s	remaining: 4.08s
# 30:	learn: 1556.2277789	total: 6.34s	remaining: 3.89s
# 31:	learn: 1552.8207059	total: 6.53s	remaining: 3.67s
# 32:	learn: 1549.1803941	total: 6.74s	remaining: 3.47s
# 33:	learn: 1546.4485698	total: 6.91s	remaining: 3.25s
# 34:	learn: 1543.3140863	total: 7.1s	remaining: 3.04s
# 35:	learn: 1536.8725708	total: 7.3s	remaining: 2.84s
# 36:	learn: 1532.7257453	total: 7.5s	remaining: 2.63s
# 37:	learn: 1531.2819232	total: 7.69s	remaining: 2.43s
# 38:	learn: 1529.1682473	total: 7.89s	remaining: 2.23s
# 39:	learn: 1526.8727504	total: 8.1s	remaining: 2.02s
# 40:	learn: 1523.9846118	total: 8.28s	remaining: 1.82s
# 41:	learn: 1521.7515211	total: 8.48s	remaining: 1.62s
# 42:	learn: 1516.7327056	total: 8.67s	remaining: 1.41s
# 43:	learn: 1515.0968473	total: 8.87s	remaining: 1.21s
# 44:	learn: 1512.3735099	total: 9.08s	remaining: 1.01s
# 45:	learn: 1510.6340441	total: 9.28s	remaining: 807ms
# 46:	learn: 1508.2654028	total: 9.48s	remaining: 605ms
# 47:	learn: 1506.0541735	total: 9.67s	remaining: 403ms
# 48:	learn: 1503.1135079	total: 9.87s	remaining: 202ms
# 49:	learn: 1499.7684669	total: 10.1s	remaining: 0us
# 0:	learn: 3065.2491896	total: 230ms	remaining: 11.3s
# 1:	learn: 2362.9103792	total: 445ms	remaining: 10.7s
# 2:	learn: 2051.9483985	total: 651ms	remaining: 10.2s
# 3:	learn: 1913.4711751	total: 857ms	remaining: 9.86s
# 4:	learn: 1844.3096409	total: 1.07s	remaining: 9.6s
# 5:	learn: 1804.1934344	total: 1.27s	remaining: 9.34s
# 6:	learn: 1778.1491018	total: 1.5s	remaining: 9.19s
# 7:	learn: 1749.2836259	total: 1.7s	remaining: 8.92s
# 8:	learn: 1716.3226677	total: 1.91s	remaining: 8.68s
# 9:	learn: 1703.2513215	total: 2.11s	remaining: 8.44s
# ...
# 2:	learn: 1973.5504344	total: 875ms	remaining: 13.7s
# 3:	learn: 1825.9298554	total: 1.16s	remaining: 13.3s
# 4:	learn: 1753.3066220	total: 1.44s	remaining: 12.9s
# 5:	learn: 1712.5266499	total: 1.71s	remaining: 12.5s
# 6:	learn: 1679.7957314	total: 1.99s	remaining: 12.2s
# 7:	learn: 1651.3301098	total: 2.26s	remaining: 11.9s
# 8:	learn: 1638.4678887	total: 2.54s	remaining: 11.6s
# 9:	learn: 1623.3183327	total: 2.82s	remaining: 11.3s
# 10:	learn: 1611.1630938	total: 3.07s	remaining: 10.9s
# 11:	learn: 1601.5800683	total: 3.33s	remaining: 10.5s
# 12:	learn: 1586.9117964	total: 3.6s	remaining: 10.3s
# 13:	learn: 1577.1794754	total: 3.88s	remaining: 9.97s
# 14:	learn: 1570.1906860	total: 4.15s	remaining: 9.69s
# 15:	learn: 1560.0749885	total: 4.43s	remaining: 9.4s
# 16:	learn: 1553.2070924	total: 4.7s	remaining: 9.12s
# 17:	learn: 1547.0022912	total: 4.98s	remaining: 8.85s
# 18:	learn: 1538.4198971	total: 5.24s	remaining: 8.55s
# 19:	learn: 1533.6163784	total: 5.51s	remaining: 8.27s
# 20:	learn: 1525.6591748	total: 5.78s	remaining: 7.99s
# 21:	learn: 1519.1043622	total: 6.04s	remaining: 7.68s
# 22:	learn: 1514.5465302	total: 6.3s	remaining: 7.4s
# 23:	learn: 1507.9747816	total: 6.56s	remaining: 7.11s
# 24:	learn: 1502.9113842	total: 6.84s	remaining: 6.84s
# 25:	learn: 1498.9307431	total: 7.12s	remaining: 6.57s
# 26:	learn: 1496.3146993	total: 7.38s	remaining: 6.29s
# 27:	learn: 1492.8424556	total: 7.66s	remaining: 6.02s
# 28:	learn: 1487.9465264	total: 7.93s	remaining: 5.74s
# 29:	learn: 1484.9192653	total: 8.2s	remaining: 5.46s
# 30:	learn: 1478.2232291	total: 8.43s	remaining: 5.17s
# 31:	learn: 1473.6763113	total: 8.71s	remaining: 4.9s
# 32:	learn: 1469.6564568	total: 8.97s	remaining: 4.62s
# 33:	learn: 1466.4565753	total: 9.26s	remaining: 4.36s
# 34:	learn: 1464.2708634	total: 9.52s	remaining: 4.08s
# 35:	learn: 1461.5815214	total: 9.77s	remaining: 3.8s
# 36:	learn: 1457.2168282	total: 10s	remaining: 3.53s
# 37:	learn: 1455.5120663	total: 10.3s	remaining: 3.26s
# 38:	learn: 1450.8061338	total: 10.6s	remaining: 2.99s
# 39:	learn: 1448.6863562	total: 10.9s	remaining: 2.71s
# 40:	learn: 1444.8248130	total: 11.1s	remaining: 2.44s
# 41:	learn: 1442.7130209	total: 11.4s	remaining: 2.17s
# 42:	learn: 1438.4125096	total: 11.7s	remaining: 1.9s
# 43:	learn: 1435.9315276	total: 11.9s	remaining: 1.63s
# 44:	learn: 1433.7955340	total: 12.2s	remaining: 1.36s
# 45:	learn: 1432.0628683	total: 12.5s	remaining: 1.08s
# 46:	learn: 1428.0357398	total: 12.8s	remaining: 815ms
# 47:	learn: 1426.3359756	total: 13s	remaining: 544ms
# 48:	learn: 1425.1418367	total: 13.3s	remaining: 271ms
# 49:	learn: 1419.7658021	total: 13.6s	remaining: 0us
# 0:	learn: 3007.7681419	total: 289ms	remaining: 14.2s
# 1:	learn: 2282.4905834	total: 552ms	remaining: 13.2s
# 2:	learn: 1942.2778702	total: 800ms	remaining: 12.5s
# 3:	learn: 1809.7924746	total: 1.07s	remaining: 12.3s
# 4:	learn: 1737.6465926	total: 1.33s	remaining: 12s
# 5:	learn: 1696.9047812	total: 1.61s	remaining: 11.8s
# 6:	learn: 1661.2149317	total: 1.88s	remaining: 11.6s
# 7:	learn: 1636.4705348	total: 2.15s	remaining: 11.3s
# 8:	learn: 1621.4234716	total: 2.43s	remaining: 11.1s
# 9:	learn: 1600.9031159	total: 2.64s	remaining: 10.5s
# 10:	learn: 1589.0435181	total: 2.9s	remaining: 10.3s
# 11:	learn: 1579.5408159	total: 3.18s	remaining: 10.1s
# 12:	learn: 1573.0242864	total: 3.45s	remaining: 9.83s
# 13:	learn: 1565.4625407	total: 3.72s	remaining: 9.57s
# 14:	learn: 1556.0158674	total: 3.98s	remaining: 9.29s
# 15:	learn: 1549.6929434	total: 4.24s	remaining: 9.01s
# 16:	learn: 1540.6737135	total: 4.48s	remaining: 8.7s
# 17:	learn: 1535.8456397	total: 4.74s	remaining: 8.43s
# 18:	learn: 1528.9070373	total: 5.02s	remaining: 8.2s
# 19:	learn: 1524.8463515	total: 5.3s	remaining: 7.96s
# 20:	learn: 1519.9417289	total: 5.58s	remaining: 7.71s
# 21:	learn: 1512.9793284	total: 5.85s	remaining: 7.45s
# 22:	learn: 1507.8551336	total: 6.12s	remaining: 7.19s
# 23:	learn: 1500.6377340	total: 6.38s	remaining: 6.91s
# 24:	learn: 1497.6117874	total: 6.66s	remaining: 6.66s
# 25:	learn: 1497.6117684	total: 6.72s	remaining: 6.2s
# 26:	learn: 1488.0317354	total: 6.95s	remaining: 5.92s
# 27:	learn: 1483.6831346	total: 7.23s	remaining: 5.68s
# 28:	learn: 1478.6919566	total: 7.51s	remaining: 5.44s
# 29:	learn: 1473.2747194	total: 7.78s	remaining: 5.19s
# 30:	learn: 1468.0950869	total: 8.06s	remaining: 4.94s
# 31:	learn: 1465.6018964	total: 8.36s	remaining: 4.7s
# 32:	learn: 1461.4323206	total: 8.63s	remaining: 4.45s
# 33:	learn: 1459.1658009	total: 8.91s	remaining: 4.19s
# 34:	learn: 1458.9322701	total: 9.14s	remaining: 3.92s
# 35:	learn: 1456.4386119	total: 9.43s	remaining: 3.67s
# 36:	learn: 1451.6208600	total: 9.68s	remaining: 3.4s
# 37:	learn: 1448.1559556	total: 9.98s	remaining: 3.15s
# 38:	learn: 1445.4104445	total: 10.3s	remaining: 2.89s
# 39:	learn: 1441.1331180	total: 10.5s	remaining: 2.63s
# 40:	learn: 1438.4751630	total: 10.8s	remaining: 2.37s
# 41:	learn: 1435.5847044	total: 11.1s	remaining: 2.11s
# 42:	learn: 1432.2629982	total: 11.4s	remaining: 1.85s
# 43:	learn: 1430.0889179	total: 11.6s	remaining: 1.59s
# 44:	learn: 1427.0995455	total: 11.9s	remaining: 1.32s
# 45:	learn: 1424.9569900	total: 12.1s	remaining: 1.05s
# 46:	learn: 1422.4052710	total: 12.4s	remaining: 793ms
# 47:	learn: 1420.3282470	total: 12.7s	remaining: 529ms
# 48:	learn: 1419.0789139	total: 13s	remaining: 265ms
# 49:	learn: 1416.3178150	total: 13.2s	remaining: 0us
# 0:	learn: 4309.5706483	total: 288ms	remaining: 14.1s
# 1:	learn: 3991.4941424	total: 582ms	remaining: 14s
# 2:	learn: 3710.4416268	total: 850ms	remaining: 13.3s
# 3:	learn: 3462.8210324	total: 1.15s	remaining: 13.2s
# 4:	learn: 3249.7234114	total: 1.4s	remaining: 12.6s
# 5:	learn: 3052.7949188	total: 1.68s	remaining: 12.3s
# 6:	learn: 2880.8192144	total: 1.95s	remaining: 12s
# 7:	learn: 2727.5392463	total: 2.22s	remaining: 11.7s
# 8:	learn: 2596.3098151	total: 2.5s	remaining: 11.4s
# 9:	learn: 2481.3662932	total: 2.78s	remaining: 11.1s
# 10:	learn: 2378.3502573	total: 3.04s	remaining: 10.8s
# 11:	learn: 2290.0350079	total: 3.3s	remaining: 10.5s
# 12:	learn: 2211.4458368	total: 3.58s	remaining: 10.2s
# 13:	learn: 2143.9189076	total: 3.86s	remaining: 9.92s
# 14:	learn: 2083.2965563	total: 4.13s	remaining: 9.64s
# 15:	learn: 2031.0431673	total: 4.41s	remaining: 9.37s
# 16:	learn: 1985.5613406	total: 4.68s	remaining: 9.09s
# 17:	learn: 1948.1115779	total: 4.97s	remaining: 8.83s
# 18:	learn: 1913.7639520	total: 5.24s	remaining: 8.54s
# 19:	learn: 1884.2984377	total: 5.5s	remaining: 8.26s
# 20:	learn: 1858.6415807	total: 5.78s	remaining: 7.99s
# 21:	learn: 1834.7788398	total: 6.05s	remaining: 7.7s
# 22:	learn: 1814.5316337	total: 6.29s	remaining: 7.39s
# 23:	learn: 1797.8336090	total: 6.57s	remaining: 7.12s
# 24:	learn: 1779.0939093	total: 6.84s	remaining: 6.84s
# 25:	learn: 1764.7639153	total: 7.08s	remaining: 6.54s
# 26:	learn: 1751.7523541	total: 7.35s	remaining: 6.26s
# 27:	learn: 1739.9993841	total: 7.62s	remaining: 5.99s
# 28:	learn: 1726.3466874	total: 7.88s	remaining: 5.7s
# 29:	learn: 1717.3651182	total: 8.12s	remaining: 5.41s
# 30:	learn: 1708.4487957	total: 8.4s	remaining: 5.15s
# 31:	learn: 1698.0988912	total: 8.67s	remaining: 4.88s
# 32:	learn: 1690.3873582	total: 8.95s	remaining: 4.61s
# 33:	learn: 1680.9229554	total: 9.2s	remaining: 4.33s
# 34:	learn: 1674.1365552	total: 9.47s	remaining: 4.06s
# 35:	learn: 1668.0038010	total: 9.75s	remaining: 3.79s
# 36:	learn: 1661.2203815	total: 10s	remaining: 3.52s
# 37:	learn: 1653.0739884	total: 10.3s	remaining: 3.25s
# 38:	learn: 1646.3819284	total: 10.6s	remaining: 2.98s
# 39:	learn: 1642.2726037	total: 10.8s	remaining: 2.71s
# 40:	learn: 1637.3389329	total: 11.1s	remaining: 2.44s
# 41:	learn: 1634.0027283	total: 11.4s	remaining: 2.17s
# 42:	learn: 1630.3306508	total: 11.7s	remaining: 1.9s
# 43:	learn: 1623.5953905	total: 12s	remaining: 1.63s
# 44:	learn: 1618.9786676	total: 12.3s	remaining: 1.36s
# 45:	learn: 1616.3791022	total: 12.5s	remaining: 1.09s
# 46:	learn: 1613.5948417	total: 12.8s	remaining: 817ms
# 47:	learn: 1611.1008192	total: 13.1s	remaining: 545ms
# 48:	learn: 1608.7896925	total: 13.3s	remaining: 272ms
# 49:	learn: 1604.9631506	total: 13.6s	remaining: 0us
# 0:	learn: 4303.6018919	total: 275ms	remaining: 13.5s
# 1:	learn: 3986.9333856	total: 558ms	remaining: 13.4s
# 2:	learn: 3706.0647496	total: 836ms	remaining: 13.1s
# 3:	learn: 3457.0300965	total: 1.11s	remaining: 12.8s
# 4:	learn: 3233.7591687	total: 1.38s	remaining: 12.4s
# 5:	learn: 3041.9527257	total: 1.65s	remaining: 12.1s
# 6:	learn: 2870.1543435	total: 1.91s	remaining: 11.7s
# 7:	learn: 2720.2290288	total: 2.18s	remaining: 11.4s
# 8:	learn: 2587.1372008	total: 2.4s	remaining: 10.9s
# 9:	learn: 2469.6562728	total: 2.68s	remaining: 10.7s
# 10:	learn: 2363.9226607	total: 2.97s	remaining: 10.5s
# 11:	learn: 2272.6696297	total: 3.25s	remaining: 10.3s
# 12:	learn: 2194.1045426	total: 3.51s	remaining: 10s
# 13:	learn: 2125.0528053	total: 3.79s	remaining: 9.74s
# 14:	learn: 2066.2753812	total: 4.08s	remaining: 9.51s
# 15:	learn: 2013.0594274	total: 4.32s	remaining: 9.17s
# 16:	learn: 1966.6404847	total: 4.58s	remaining: 8.88s
# 17:	learn: 1929.5647882	total: 4.85s	remaining: 8.62s
# 18:	learn: 1896.3133050	total: 5.13s	remaining: 8.38s
# 19:	learn: 1867.0935446	total: 5.41s	remaining: 8.11s
# 20:	learn: 1841.2564965	total: 5.66s	remaining: 7.82s
# 21:	learn: 1815.4061790	total: 5.92s	remaining: 7.54s
# 22:	learn: 1795.5468537	total: 6.2s	remaining: 7.27s
# 23:	learn: 1774.3684936	total: 6.47s	remaining: 7.01s
# 24:	learn: 1757.8450608	total: 6.75s	remaining: 6.75s
# 25:	learn: 1743.3735251	total: 7.02s	remaining: 6.48s
# 26:	learn: 1730.6149045	total: 7.27s	remaining: 6.19s
# 27:	learn: 1718.0184886	total: 7.55s	remaining: 5.93s
# 28:	learn: 1707.9999793	total: 7.79s	remaining: 5.64s
# 29:	learn: 1698.9224408	total: 8.07s	remaining: 5.38s
# 30:	learn: 1690.5703362	total: 8.35s	remaining: 5.12s
# 31:	learn: 1683.3048433	total: 8.62s	remaining: 4.85s
# 32:	learn: 1674.9940321	total: 8.89s	remaining: 4.58s
# 33:	learn: 1669.7637281	total: 9.18s	remaining: 4.32s
# 34:	learn: 1661.7805527	total: 9.47s	remaining: 4.06s
# 35:	learn: 1654.3198791	total: 9.74s	remaining: 3.79s
# 36:	learn: 1647.9508752	total: 10s	remaining: 3.52s
# 37:	learn: 1640.6711323	total: 10.3s	remaining: 3.25s
# 38:	learn: 1635.0305463	total: 10.6s	remaining: 2.98s
# 39:	learn: 1630.3335968	total: 10.8s	remaining: 2.71s
# 40:	learn: 1625.9385194	total: 11.1s	remaining: 2.43s
# 41:	learn: 1620.0953133	total: 11.4s	remaining: 2.16s
# 42:	learn: 1616.8502946	total: 11.6s	remaining: 1.89s
# 43:	learn: 1610.9728712	total: 11.9s	remaining: 1.63s
# 44:	learn: 1607.3401772	total: 12.2s	remaining: 1.35s
# 45:	learn: 1604.0849014	total: 12.5s	remaining: 1.08s
# 46:	learn: 1599.4062216	total: 12.7s	remaining: 812ms
# 47:	learn: 1596.4902703	total: 13s	remaining: 542ms
# 48:	learn: 1593.6352819	total: 13.2s	remaining: 270ms
# 49:	learn: 1590.4964880	total: 13.5s	remaining: 0us
# 0:	learn: 4311.4160395	total: 279ms	remaining: 13.7s
# 1:	learn: 3994.1494147	total: 549ms	remaining: 13.2s
# 2:	learn: 3710.6393612	total: 837ms	remaining: 13.1s
# 3:	learn: 3462.6026427	total: 1.11s	remaining: 12.8s
# 4:	learn: 3237.2510050	total: 1.36s	remaining: 12.3s
# 5:	learn: 3042.9299282	total: 1.64s	remaining: 12s
# 6:	learn: 2868.4600974	total: 1.92s	remaining: 11.8s
# 7:	learn: 2718.0183936	total: 2.19s	remaining: 11.5s
# 8:	learn: 2585.8955392	total: 2.46s	remaining: 11.2s
# 9:	learn: 2466.4355658	total: 2.71s	remaining: 10.8s
# 10:	learn: 2363.3587252	total: 2.98s	remaining: 10.6s
# 11:	learn: 2273.9386641	total: 3.23s	remaining: 10.2s
# 12:	learn: 2193.7498273	total: 3.48s	remaining: 9.9s
# 13:	learn: 2126.4274909	total: 3.74s	remaining: 9.61s
# 14:	learn: 2069.8820142	total: 4.02s	remaining: 9.37s
# 15:	learn: 2019.7267476	total: 4.29s	remaining: 9.12s
# 16:	learn: 1970.2550450	total: 4.56s	remaining: 8.85s
# 17:	learn: 1929.3134842	total: 4.83s	remaining: 8.58s
# 18:	learn: 1894.4615241	total: 5.05s	remaining: 8.24s
# 19:	learn: 1864.3425510	total: 5.32s	remaining: 7.97s
# 20:	learn: 1836.4728970	total: 5.58s	remaining: 7.7s
# 21:	learn: 1810.0408446	total: 5.86s	remaining: 7.46s
# 22:	learn: 1787.9738458	total: 6.13s	remaining: 7.2s
# 23:	learn: 1769.4764594	total: 6.39s	remaining: 6.92s
# 24:	learn: 1754.3299698	total: 6.66s	remaining: 6.66s
# 25:	learn: 1739.0497615	total: 6.88s	remaining: 6.35s
# 26:	learn: 1726.4939270	total: 7.13s	remaining: 6.07s
# 27:	learn: 1714.8571143	total: 7.33s	remaining: 5.76s
# 28:	learn: 1705.1495300	total: 7.62s	remaining: 5.52s
# 29:	learn: 1697.2852566	total: 7.89s	remaining: 5.26s
# 30:	learn: 1687.5165798	total: 8.17s	remaining: 5.01s
# 31:	learn: 1677.7291116	total: 8.44s	remaining: 4.75s
# 32:	learn: 1670.8720937	total: 8.72s	remaining: 4.49s
# 33:	learn: 1663.5142617	total: 9s	remaining: 4.23s
# 34:	learn: 1655.4728018	total: 9.3s	remaining: 3.98s
# 35:	learn: 1647.6573740	total: 9.56s	remaining: 3.72s
# 36:	learn: 1641.6193244	total: 9.84s	remaining: 3.46s
# 37:	learn: 1634.7021852	total: 10.1s	remaining: 3.19s
# 38:	learn: 1625.8304448	total: 10.4s	remaining: 2.93s
# 39:	learn: 1621.2978844	total: 10.7s	remaining: 2.67s
# 40:	learn: 1615.5377679	total: 10.9s	remaining: 2.4s
# 41:	learn: 1611.7050650	total: 11.2s	remaining: 2.14s
# 42:	learn: 1608.0481638	total: 11.5s	remaining: 1.87s
# 43:	learn: 1605.0261112	total: 11.8s	remaining: 1.6s
# 44:	learn: 1601.7029689	total: 12s	remaining: 1.34s
# 45:	learn: 1598.0199014	total: 12.3s	remaining: 1.07s
# 46:	learn: 1593.8367126	total: 12.6s	remaining: 803ms
# 47:	learn: 1590.0795168	total: 12.8s	remaining: 534ms
# 48:	learn: 1587.1672851	total: 13.1s	remaining: 267ms
# 49:	learn: 1583.6828635	total: 13.3s	remaining: 0us
# 0:	learn: 3014.0255569	total: 442ms	remaining: 21.7s
# 1:	learn: 2275.5552538	total: 881ms	remaining: 21.1s
# 2:	learn: 1947.7892942	total: 1.3s	remaining: 20.3s
# 3:	learn: 1817.7779943	total: 1.64s	remaining: 18.8s
# 4:	learn: 1758.2782710	total: 2.03s	remaining: 18.3s
# 5:	learn: 1706.9228014	total: 2.42s	remaining: 17.8s
# 6:	learn: 1676.7200031	total: 2.83s	remaining: 17.4s
# 7:	learn: 1654.8136081	total: 3.19s	remaining: 16.7s
# 8:	learn: 1632.8117955	total: 3.58s	remaining: 16.3s
# 9:	learn: 1622.7491596	total: 3.98s	remaining: 15.9s
# 10:	learn: 1602.5335847	total: 4.38s	remaining: 15.5s
# 11:	learn: 1594.0452358	total: 4.76s	remaining: 15.1s
# 12:	learn: 1582.4901623	total: 5.17s	remaining: 14.7s
# 13:	learn: 1566.8558039	total: 5.58s	remaining: 14.3s
# 14:	learn: 1557.8485646	total: 5.97s	remaining: 13.9s
# 15:	learn: 1548.5326875	total: 6.37s	remaining: 13.5s
# 16:	learn: 1541.7870407	total: 6.76s	remaining: 13.1s
# 17:	learn: 1535.1642950	total: 7.17s	remaining: 12.8s
# 18:	learn: 1528.5878985	total: 7.57s	remaining: 12.3s
# 19:	learn: 1523.1268583	total: 7.98s	remaining: 12s
# 20:	learn: 1516.3515948	total: 8.4s	remaining: 11.6s
# 21:	learn: 1509.8246024	total: 8.77s	remaining: 11.2s
# 22:	learn: 1507.0455007	total: 9.13s	remaining: 10.7s
# 23:	learn: 1504.7602114	total: 9.53s	remaining: 10.3s
# 24:	learn: 1501.2346069	total: 9.92s	remaining: 9.92s
# 25:	learn: 1496.8936521	total: 10.3s	remaining: 9.47s
# 26:	learn: 1492.2760338	total: 10.6s	remaining: 9.06s
# 27:	learn: 1487.7320551	total: 11s	remaining: 8.65s
# 28:	learn: 1484.2741151	total: 11.4s	remaining: 8.26s
# 29:	learn: 1479.3485879	total: 11.8s	remaining: 7.87s
# 30:	learn: 1474.7653949	total: 12.2s	remaining: 7.46s
# 31:	learn: 1469.1863031	total: 12.5s	remaining: 7.04s
# 32:	learn: 1465.8375099	total: 12.9s	remaining: 6.66s
# 33:	learn: 1462.1999477	total: 13.3s	remaining: 6.26s
# 34:	learn: 1459.0969628	total: 13.7s	remaining: 5.86s
# 35:	learn: 1453.7510727	total: 14.1s	remaining: 5.47s
# 36:	learn: 1450.9816324	total: 14.4s	remaining: 5.08s
# 37:	learn: 1447.8986320	total: 14.8s	remaining: 4.68s
# 38:	learn: 1444.3123548	total: 15.3s	remaining: 4.3s
# 39:	learn: 1441.3728040	total: 15.6s	remaining: 3.9s
# 40:	learn: 1436.6076824	total: 15.9s	remaining: 3.5s
# 41:	learn: 1433.6409200	total: 16.3s	remaining: 3.11s
# 42:	learn: 1431.6400282	total: 16.7s	remaining: 2.72s
# 43:	learn: 1429.3785713	total: 17.1s	remaining: 2.34s
# 44:	learn: 1428.1037005	total: 17.5s	remaining: 1.95s
# 45:	learn: 1424.3123351	total: 17.9s	remaining: 1.55s
# 46:	learn: 1422.5043313	total: 18.3s	remaining: 1.17s
# 47:	learn: 1419.6432808	total: 18.7s	remaining: 779ms
# 48:	learn: 1418.4048968	total: 19.1s	remaining: 389ms
# 49:	learn: 1413.3915231	total: 19.5s	remaining: 0us

# %% [markdown]
# We can print out the best hyperparameter settings for our model

# %%
print('Best score across all searched parameters', grid.best_score_)
print('Best parameters:', best_par)
# Out:
# Best score across all searched parameters -1525.683316147072
# Best parameters: {'depth': 10, 'iterations': 50, 'l2_leaf_reg': 2, 'learning_rate': 0.5, 'loss_function': 'RMSE', 'random_seed': 12345}

# %% [markdown]
# Next, we train our CatBoost Regressor model using the best hyperparameter settings. Also, we note the time of the process.

# %%
#CatBoost Model training 

CBR_model = CatBoostRegressor(depth = 10,
                              iterations = 50,
                              l2_leaf_reg = 2,
                              learning_rate = 0.5,
                              loss_function = 'RMSE', 
                              random_seed = random_state)

# %time CBR_model.fit(f_train_gbm, t_train_gbm, cat_features = dat_features, verbose = False, plot = False)
# Out:
# CPU times: user 20.6 s, sys: 48.1 ms, total: 20.6 s
# Wall time: 20.8 s

# %%
#CatBoost Model Predictions

# %time CBR_model_pred = CBR_model.predict(f_test_gbm)
# Out:
# CPU times: user 162 ms, sys: 11 µs, total: 162 ms
# Wall time: 161 ms

# %% [markdown]
# RMSE Calculation:

# %%
CBR_rmse = rmse(t_test_gbm, CBR_model_pred)

CBR_rmse
# Out:
# 1489.7733356259291

# %% [markdown]
# We got an RMSE of 1489.77. This RMSE is higher than our baseline model

# %% [markdown]
# ## LightGBM Regressor

# %% [markdown]
# The LightGBM model does not require encoding. We will still be performing hyperparameter tuning similar to the way we did for CatBoost, except we will be dealing with different hyperparameters.
# One thing to note about LightGBM is that our categorical features have to be of the 'category' type before feeding it to LightGBM.
# LightGBM does not accept 'object' type or anything else. So we will need to do so both for the training set and the test set.

# %%
#Converting all training features to "category" type

obj_feat = list(f_train_gbm.loc[:, f_train_gbm.dtypes == 'object'].columns.values)

for feature in obj_feat:
    f_train_gbm[feature] = pd.Series(f_train_gbm[feature], dtype="category")

model_GBM = LGBMRegressor()
parameters = {'num_leaves': [10, 20, 30],
              'learning_rate': [0.5, 0.1],
              'n_estimators': [10, 20],
              'random_state': [random_state],
              'objective': ['rmse']}

grid = GridSearchCV(estimator = model_GBM, param_grid = parameters, scoring = scorer, cv=3, n_jobs=-1)
grid.fit(f_train_gbm, t_train_gbm)
best_param = grid.best_params_
# Out:
# /tmp/ipykernel_65/2124378442.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_train_gbm[feature] = pd.Series(f_train_gbm[feature], dtype="category")

# %% [markdown]
# Getting our best hyperparameter setting:

# %%
print('Best score across all searched parameters', grid.best_score_)
print('Best parameters:', best_param)
# Out:
# Best score across all searched parameters -1579.8335124962603
# Best parameters: {'learning_rate': 0.5, 'n_estimators': 20, 'num_leaves': 30, 'objective': 'rmse', 'random_state': 12345}

# %% [markdown]
# Next, we will train and test our LightGBM model using the hyperparameter settings above, while timing the process.

# %%
#LightGBM model training

LGBM_model = LGBMRegressor(learning_rate = 0.5,
                           n_estimators = 20,
                           num_leaves = 30,
                           objective = 'rmse',
                           random_state = random_state)

# %time LGBM_model.fit(f_train_gbm, t_train_gbm)
# Out:
# CPU times: user 1.68 s, sys: 19.3 ms, total: 1.7 s
# Wall time: 1.67 s
# LGBMRegressor(learning_rate=0.5, n_estimators=20, num_leaves=30,
#               objective='rmse', random_state=12345)

# %%
#Converting all test features to "category" type

obj_feat = list(f_test_gbm.loc[:, f_test_gbm.dtypes == 'object'].columns.values)

for feature in obj_feat:
    f_test_gbm[feature] = pd.Series(f_test_gbm[feature], dtype="category")

#LightGBM model predictions
# %time LGBM_pred = LGBM_model.predict(f_test_gbm)
# Out:
# CPU times: user 148 ms, sys: 0 ns, total: 148 ms
# Wall time: 89.2 ms
# /tmp/ipykernel_65/4195612490.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_test_gbm[feature] = pd.Series(f_test_gbm[feature], dtype="category")

# %% [markdown]
# RMSE Calculcation:

# %%
LGBM_rmse = rmse(LGBM_pred, t_test_gbm)

LGBM_rmse

#def rmse(pred, target):
# Out:
# 1547.9494795906612

# %% [markdown]
# The RMSE of 1547.949 is much better than the RMSE of the baseline model

# %% [markdown]
# ## Model analysis

# %% [markdown]
# To analyze the model, we prepare a table showing the different models, their training and prediction times (in milliseconds) and RMSEs

# %%
index = ['LR', 'DTR', 'RFR', 'CBM', 'LGBM']

total_summary = pd.DataFrame(data = {'training_time(ms)': [90.9, 1130, 40700, 20800, 1670],
                                     'prediction_time(ms)': [5.96, 12.9, 886, 161, 89.2],
                                     'RMSE': [3025, 1741, 1457, 1489, 1547]},
                            index = index)
                                     
                                    
total_summary
# Out:
#       training_time(ms)  prediction_time(ms)  RMSE
# LR                 90.9                 5.96  3025
# DTR              1130.0                12.90  1741
# RFR             40700.0               886.00  1457
# CBM             20800.0               161.00  1489
# LGBM             1670.0                89.20  1547

# %% [markdown]
# Takeaways:
#
# - Linear Regression had the best training time (90.9 ms) while the worst goes to Random Forest (40700 ms)
#
# - Linear Regression had the best prediction time (5.96 ms) while the worst goes to Random Forest (886 ms)
#
# - Random Forest had the best RMSE (1457) while the worst goes to Linear Regression (3025)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This project was done to develop an app to attract new customers for Rusty Bargain. Several models were built to determine the value of the cars. We have successfully cleaned and prepared the data and used it to train models. Linear Regression has the best training time (90.9 ms) while the worst is Random Forest (40700 ms). Also, Linear Regression has the best prediction time of 5.96 ms while the Random Forest Model has the worst, 886 ms.
#
# Random Forest has the best RMSE of 1457. However, the time taken for training and prediction is highest. The CatBoost model takes about half the time of the Random Forest model for training, and about four times less than the Random Forest Model for making predictions. Moreover, the RMSE of the CatBoost Model is 1489. Therefore, we will recommend with the CatBoost model.
