# %% [markdown]
# **Review**
#
# Hi, my name is Dmitry and I will be reviewing your project.
#
# You can find my comments in colored markdown cells:
#
# <div class="alert alert-success">
#   If everything is done successfully.
# </div>
#
# <div class="alert alert-warning">
#   If I have some (optional) suggestions, or questions to think about, or general comments.
# </div>
#
# <div class="alert alert-danger">
#   If a section requires some corrections. Work can't be accepted with red comments.
# </div>
#
# Please don't remove my comments, as it will make further review iterations much harder for me.
#
# Feel free to reply to my comments or ask questions using the following template:
#
# <div class="alert alert-info">
#   For your comments and questions.
# </div>
#
# First of all, thank you for turning in the project! Unfortunately it looks like the project is not quite ready for review yet. Please make sure that your code runs without errors. Also don't forget to add a final conclusion.

# %% [markdown]
# Rusty Bargain used car sales service is developing an app to attract new customers. In that app, you can quickly find out the market value of your car. You have access to historical data: technical specifications, trim versions, and prices. You need to build the model to determine the value.
#
# Rusty Bargain is interested in:
#
# - the quality of the prediction;
# - the speed of the prediction;
# - the time required for training
#
# ## Table of Contents
#
# 1. Data Preparation
# 2. Data Preprocessing
# 3. Model Training
# - Linear Regression
# - Decision Tree
# - Random Forest
# - CatBoost
# - LightGBM
# 4. Model Analysis
# 5. Conclusion

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Let us import our necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import make_scorer
random_state = 12345

# %% [markdown]
# Loading the dataset

# %%
data = pd.read_csv('/datasets/car_data.csv')

data.head()
# Out:
#         DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  24/03/2016 11:52    480         NaN              1993  manual      0
# 1  24/03/2016 10:58  18300       coupe              2011  manual    190
# 2  14/03/2016 12:52   9800         suv              2004    auto    163
# 3  17/03/2016 16:54   1500       small              2001  manual     75
# 4  31/03/2016 17:25   3600       small              2008  manual     69
#
#    Model  Mileage  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0   golf   150000                  0    petrol  volkswagen         NaN
# 1    NaN   125000                  5  gasoline        audi         yes
# 2  grand   125000                  8  gasoline        jeep         NaN
# 3   golf   150000                  6    petrol  volkswagen          no
# 4  fabia    90000                  7  gasoline       skoda          no
#
#         DateCreated  NumberOfPictures  PostalCode          LastSeen
# 0  24/03/2016 00:00                 0       70435  07/04/2016 03:16
# 1  24/03/2016 00:00                 0       66954  07/04/2016 01:46
# 2  14/03/2016 00:00                 0       90480  05/04/2016 12:47
# 3  17/03/2016 00:00                 0       91074  17/03/2016 17:40
# 4  31/03/2016 00:00                 0       60437  06/04/2016 10:17

# %% [markdown]
# Getting some info about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %% [markdown]
# The total number of rows for the dataset is 354369. Some columns have missing values which have to be dealt with. We will take a look at the description of the numerical columns

# %%
data.describe()
# Out:
#                Price  RegistrationYear          Power        Mileage  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %% [markdown]
# Taking a look at the dataset, we see that:
#
# - There are price values of zero. Considering the fact that we are looking at the market value of a car, the price cannot be zero. Therfore, we need to filter out the rows that have prices of zero.
# - There are registration years that date as far back as the year 1000, and far into the future as much as 9999. This is the year 2023. Therefore, those outlier values have to be filtered out .
# - Also, from the power column, there are cars with zero power. Those zero values will be filtered out also.
# - The number of Months goes from 1 to 12. However, we have values of 0 in the RegistrationMonth column. The zero values will be filtered out
# - Lastly, the  NumberOfPictures column is zero all through. The column is not of any significance. Therefore, it will be dropped.

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Great, you loaded the data, briefly explored it and made some interesting observations
#
# </div>

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Counting the number of duplicate rows

# %%
data.duplicated().sum()
# Out:
# 262

# %% [markdown]
# Next, we drop the 0 values from the columns

# %%
data = data.loc[data['Price'] != 0] #this code drops 0 values from the Price column

data = data.loc[data['RegistrationYear'] != 0] #this code drops 0 values from the RegistrationYear column

data = data.loc[data['Power'] != 0] #this code drops 0 values from the Power column

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Good!
#
# </div>

# %% [markdown]
# To filter out the outliers in "RegistrationYear" column, we need cars that have more recent registration dates.

# %% [markdown]
# Checking for the Registration dates older than 1990

# %%
old_registn = data.loc[data['RegistrationYear'] <= 1990].shape[0]
old_registn
# Out:
# 8842

# %%
tefy = old_registn/data.shape[0]
print(tefy)
# Out:
# 0.028779085852289926

# %% [markdown]
# Filtering out dates from 1990 takes out about 2.8% from our dataset, which is not much.

# %% [markdown]
# Also, to filter the outliers in the future dates, we take a look at the number of dates beyond 2023.

# %%
new_registn = data.loc[data['RegistrationYear'] >= 2023].shape[0]
new_registn
# Out:
# 24

# %% [markdown]
# There are 24 records of the Registration dates beyond 2023. Seeing that Rusty Bargain used car sales service is developing an app to attract new customers in the year 2023, then we will filter out Registration Years older than 1990, and beyond 2023

# %%
data = data.loc[(data['RegistrationYear'] >= 1990 ) & (data['RegistrationYear'] <= 2023)]
#registration Years between and including 1990 and 2023

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Ok, makes sense!
#
# </div>

# %% [markdown]
# Dropping the NumberofPictures Column

# %%
data = data.drop('NumberOfPictures', axis = 1)

# %% [markdown]
# Filling the missing values in 'NotRepaired' Column with empty values

# %%
data['NotRepaired'].fillna(value = 'unknown', inplace = True)

# %% [markdown]
# Dropping all other missing values and duplicate rows

# %%
data.dropna(inplace = True)

data.drop_duplicates(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 258067 entries, 2 to 354368
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        258067 non-null  object
#  1   Price              258067 non-null  int64
#  2   VehicleType        258067 non-null  object
#  3   RegistrationYear   258067 non-null  int64
#  4   Gearbox            258067 non-null  object
#  5   Power              258067 non-null  int64
#  6   Model              258067 non-null  object
#  7   Mileage            258067 non-null  int64
#  8   RegistrationMonth  258067 non-null  int64
#  9   FuelType           258067 non-null  object
#  10  Brand              258067 non-null  object
#  11  NotRepaired        258067 non-null  object
#  12  DateCreated        258067 non-null  object
#  13  PostalCode         258067 non-null  int64
#  14  LastSeen           258067 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 31.5+ MB

# %% [markdown]
# The cleaning process is done. Next, we prepare the data splits.

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Good job on cleaning the data!
#
# </div>

# %% [markdown]
# ## Model training

# %% [markdown]
# We will be training Linear Regression (as a baseline), Decision Tree Regressor, Random Forest Regressor, CatBoost Regressor, and LightGBM Regressor models. For the first three models we will need to encode the categorical features prior to training. The last two models don't need prior encoding since they have built-in encoders. Therefore, we will make two copies of the cleaned data: one that isn't encoded (which will be used with CatBoost and LightGBM), and the other which will be encoded for the other models

# %% [markdown]
# Creating and preparing a copy of the cleaned data to use it with CatBoost and LightGBM

# %%
data_gbm = data.copy()#makes a copy of our cleaned data
data_gbm.drop(['DateCrawled', 'DateCreated', 'LastSeen'], axis=1, inplace=True)#drops the columns that are in time-date
#format 
data_gbm.reset_index(drop=True, inplace=True)#resets the index
features_gbm=data_gbm.drop('Price', axis=1)#defines our features
target_gbm=data_gbm['Price']#defines the price column as our target
f_train_gbm, f_test_gbm, t_train_gbm, t_test_gbm = train_test_split(features_gbm, target_gbm, test_size=0.2,
                                                                 random_state=random_state)
#splits our new data into training and test sets for our features and target

#prints the shapes of our splits
print(f_train_gbm.shape)
print(t_train_gbm.shape)
print(f_test_gbm.shape)
print(t_test_gbm.shape)
# Out:
# (206453, 11)
# (206453,)
# (51614, 11)
# (51614,)

# %% [markdown]
# For the models that need encoding, we will create a list that comprises the columns that we want encoded:

# %%
dat_features = ['VehicleType', 'RegistrationYear', 'Gearbox', 'Model', 'RegistrationMonth',
         'FuelType', 'Brand', 'NotRepaired', 'PostalCode']

# %%
#creating and preparing a copy of data to use with models requiring prior encoding
data_enc = data.copy() # creating a copy of cleaned data and putting it into the variable data_enc
encoder = OrdinalEncoder()#creates an instance of the ordinal encoder
data_enc[dat_features] = encoder.fit_transform(data_enc[dat_features]) #encodes the columns and saves the encoded values into
                                                                       # into a new table called data_enc[dat_features]

# %%
data_enc[dat_features]
# Out:
#         VehicleType  RegistrationYear  Gearbox  Model  RegistrationMonth  \
# 2               6.0              14.0      0.0  117.0                8.0
# 3               5.0              11.0      1.0  116.0                6.0
# 4               5.0              18.0      1.0  101.0                7.0
# 5               4.0               5.0      1.0   11.0               10.0
# 6               1.0              14.0      1.0    8.0                8.0
# ...             ...               ...      ...    ...                ...
# 354360          7.0              15.0      1.0   11.0                5.0
# 354362          4.0              14.0      1.0  140.0                5.0
# 354366          1.0              10.0      0.0  106.0                3.0
# 354367          0.0               6.0      1.0  221.0                3.0
# 354368          7.0              12.0      1.0  116.0                6.0
#
#         FuelType  Brand  NotRepaired  PostalCode
# 2            2.0   14.0          1.0      6935.0
# 3            6.0   37.0          0.0      6975.0
# 4            2.0   31.0          0.0      4167.0
# 5            6.0    2.0          2.0      2341.0
# 6            6.0   25.0          0.0      4591.0
# ...          ...    ...          ...         ...
# 354360       2.0    2.0          0.0      5861.0
# 354362       6.0   30.0          2.0      7719.0
# 354366       6.0   32.0          0.0      1793.0
# 354367       2.0   37.0          0.0      6580.0
# 354368       2.0   37.0          1.0      2933.0
#
# [258067 rows x 9 columns]

# %% [markdown]
# Preparing and splitting the encoded data

# %%
#preparation and splitting for encoded data

data_enc.drop(['DateCrawled', 'DateCreated', 'LastSeen'], axis = 1, inplace = True)

data_enc.reset_index(drop = True, inplace = True)

feat_enc = data_enc.drop('Price', axis = 1)
targ_enc = data_enc['Price']

feat_train_enc, feat_test_enc, targ_train_enc, targ_test_enc = train_test_split(feat_enc, targ_enc, test_size=0.2,
                                                                 random_state=random_state)

print(feat_train_enc.shape)
print(feat_test_enc.shape)
print(targ_train_enc.shape)
print(targ_test_enc.shape)
# Out:
# (206453, 11)
# (51614, 11)
# (206453,)
# (51614,)

# %% [markdown]
# Our dataset has been cleaned, and split into the training, and test sets for both the encoded and unencoded data

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Alright, the data was split into train and test sets
#
# </div>

# %% [markdown]
# Next, we will create a function to calculate the RMSE and then make it our evaluation metric for our models. It takes as arguments the prediction and target data.

# %%
#create an rmse function and make it our scorer
def rmse(pred, target): #creates the rmse function that takes target and prediction values as arguments
    pred = np.array(pred) #turns the prediction into a vector
    target = np.array(target) #turns the target into a vector
    error = pred - target
    error_sq = error ** 2
    error_sq_mean = error_sq.mean() #this gives the mean of all errors
    score = error_sq_mean ** 0.5 #this code gives the Square Root Error
    return score #returns the value


scorer = make_scorer(rmse, greater_is_better = False) 
#makes our rmse function our scorer and specifies that a smaller value is better
#make_scorer calls the function rmse, with its arguments

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment</b>
#
# You are correct that lower RMSE values are better, but the scorer was initialized with `greater_is_better=True`, which is the opposite :)
#
# Using this scorer with GridSearchCV will make it select the model with the biggest error.
#
# By the way, there is no need to define an RMSE scorer yourself: it is one of the [predefined metrics](https://scikit-learn.org/stable/modules/model_evaluation.html#common-cases-predefined-values) (`scoring='neg_root_mean_squared_error'`)
#
# </div>

# %% [markdown]
# Using Linear Regression as a Baseline

# %% [markdown]
# ## Linear Regression (Baseline)

# %% [markdown]
# The next step is to train a Linear Regression model as our baseline. We will feed the Linear Regression model with the encoded data. Let's get a cross-validation score:

# %%
LR = LinearRegression()
LR_score = cross_val_score(LR, feat_train_enc, targ_train_enc, scoring = scorer, cv=5) #++++++
#calculates the cross-validation scores for 5 folds of the training data
print(LR_score.mean()) #prints the mean of those scores
# Out:
# -3024.555600865481

# %% [markdown]
# Next, we train the model and take note of the wall time it takes to do so

# %%
# %time LR.fit(feat_train_enc, targ_train_enc) #trains the model with the encoded data and times the process
# Out:
# CPU times: user 76.1 ms, sys: 89.3 ms, total: 165 ms
# Wall time: 144 ms
# LinearRegression()

# %% [markdown]
# Next, we get the prediction

# %%
# %time lr_pred = LR.predict(feat_test_enc) #gets predictions and times the process
# Out:
# CPU times: user 4.78 ms, sys: 33.5 ms, total: 38.2 ms
# Wall time: 15.2 ms

# %%
#Calculating the RMSE

rmse_lin = rmse(lr_pred, targ_test_enc)
rmse_lin
# Out:
# 3025.5635552424487

# %% [markdown]
# So the RMSE score of the Linear Model is 3025.56. This is the baseline score that all other models must exceed.

# %% [markdown]
# ## Decision Tree Regressor

# %% [markdown]
# For this model we will perform hyperparameter tuning (with the max_depth hyperparameter). We want to find the best value to set it to when training the model. We will choose the hyperparameter which gets the best cross-validation score.

# %%
#Decision Tree Rgressor - hyperparameter tuning

for depth in range(1, 20):
    DTR = DecisionTreeRegressor(max_depth = depth, random_state=random_state)
    
    DTR_score = cross_val_score(DTR, feat_train_enc, targ_train_enc, scoring=scorer, cv=5)
    #gets cross-validation score
    
    print('Max_depth', depth, 'score:', DTR_score.mean())
    #prints max_depth value and the mean cross-validation score
# Out:
# Max_depth 1 score: -3521.978669523077
# Max_depth 2 score: -3069.033708414861
# Max_depth 3 score: -2682.365668080236
# Max_depth 4 score: -2439.3184454603615
# Max_depth 5 score: -2271.762077459454
# Max_depth 6 score: -2169.0729030836947
# Max_depth 7 score: -2076.1607854002673
# Max_depth 8 score: -2000.3913187802452
# Max_depth 9 score: -1925.2246002770867
# Max_depth 10 score: -1880.0420807615567
# Max_depth 11 score: -1838.190057993053
# Max_depth 12 score: -1812.7662955205255
# Max_depth 13 score: -1806.4749135845188
# Max_depth 14 score: -1817.3029310842855
# Max_depth 15 score: -1834.2969364040723
# Max_depth 16 score: -1856.2507639921885
# Max_depth 17 score: -1877.8910328720085
# Max_depth 18 score: -1899.289940839661
# Max_depth 19 score: -1921.3172146778893

# %% [markdown]
# The best score was gotten when the max_depth hyperparameter was 13. So this max_depth of 13 will be used to train our model and get predictions, and the processes will be timed.

# %%
#DTR Training

DTR = DecisionTreeRegressor(max_depth = 13, random_state = random_state)

# %time DTR.fit(feat_train_enc, targ_train_enc)
# Out:
# CPU times: user 1.09 s, sys: 12 ms, total: 1.1 s
# Wall time: 1.11 s
# DecisionTreeRegressor(max_depth=13, random_state=12345)

# %%
#DTR model prediction
# %time DTR_pred = DTR.predict(feat_test_enc)
# Out:
# CPU times: user 16.9 ms, sys: 0 ns, total: 16.9 ms
# Wall time: 14.9 ms

# %%
#DTR RMSE
DTR_rmse = rmse(targ_test_enc, DTR_pred)
DTR_rmse
# Out:
# 1741.9646827979418

# %% [markdown]
# The RMSE for the Decision Tree model is 1741.96 which is way better than our baseline

# %% [markdown]
# ## Random Forest Regressor

# %% [markdown]
# For this modelling, we would be calling the RandomForestRegressor() function. The hyperparameters that we will be dealing with are max_depth, which is the depth of each tree, and n_estimators, which is the number of trees.

# %%
#Random Forest Regressor - hyperparameter tuning
for depth in range(5, 20):
    RFR = RandomForestRegressor(n_estimators = 40, max_depth = depth, random_state = random_state)
    RFR_score = cross_val_score(RFR, feat_train_enc, targ_train_enc, scoring = scorer, cv = 5)
    print('Max_depth', depth, 'score:', RFR_score.mean())
# Out:
# Max_depth 5 score: -2242.7838215752417
# Max_depth 6 score: -2123.2738875063774
# Max_depth 7 score: -2017.4549151904678
# Max_depth 8 score: -1927.3379542957125
# Max_depth 9 score: -1843.111338657626
# Max_depth 10 score: -1770.4342461342865
# Max_depth 11 score: -1705.9164234292668
# Max_depth 12 score: -1652.6048068778769
# Max_depth 13 score: -1609.427899022185
# Max_depth 14 score: -1574.9250191060187
# Max_depth 15 score: -1549.3650093061883
# Max_depth 16 score: -1531.8121481561598
# Max_depth 17 score: -1518.0519262817368
# Max_depth 18 score: -1508.885344389258
# Max_depth 19 score: -1504.218039629033

# %% [markdown]
# Next we train and test our model, with the processes being timed

# %%
#Random Forest Regressor model training
model_RFR = RandomForestRegressor(n_estimators = 40, max_depth = 19, random_state = random_state)
# %time model_RFR.fit(feat_train_enc, targ_train_enc)
# Out:
# CPU times: user 39.4 s, sys: 128 ms, total: 39.5 s
# Wall time: 39.7 s
# RandomForestRegressor(max_depth=19, n_estimators=40, random_state=12345)

# %%
#Random Forest Regressor model predictions
# %time RFR_pred = model_RFR.predict(feat_test_enc)
# Out:
# CPU times: user 711 ms, sys: 1 µs, total: 711 ms
# Wall time: 710 ms

# %% [markdown]
# Calculating the RMSE

# %%
RFR_model_RMSE = rmse(targ_test_enc, RFR_pred)
RFR_model_RMSE
# Out:
# 1457.4614759314102

# %% [markdown]
# RMSE of 1457.456. Much better than our baseline

# %% [markdown]
# ## CatBoost Regressor

# %% [markdown]
# CatBoost regressor uses gradient boosting, so, we don't need prior encoding. We will be tuning using different hyperparameters this time, such as depth, learning rate, 12_lear_reg, iterations, loss functions, random_speed. We will find the best parameters using GridSearchCV.

# %%
CBR = CatBoostRegressor()
parameters={'depth': [6, 8, 10],
           'learning_rate': [0.5, 0.1],
           'l2_leaf_reg': [2, 4],
           'iterations': [10, 50],
           'loss_function': ['RMSE'],
           'random_seed': [random_state]} #our dictionary of hyperparameters that will be looped through when 
                                          #we feed them to GridSearch
grid = GridSearchCV(estimator = CBR, param_grid = parameters, scoring = scorer, cv = 3, n_jobs=-1, verbose=0)

grid.fit(f_train_gbm, t_train_gbm,  cat_features = dat_features) #fits our training unencoded data into our grid instance

best_par = grid.best_params_ #gets the best set of parameters for our model
# Out:
# 0:	learn: 3157.5838254	total: 225ms	remaining: 2.02s
# 1:	learn: 2464.3591891	total: 377ms	remaining: 1.51s
# 2:	learn: 2156.0403011	total: 548ms	remaining: 1.28s
# 3:	learn: 2006.3875119	total: 689ms	remaining: 1.03s
# 4:	learn: 1926.1073904	total: 848ms	remaining: 848ms
# 5:	learn: 1891.7555166	total: 1s	remaining: 668ms
# 6:	learn: 1862.9877756	total: 1.18s	remaining: 506ms
# 7:	learn: 1834.7744324	total: 1.34s	remaining: 334ms
# 8:	learn: 1819.1045177	total: 1.49s	remaining: 166ms
# 9:	learn: 1801.2861528	total: 1.64s	remaining: 0us
# 0:	learn: 3160.8208597	total: 171ms	remaining: 1.54s
# 1:	learn: 2486.2182110	total: 320ms	remaining: 1.28s
# 2:	learn: 2205.0192763	total: 491ms	remaining: 1.15s
# 3:	learn: 2020.3149201	total: 652ms	remaining: 978ms
# 4:	learn: 1943.4368540	total: 832ms	remaining: 832ms
# 5:	learn: 1898.8838408	total: 983ms	remaining: 655ms
# 6:	learn: 1868.5899521	total: 1.14s	remaining: 488ms
# 7:	learn: 1846.1523077	total: 1.29s	remaining: 323ms
# 8:	learn: 1817.6770620	total: 1.45s	remaining: 162ms
# 9:	learn: 1798.0647249	total: 1.61s	remaining: 0us
# 0:	learn: 3190.5607226	total: 174ms	remaining: 1.57s
# 1:	learn: 2482.3654185	total: 359ms	remaining: 1.43s
# 2:	learn: 2180.0692119	total: 533ms	remaining: 1.24s
# 3:	learn: 2023.0221271	total: 690ms	remaining: 1.03s
# 4:	learn: 1947.3742658	total: 845ms	remaining: 845ms
# 5:	learn: 1891.6450533	total: 1.01s	remaining: 677ms
# 6:	learn: 1853.3440935	total: 1.18s	remaining: 506ms
# 7:	learn: 1820.5098473	total: 1.33s	remaining: 332ms
# 8:	learn: 1803.6744873	total: 1.49s	remaining: 165ms
# 9:	learn: 1784.2294384	total: 1.64s	remaining: 0us
# 0:	learn: 4329.2224504	total: 196ms	remaining: 1.76s
# 1:	learn: 4038.3886626	total: 365ms	remaining: 1.46s
# 2:	learn: 3781.2281142	total: 532ms	remaining: 1.24s
# 3:	learn: 3550.7840993	total: 692ms	remaining: 1.04s
# 4:	learn: 3350.6093154	total: 845ms	remaining: 845ms
# 5:	learn: 3174.3886435	total: 994ms	remaining: 663ms
# 6:	learn: 3018.8793448	total: 1.15s	remaining: 495ms
# 7:	learn: 2877.4432448	total: 1.31s	remaining: 327ms
# 8:	learn: 2754.7444323	total: 1.47s	remaining: 163ms
# 9:	learn: 2644.1364460	total: 1.63s	remaining: 0us
# 0:	learn: 4323.1573717	total: 170ms	remaining: 1.53s
# 1:	learn: 4034.2121088	total: 323ms	remaining: 1.29s
# 2:	learn: 3778.3733104	total: 485ms	remaining: 1.13s
# 3:	learn: 3550.0966421	total: 641ms	remaining: 962ms
# 4:	learn: 3351.3015285	total: 790ms	remaining: 790ms
# 5:	learn: 3177.8355138	total: 942ms	remaining: 628ms
# 6:	learn: 3023.3150317	total: 1.11s	remaining: 474ms
# 7:	learn: 2884.0342315	total: 1.25s	remaining: 314ms
# 8:	learn: 2758.3916682	total: 1.4s	remaining: 156ms
# 9:	learn: 2647.3749733	total: 1.55s	remaining: 0us
# 0:	learn: 4343.8235713	total: 183ms	remaining: 1.65s
# 1:	learn: 4055.9834887	total: 359ms	remaining: 1.44s
# 2:	learn: 3790.1559379	total: 531ms	remaining: 1.24s
# 3:	learn: 3560.0166557	total: 686ms	remaining: 1.03s
# 4:	learn: 3353.6149085	total: 843ms	remaining: 843ms
# 5:	learn: 3173.3881878	total: 1s	remaining: 669ms
# 6:	learn: 3013.6534814	total: 1.16s	remaining: 497ms
# 7:	learn: 2876.1179490	total: 1.31s	remaining: 329ms
# 8:	learn: 2749.2529458	total: 1.48s	remaining: 164ms
# 9:	learn: 2638.7678292	total: 1.64s	remaining: 0us
# 0:	learn: 3158.3537058	total: 153ms	remaining: 1.38s
# 1:	learn: 2465.4654576	total: 290ms	remaining: 1.16s
# 2:	learn: 2156.9715450	total: 498ms	remaining: 1.16s
# 3:	learn: 2007.2083644	total: 653ms	remaining: 980ms
# 4:	learn: 1927.6246597	total: 813ms	remaining: 813ms
# 5:	learn: 1890.7680200	total: 973ms	remaining: 649ms
# 6:	learn: 1866.2577803	total: 1.15s	remaining: 493ms
# 7:	learn: 1835.8752138	total: 1.3s	remaining: 326ms
# 8:	learn: 1810.5613826	total: 1.46s	remaining: 162ms
# 9:	learn: 1793.9450013	total: 1.61s	remaining: 0us
# 0:	learn: 3161.5635850	total: 178ms	remaining: 1.6s
# 1:	learn: 2487.0232485	total: 330ms	remaining: 1.32s
# 2:	learn: 2205.5964842	total: 511ms	remaining: 1.19s
# 3:	learn: 2020.8944232	total: 679ms	remaining: 1.02s
# 4:	learn: 1944.1834363	total: 837ms	remaining: 837ms
# 5:	learn: 1900.2124590	total: 990ms	remaining: 660ms
# 6:	learn: 1870.1809743	total: 1.14s	remaining: 489ms
# 7:	learn: 1847.9643776	total: 1.29s	remaining: 323ms
# 8:	learn: 1819.1538587	total: 1.44s	remaining: 160ms
# 9:	learn: 1792.8607394	total: 1.59s	remaining: 0us
# 0:	learn: 3191.5200125	total: 195ms	remaining: 1.75s
# 1:	learn: 2483.1695911	total: 368ms	remaining: 1.47s
# 2:	learn: 2180.7749092	total: 538ms	remaining: 1.26s
# 3:	learn: 2023.6667942	total: 712ms	remaining: 1.07s
# 4:	learn: 1948.0991511	total: 871ms	remaining: 871ms
# 5:	learn: 1892.4401428	total: 1.03s	remaining: 684ms
# 6:	learn: 1854.3686977	total: 1.19s	remaining: 509ms
# 7:	learn: 1825.1382679	total: 1.33s	remaining: 334ms
# 8:	learn: 1807.6823481	total: 1.49s	remaining: 165ms
# 9:	learn: 1782.9759112	total: 1.64s	remaining: 0us
# 0:	learn: 4329.4207103	total: 174ms	remaining: 1.57s
# 1:	learn: 4038.9226259	total: 327ms	remaining: 1.31s
# 2:	learn: 3781.8660002	total: 485ms	remaining: 1.13s
# 3:	learn: 3551.4830193	total: 644ms	remaining: 966ms
# 4:	learn: 3351.4660203	total: 790ms	remaining: 790ms
# 5:	learn: 3175.2829003	total: 943ms	remaining: 629ms
# 6:	learn: 3019.8211997	total: 1.12s	remaining: 479ms
# 7:	learn: 2878.3894228	total: 1.27s	remaining: 317ms
# 8:	learn: 2755.7993648	total: 1.42s	remaining: 158ms
# 9:	learn: 2645.1853736	total: 1.57s	remaining: 0us
# 0:	learn: 4323.3500201	total: 168ms	remaining: 1.51s
# 1:	learn: 4035.9176567	total: 320ms	remaining: 1.28s
# 2:	learn: 3781.5252065	total: 482ms	remaining: 1.12s
# 3:	learn: 3555.3912082	total: 643ms	remaining: 964ms
# 4:	learn: 3356.8104641	total: 798ms	remaining: 798ms
# 5:	learn: 3177.7074221	total: 950ms	remaining: 633ms
# 6:	learn: 3018.8348284	total: 1.1s	remaining: 473ms
# 7:	learn: 2883.9725410	total: 1.25s	remaining: 313ms
# 8:	learn: 2759.2573201	total: 1.4s	remaining: 156ms
# 9:	learn: 2651.2527008	total: 1.57s	remaining: 0us
# 0:	learn: 4344.0740567	total: 175ms	remaining: 1.58s
# 1:	learn: 4056.4798444	total: 340ms	remaining: 1.36s
# 2:	learn: 3790.8112124	total: 511ms	remaining: 1.19s
# 3:	learn: 3560.7705590	total: 667ms	remaining: 1s
# 4:	learn: 3354.4742340	total: 823ms	remaining: 823ms
# 5:	learn: 3174.3014075	total: 976ms	remaining: 651ms
# 6:	learn: 3014.5854651	total: 1.13s	remaining: 486ms
# 7:	learn: 2877.0747652	total: 1.28s	remaining: 319ms
# 8:	learn: 2750.2908120	total: 1.44s	remaining: 160ms
# 9:	learn: 2639.8087906	total: 1.6s	remaining: 0us
# 0:	learn: 3157.5838254	total: 177ms	remaining: 8.66s
# 1:	learn: 2464.3591891	total: 319ms	remaining: 7.67s
# 2:	learn: 2156.0403011	total: 484ms	remaining: 7.59s
# 3:	learn: 2006.3875119	total: 638ms	remaining: 7.34s
# 4:	learn: 1926.1073904	total: 789ms	remaining: 7.11s
# 5:	learn: 1891.7555166	total: 941ms	remaining: 6.9s
# 6:	learn: 1862.9877756	total: 1.11s	remaining: 6.84s
# 7:	learn: 1834.7744324	total: 1.29s	remaining: 6.8s
# 8:	learn: 1819.1045177	total: 1.45s	remaining: 6.59s
# 9:	learn: 1801.2861528	total: 1.59s	remaining: 6.38s
# 10:	learn: 1784.1044555	total: 1.75s	remaining: 6.19s
# 11:	learn: 1761.9664400	total: 1.9s	remaining: 6.02s
# 12:	learn: 1745.8953689	total: 2.05s	remaining: 5.84s
# 13:	learn: 1736.1745639	total: 2.2s	remaining: 5.66s
# 14:	learn: 1722.7310933	total: 2.35s	remaining: 5.49s
# 15:	learn: 1714.4162455	total: 2.51s	remaining: 5.33s
# 16:	learn: 1707.0553914	total: 2.66s	remaining: 5.16s
# 17:	learn: 1697.5312774	total: 2.81s	remaining: 4.99s
# 18:	learn: 1686.7102065	total: 2.96s	remaining: 4.84s
# 19:	learn: 1682.4415912	total: 3.12s	remaining: 4.67s
# 20:	learn: 1675.4806559	total: 3.29s	remaining: 4.55s
# 21:	learn: 1669.8873896	total: 3.44s	remaining: 4.38s
# 22:	learn: 1662.4530519	total: 3.59s	remaining: 4.22s
# 23:	learn: 1658.4018493	total: 3.75s	remaining: 4.06s
# 24:	learn: 1654.0140690	total: 3.9s	remaining: 3.9s
# 25:	learn: 1651.3679156	total: 4.05s	remaining: 3.74s
# 26:	learn: 1646.4673029	total: 4.2s	remaining: 3.57s
# 27:	learn: 1643.5734663	total: 4.35s	remaining: 3.41s
# 28:	learn: 1635.7761595	total: 4.5s	remaining: 3.26s
# 29:	learn: 1632.3852509	total: 4.64s	remaining: 3.1s
# 30:	learn: 1628.9905547	total: 4.79s	remaining: 2.94s
# 31:	learn: 1626.5119817	total: 4.93s	remaining: 2.77s
# 32:	learn: 1621.6105056	total: 5.09s	remaining: 2.62s
# 33:	learn: 1619.8492153	total: 5.25s	remaining: 2.47s
# 34:	learn: 1616.4245482	total: 5.41s	remaining: 2.32s
# 35:	learn: 1613.5747642	total: 5.56s	remaining: 2.16s
# 36:	learn: 1611.3449004	total: 5.7s	remaining: 2s
# 37:	learn: 1609.1400602	total: 5.85s	remaining: 1.85s
# 38:	learn: 1607.0014477	total: 6s	remaining: 1.69s
# 39:	learn: 1604.0478528	total: 6.15s	remaining: 1.54s
# 40:	learn: 1602.1362323	total: 6.3s	remaining: 1.38s
# 41:	learn: 1600.4442312	total: 6.46s	remaining: 1.23s
# 42:	learn: 1599.7926392	total: 6.63s	remaining: 1.08s
# 43:	learn: 1598.2112973	total: 6.77s	remaining: 924ms
# 44:	learn: 1595.4317868	total: 6.93s	remaining: 770ms
# 45:	learn: 1591.9162349	total: 7.08s	remaining: 616ms
# 46:	learn: 1589.8015860	total: 7.24s	remaining: 462ms
# 47:	learn: 1588.2265517	total: 7.39s	remaining: 308ms
# 48:	learn: 1586.2335500	total: 7.54s	remaining: 154ms
# 49:	learn: 1583.6327593	total: 7.7s	remaining: 0us
# 0:	learn: 3160.8208597	total: 176ms	remaining: 8.64s
# 1:	learn: 2486.2182110	total: 324ms	remaining: 7.77s
# 2:	learn: 2205.0192763	total: 504ms	remaining: 7.89s
# 3:	learn: 2020.3149201	total: 644ms	remaining: 7.41s
# 4:	learn: 1943.4368540	total: 820ms	remaining: 7.38s
# 5:	learn: 1898.8838408	total: 994ms	remaining: 7.29s
# 6:	learn: 1868.5899521	total: 1.15s	remaining: 7.05s
# 7:	learn: 1846.1523077	total: 1.3s	remaining: 6.81s
# 8:	learn: 1817.6770620	total: 1.45s	remaining: 6.6s
# 9:	learn: 1798.0647249	total: 1.6s	remaining: 6.4s
# 10:	learn: 1785.4641061	total: 1.75s	remaining: 6.21s
# 11:	learn: 1771.9701243	total: 1.9s	remaining: 6.02s
# 12:	learn: 1750.4489301	total: 2.05s	remaining: 5.84s
# 13:	learn: 1740.2370800	total: 2.2s	remaining: 5.66s
# 14:	learn: 1728.8704044	total: 2.36s	remaining: 5.5s
# 15:	learn: 1716.5963704	total: 2.51s	remaining: 5.33s
# 16:	learn: 1707.1351261	total: 2.66s	remaining: 5.16s
# 17:	learn: 1698.9015204	total: 2.82s	remaining: 5.01s
# 18:	learn: 1689.3453368	total: 2.98s	remaining: 4.86s
# 19:	learn: 1681.8199931	total: 3.15s	remaining: 4.72s
# 20:	learn: 1677.6193868	total: 3.31s	remaining: 4.56s
# 21:	learn: 1671.5304139	total: 3.46s	remaining: 4.4s
# 22:	learn: 1666.6149487	total: 3.61s	remaining: 4.24s
# 23:	learn: 1662.9019481	total: 3.76s	remaining: 4.07s
# 24:	learn: 1655.4891025	total: 3.91s	remaining: 3.91s
# 25:	learn: 1651.9578617	total: 4.06s	remaining: 3.75s
# 26:	learn: 1647.0762732	total: 4.21s	remaining: 3.58s
# 27:	learn: 1641.9326703	total: 4.38s	remaining: 3.44s
# 28:	learn: 1636.5516173	total: 4.53s	remaining: 3.28s
# 29:	learn: 1634.0055898	total: 4.69s	remaining: 3.13s
# 30:	learn: 1629.9898931	total: 4.86s	remaining: 2.98s
# 31:	learn: 1625.4559816	total: 5.02s	remaining: 2.83s
# 32:	learn: 1622.0096285	total: 5.17s	remaining: 2.66s
# 33:	learn: 1617.6999876	total: 5.35s	remaining: 2.52s
# 34:	learn: 1614.5975205	total: 5.5s	remaining: 2.35s
# 35:	learn: 1612.3992373	total: 5.64s	remaining: 2.19s
# 36:	learn: 1610.2428201	total: 5.79s	remaining: 2.04s
# 37:	learn: 1606.8858424	total: 5.95s	remaining: 1.88s
# 38:	learn: 1604.0537499	total: 6.1s	remaining: 1.72s
# 39:	learn: 1602.0535036	total: 6.25s	remaining: 1.56s
# 40:	learn: 1599.4175548	total: 6.41s	remaining: 1.41s
# 41:	learn: 1595.4294122	total: 6.56s	remaining: 1.25s
# 42:	learn: 1591.7202546	total: 6.72s	remaining: 1.09s
# 43:	learn: 1590.0595834	total: 6.87s	remaining: 936ms
# 44:	learn: 1588.2308301	total: 7.03s	remaining: 781ms
# 45:	learn: 1586.7182931	total: 7.17s	remaining: 624ms
# 46:	learn: 1584.3863714	total: 7.34s	remaining: 468ms
# 47:	learn: 1581.4920042	total: 7.5s	remaining: 313ms
# 48:	learn: 1580.1072300	total: 7.66s	remaining: 156ms
# 49:	learn: 1578.5292693	total: 7.81s	remaining: 0us
# 0:	learn: 3190.5607226	total: 171ms	remaining: 8.4s
# 1:	learn: 2482.3654185	total: 353ms	remaining: 8.48s
# 2:	learn: 2180.0692119	total: 540ms	remaining: 8.46s
# 3:	learn: 2023.0221271	total: 691ms	remaining: 7.95s
# 4:	learn: 1947.3742658	total: 843ms	remaining: 7.59s
# 5:	learn: 1891.6450533	total: 998ms	remaining: 7.32s
# 6:	learn: 1853.3440935	total: 1.15s	remaining: 7.08s
# 7:	learn: 1820.5098473	total: 1.3s	remaining: 6.85s
# 8:	learn: 1803.6744873	total: 1.46s	remaining: 6.63s
# 9:	learn: 1784.2294384	total: 1.61s	remaining: 6.43s
# 10:	learn: 1765.1218064	total: 1.76s	remaining: 6.24s
# 11:	learn: 1752.6898217	total: 1.91s	remaining: 6.05s
# 12:	learn: 1736.8108565	total: 2.07s	remaining: 5.9s
# 13:	learn: 1728.5283656	total: 2.22s	remaining: 5.71s
# 14:	learn: 1714.1327868	total: 2.36s	remaining: 5.5s
# 15:	learn: 1705.3924365	total: 2.5s	remaining: 5.32s
# 16:	learn: 1696.9709957	total: 2.65s	remaining: 5.14s
# 17:	learn: 1689.1720939	total: 2.8s	remaining: 4.97s
# 18:	learn: 1682.0582770	total: 2.94s	remaining: 4.8s
# 19:	learn: 1676.1117412	total: 3.1s	remaining: 4.65s
# 20:	learn: 1667.1964235	total: 3.25s	remaining: 4.49s
# 21:	learn: 1661.9061140	total: 3.4s	remaining: 4.33s
# 22:	learn: 1654.9997117	total: 3.56s	remaining: 4.17s
# 23:	learn: 1648.9533116	total: 3.71s	remaining: 4.02s
# 24:	learn: 1645.0686403	total: 3.86s	remaining: 3.86s
# 25:	learn: 1637.4403108	total: 4.01s	remaining: 3.71s
# 26:	learn: 1634.0224242	total: 4.17s	remaining: 3.55s
# 27:	learn: 1631.4505881	total: 4.32s	remaining: 3.4s
# 28:	learn: 1627.5894912	total: 4.47s	remaining: 3.24s
# 29:	learn: 1623.0659505	total: 4.62s	remaining: 3.08s
# 30:	learn: 1619.1336804	total: 4.78s	remaining: 2.93s
# 31:	learn: 1615.2696120	total: 4.94s	remaining: 2.78s
# 32:	learn: 1611.0173901	total: 5.09s	remaining: 2.62s
# 33:	learn: 1608.4568211	total: 5.24s	remaining: 2.46s
# 34:	learn: 1606.4513739	total: 5.4s	remaining: 2.31s
# 35:	learn: 1603.5893279	total: 5.55s	remaining: 2.16s
# 36:	learn: 1601.4122395	total: 5.7s	remaining: 2s
# 37:	learn: 1598.4266478	total: 5.86s	remaining: 1.85s
# 38:	learn: 1594.9867437	total: 6s	remaining: 1.69s
# 39:	learn: 1592.1402455	total: 6.15s	remaining: 1.54s
# 40:	learn: 1589.8627043	total: 6.32s	remaining: 1.39s
# 41:	learn: 1588.2655104	total: 6.49s	remaining: 1.24s
# 42:	learn: 1586.9709845	total: 6.64s	remaining: 1.08s
# 43:	learn: 1584.3577992	total: 6.8s	remaining: 927ms
# 44:	learn: 1582.9324573	total: 6.95s	remaining: 772ms
# 45:	learn: 1579.2958792	total: 7.09s	remaining: 617ms
# 46:	learn: 1576.4782303	total: 7.25s	remaining: 463ms
# 47:	learn: 1573.4922853	total: 7.4s	remaining: 308ms
# 48:	learn: 1571.7579758	total: 7.57s	remaining: 155ms
# 49:	learn: 1569.0799944	total: 7.72s	remaining: 0us
# 0:	learn: 4329.2224504	total: 168ms	remaining: 8.26s
# 1:	learn: 4038.3886626	total: 314ms	remaining: 7.54s
# 2:	learn: 3781.2281142	total: 474ms	remaining: 7.42s
# 3:	learn: 3550.7840993	total: 629ms	remaining: 7.23s
# 4:	learn: 3350.6093154	total: 789ms	remaining: 7.1s
# 5:	learn: 3174.3886435	total: 944ms	remaining: 6.92s
# 6:	learn: 3018.8793448	total: 1.11s	remaining: 6.83s
# 7:	learn: 2877.4432448	total: 1.27s	remaining: 6.69s
# 8:	learn: 2754.7444323	total: 1.43s	remaining: 6.5s
# 9:	learn: 2644.1364460	total: 1.58s	remaining: 6.31s
# 10:	learn: 2545.7763919	total: 1.74s	remaining: 6.17s
# 11:	learn: 2463.1117666	total: 1.9s	remaining: 6s
# 12:	learn: 2388.3470952	total: 2.05s	remaining: 5.84s
# 13:	learn: 2322.3237482	total: 2.21s	remaining: 5.68s
# 14:	learn: 2263.9782035	total: 2.37s	remaining: 5.53s
# 15:	learn: 2210.4401352	total: 2.52s	remaining: 5.36s
# 16:	learn: 2164.4708407	total: 2.68s	remaining: 5.2s
# 17:	learn: 2123.3470745	total: 2.84s	remaining: 5.04s
# 18:	learn: 2090.7157957	total: 2.97s	remaining: 4.85s
# 19:	learn: 2058.2941444	total: 3.13s	remaining: 4.69s
# 20:	learn: 2028.6711902	total: 3.28s	remaining: 4.54s
# 21:	learn: 2003.9746416	total: 3.44s	remaining: 4.37s
# 22:	learn: 1983.0075948	total: 3.59s	remaining: 4.21s
# 23:	learn: 1963.4781224	total: 3.74s	remaining: 4.06s
# 24:	learn: 1945.7472654	total: 3.9s	remaining: 3.9s
# 25:	learn: 1930.4772717	total: 4.06s	remaining: 3.74s
# 26:	learn: 1914.6050217	total: 4.21s	remaining: 3.59s
# 27:	learn: 1901.1020438	total: 4.36s	remaining: 3.43s
# 28:	learn: 1889.5067658	total: 4.53s	remaining: 3.28s
# 29:	learn: 1879.7422014	total: 4.68s	remaining: 3.12s
# 30:	learn: 1870.1440406	total: 4.83s	remaining: 2.96s
# 31:	learn: 1860.7302622	total: 4.99s	remaining: 2.8s
# 32:	learn: 1851.8918957	total: 5.14s	remaining: 2.65s
# 33:	learn: 1844.0938117	total: 5.29s	remaining: 2.49s
# 34:	learn: 1837.6088625	total: 5.45s	remaining: 2.33s
# 35:	learn: 1829.6785406	total: 5.6s	remaining: 2.18s
# 36:	learn: 1824.6445287	total: 5.75s	remaining: 2.02s
# 37:	learn: 1817.0632964	total: 5.91s	remaining: 1.86s
# 38:	learn: 1810.3175366	total: 6.06s	remaining: 1.71s
# 39:	learn: 1803.6072208	total: 6.21s	remaining: 1.55s
# 40:	learn: 1798.6730673	total: 6.36s	remaining: 1.4s
# 41:	learn: 1791.7131011	total: 6.51s	remaining: 1.24s
# 42:	learn: 1785.2885086	total: 6.66s	remaining: 1.08s
# 43:	learn: 1780.6410490	total: 6.82s	remaining: 930ms
# 44:	learn: 1775.5940848	total: 6.97s	remaining: 775ms
# 45:	learn: 1770.8499492	total: 7.13s	remaining: 620ms
# 46:	learn: 1766.4587521	total: 7.29s	remaining: 465ms
# 47:	learn: 1763.3553322	total: 7.44s	remaining: 310ms
# 48:	learn: 1759.5310993	total: 7.59s	remaining: 155ms
# 49:	learn: 1756.7377517	total: 7.75s	remaining: 0us
# 0:	learn: 4323.1573717	total: 173ms	remaining: 8.46s
# 1:	learn: 4034.2121088	total: 324ms	remaining: 7.78s
# 2:	learn: 3778.3733104	total: 491ms	remaining: 7.69s
# 3:	learn: 3550.0966421	total: 636ms	remaining: 7.32s
# 4:	learn: 3351.3015285	total: 769ms	remaining: 6.92s
# 5:	learn: 3177.8355138	total: 933ms	remaining: 6.84s
# 6:	learn: 3023.3150317	total: 1.11s	remaining: 6.81s
# 7:	learn: 2884.0342315	total: 1.26s	remaining: 6.63s
# 8:	learn: 2758.3916682	total: 1.42s	remaining: 6.49s
# 9:	learn: 2647.3749733	total: 1.58s	remaining: 6.32s
# 10:	learn: 2550.2978585	total: 1.73s	remaining: 6.15s
# 11:	learn: 2461.5633899	total: 1.88s	remaining: 5.96s
# 12:	learn: 2387.0007520	total: 2.04s	remaining: 5.8s
# 13:	learn: 2321.9666093	total: 2.2s	remaining: 5.65s
# 14:	learn: 2263.4263710	total: 2.35s	remaining: 5.48s
# 15:	learn: 2212.3465973	total: 2.5s	remaining: 5.31s
# 16:	learn: 2166.1533972	total: 2.65s	remaining: 5.14s
# 17:	learn: 2121.9118640	total: 2.81s	remaining: 5s
# 18:	learn: 2085.7028840	total: 2.95s	remaining: 4.82s
# 19:	learn: 2054.7696391	total: 3.12s	remaining: 4.68s
# 20:	learn: 2026.6289974	total: 3.28s	remaining: 4.53s
# 21:	learn: 1999.9705029	total: 3.43s	remaining: 4.37s
# 22:	learn: 1974.9189297	total: 3.59s	remaining: 4.21s
# 23:	learn: 1955.9963824	total: 3.74s	remaining: 4.05s
# 24:	learn: 1937.9344359	total: 3.89s	remaining: 3.89s
# 25:	learn: 1919.6395611	total: 4.04s	remaining: 3.73s
# 26:	learn: 1903.9415451	total: 4.2s	remaining: 3.58s
# 27:	learn: 1890.2984483	total: 4.35s	remaining: 3.42s
# 28:	learn: 1879.6442510	total: 4.5s	remaining: 3.26s
# 29:	learn: 1868.5590805	total: 4.66s	remaining: 3.1s
# 30:	learn: 1855.0391421	total: 4.82s	remaining: 2.95s
# 31:	learn: 1846.2550733	total: 4.96s	remaining: 2.79s
# 32:	learn: 1836.9631894	total: 5.11s	remaining: 2.63s
# 33:	learn: 1829.3380077	total: 5.26s	remaining: 2.48s
# 34:	learn: 1822.7072072	total: 5.43s	remaining: 2.33s
# 35:	learn: 1815.9655873	total: 5.59s	remaining: 2.17s
# 36:	learn: 1806.0214256	total: 5.74s	remaining: 2.02s
# 37:	learn: 1798.5313851	total: 5.89s	remaining: 1.86s
# 38:	learn: 1793.2344318	total: 6.05s	remaining: 1.71s
# 39:	learn: 1787.0552306	total: 6.21s	remaining: 1.55s
# 40:	learn: 1781.7587745	total: 6.35s	remaining: 1.39s
# 41:	learn: 1777.5743973	total: 6.5s	remaining: 1.24s
# 42:	learn: 1772.7390515	total: 6.68s	remaining: 1.09s
# 43:	learn: 1768.7111942	total: 6.84s	remaining: 932ms
# 44:	learn: 1764.1720523	total: 6.98s	remaining: 776ms
# 45:	learn: 1760.8177817	total: 7.13s	remaining: 620ms
# 46:	learn: 1757.5233890	total: 7.29s	remaining: 466ms
# 47:	learn: 1753.4711313	total: 7.45s	remaining: 310ms
# 48:	learn: 1750.1856816	total: 7.6s	remaining: 155ms
# 49:	learn: 1746.1683593	total: 7.75s	remaining: 0us
# 0:	learn: 4343.8235713	total: 180ms	remaining: 8.82s
# 1:	learn: 4055.9834887	total: 359ms	remaining: 8.62s
# 2:	learn: 3790.1559379	total: 510ms	remaining: 7.99s
# 3:	learn: 3560.0166557	total: 679ms	remaining: 7.8s
# 4:	learn: 3353.6149085	total: 842ms	remaining: 7.58s
# 5:	learn: 3173.3881878	total: 992ms	remaining: 7.28s
# 6:	learn: 3013.6534814	total: 1.15s	remaining: 7.04s
# 7:	learn: 2876.1179490	total: 1.3s	remaining: 6.83s
# 8:	learn: 2749.2529458	total: 1.46s	remaining: 6.65s
# 9:	learn: 2638.7678292	total: 1.6s	remaining: 6.42s
# 10:	learn: 2543.0152996	total: 1.76s	remaining: 6.24s
# 11:	learn: 2459.0703738	total: 1.92s	remaining: 6.07s
# 12:	learn: 2379.4667089	total: 2.08s	remaining: 5.93s
# 13:	learn: 2316.7929616	total: 2.24s	remaining: 5.75s
# 14:	learn: 2257.8160945	total: 2.4s	remaining: 5.59s
# 15:	learn: 2208.2018896	total: 2.54s	remaining: 5.4s
# 16:	learn: 2163.5923773	total: 2.7s	remaining: 5.24s
# 17:	learn: 2120.5326287	total: 2.86s	remaining: 5.09s
# 18:	learn: 2083.9662446	total: 3.02s	remaining: 4.92s
# 19:	learn: 2052.0542462	total: 3.17s	remaining: 4.76s
# 20:	learn: 2023.9057467	total: 3.33s	remaining: 4.59s
# 21:	learn: 1997.5793227	total: 3.47s	remaining: 4.42s
# 22:	learn: 1975.2762956	total: 3.63s	remaining: 4.25s
# 23:	learn: 1955.8273917	total: 3.77s	remaining: 4.09s
# 24:	learn: 1937.1926774	total: 3.94s	remaining: 3.94s
# 25:	learn: 1919.9161970	total: 4.11s	remaining: 3.79s
# 26:	learn: 1904.9907148	total: 4.26s	remaining: 3.63s
# 27:	learn: 1891.3641589	total: 4.42s	remaining: 3.47s
# 28:	learn: 1879.7378971	total: 4.57s	remaining: 3.31s
# 29:	learn: 1868.2283730	total: 4.73s	remaining: 3.15s
# 30:	learn: 1857.1609367	total: 4.91s	remaining: 3.01s
# 31:	learn: 1844.6380398	total: 5.08s	remaining: 2.86s
# 32:	learn: 1836.0027871	total: 5.21s	remaining: 2.68s
# 33:	learn: 1827.3765666	total: 5.36s	remaining: 2.52s
# 34:	learn: 1820.0394735	total: 5.51s	remaining: 2.36s
# 35:	learn: 1813.1890451	total: 5.68s	remaining: 2.21s
# 36:	learn: 1807.1491436	total: 5.83s	remaining: 2.05s
# 37:	learn: 1798.6968402	total: 6s	remaining: 1.89s
# 38:	learn: 1789.8035142	total: 6.15s	remaining: 1.74s
# 39:	learn: 1784.5943637	total: 6.3s	remaining: 1.57s
# 40:	learn: 1779.0871105	total: 6.45s	remaining: 1.42s
# 41:	learn: 1772.6198135	total: 6.6s	remaining: 1.26s
# 42:	learn: 1766.7346288	total: 6.76s	remaining: 1.1s
# 43:	learn: 1761.5383878	total: 6.89s	remaining: 940ms
# 44:	learn: 1757.0842552	total: 7.05s	remaining: 784ms
# 45:	learn: 1752.4569649	total: 7.21s	remaining: 627ms
# 46:	learn: 1748.6120985	total: 7.36s	remaining: 470ms
# 47:	learn: 1742.7227058	total: 7.51s	remaining: 313ms
# 48:	learn: 1739.3494871	total: 7.66s	remaining: 156ms
# 49:	learn: 1735.1494240	total: 7.81s	remaining: 0us
# 0:	learn: 3158.3537058	total: 179ms	remaining: 8.79s
# 1:	learn: 2465.4654576	total: 350ms	remaining: 8.41s
# 2:	learn: 2156.9715450	total: 524ms	remaining: 8.21s
# 3:	learn: 2007.2083644	total: 678ms	remaining: 7.8s
# 4:	learn: 1927.6246597	total: 839ms	remaining: 7.55s
# 5:	learn: 1890.7680200	total: 984ms	remaining: 7.21s
# 6:	learn: 1866.2577803	total: 1.14s	remaining: 6.98s
# 7:	learn: 1835.8752138	total: 1.29s	remaining: 6.75s
# 8:	learn: 1810.5613826	total: 1.44s	remaining: 6.55s
# 9:	learn: 1793.9450013	total: 1.59s	remaining: 6.36s
# 10:	learn: 1781.7319083	total: 1.74s	remaining: 6.17s
# 11:	learn: 1772.9066999	total: 1.89s	remaining: 6s
# 12:	learn: 1746.7800789	total: 2.04s	remaining: 5.8s
# 13:	learn: 1736.8320454	total: 2.2s	remaining: 5.66s
# 14:	learn: 1728.2370173	total: 2.38s	remaining: 5.55s
# 15:	learn: 1719.5531552	total: 2.53s	remaining: 5.38s
# 16:	learn: 1712.6091985	total: 2.68s	remaining: 5.21s
# 17:	learn: 1704.9652841	total: 2.82s	remaining: 5.02s
# 18:	learn: 1696.0651054	total: 2.97s	remaining: 4.85s
# 19:	learn: 1687.5728830	total: 3.12s	remaining: 4.67s
# 20:	learn: 1680.4411271	total: 3.26s	remaining: 4.51s
# 21:	learn: 1676.1897163	total: 3.42s	remaining: 4.35s
# 22:	learn: 1671.9481968	total: 3.57s	remaining: 4.19s
# 23:	learn: 1665.1672161	total: 3.72s	remaining: 4.03s
# 24:	learn: 1659.8103252	total: 3.87s	remaining: 3.87s
# 25:	learn: 1657.0727329	total: 4.03s	remaining: 3.72s
# 26:	learn: 1652.9791574	total: 4.19s	remaining: 3.57s
# 27:	learn: 1649.9939325	total: 4.34s	remaining: 3.41s
# 28:	learn: 1645.3028747	total: 4.5s	remaining: 3.26s
# 29:	learn: 1637.4628792	total: 4.65s	remaining: 3.1s
# 30:	learn: 1635.2881566	total: 4.8s	remaining: 2.94s
# 31:	learn: 1630.1874328	total: 4.96s	remaining: 2.79s
# 32:	learn: 1627.0173790	total: 5.11s	remaining: 2.63s
# 33:	learn: 1622.1923202	total: 5.26s	remaining: 2.48s
# 34:	learn: 1618.6047760	total: 5.42s	remaining: 2.32s
# 35:	learn: 1615.4333265	total: 5.57s	remaining: 2.17s
# 36:	learn: 1612.6510236	total: 5.72s	remaining: 2.01s
# 37:	learn: 1610.0028851	total: 5.88s	remaining: 1.85s
# 38:	learn: 1607.0519805	total: 6.03s	remaining: 1.7s
# 39:	learn: 1606.1880585	total: 6.18s	remaining: 1.54s
# 40:	learn: 1602.1363167	total: 6.33s	remaining: 1.39s
# 41:	learn: 1599.6069608	total: 6.49s	remaining: 1.24s
# 42:	learn: 1597.2368995	total: 6.64s	remaining: 1.08s
# 43:	learn: 1594.9516649	total: 6.79s	remaining: 926ms
# 44:	learn: 1593.9805011	total: 6.95s	remaining: 772ms
# 45:	learn: 1592.6766055	total: 7.1s	remaining: 618ms
# 46:	learn: 1589.4547728	total: 7.26s	remaining: 463ms
# 47:	learn: 1587.4208742	total: 7.41s	remaining: 309ms
# 48:	learn: 1584.2612755	total: 7.56s	remaining: 154ms
# 49:	learn: 1582.1427887	total: 7.71s	remaining: 0us
# 0:	learn: 3161.5635850	total: 174ms	remaining: 8.54s
# 1:	learn: 2487.0232485	total: 320ms	remaining: 7.68s
# 2:	learn: 2205.5964842	total: 503ms	remaining: 7.88s
# 3:	learn: 2020.8944232	total: 670ms	remaining: 7.7s
# 4:	learn: 1944.1834363	total: 830ms	remaining: 7.47s
# 5:	learn: 1900.2124590	total: 984ms	remaining: 7.22s
# 6:	learn: 1870.1809743	total: 1.14s	remaining: 6.97s
# 7:	learn: 1847.9643776	total: 1.28s	remaining: 6.74s
# 8:	learn: 1819.1538587	total: 1.43s	remaining: 6.52s
# 9:	learn: 1792.8607394	total: 1.58s	remaining: 6.32s
# 10:	learn: 1776.8898815	total: 1.73s	remaining: 6.14s
# 11:	learn: 1767.8913501	total: 1.89s	remaining: 6s
# 12:	learn: 1755.8979558	total: 2.05s	remaining: 5.83s
# 13:	learn: 1743.5772546	total: 2.2s	remaining: 5.66s
# 14:	learn: 1727.6437167	total: 2.35s	remaining: 5.49s
# 15:	learn: 1717.5317751	total: 2.5s	remaining: 5.31s
# 16:	learn: 1710.3476621	total: 2.66s	remaining: 5.16s
# 17:	learn: 1698.4262671	total: 2.81s	remaining: 4.99s
# 18:	learn: 1690.2630729	total: 2.96s	remaining: 4.83s
# 19:	learn: 1685.8980289	total: 3.11s	remaining: 4.67s
# 20:	learn: 1679.4819749	total: 3.27s	remaining: 4.51s
# 21:	learn: 1673.5188272	total: 3.42s	remaining: 4.35s
# 22:	learn: 1667.7027219	total: 3.56s	remaining: 4.18s
# 23:	learn: 1664.3915338	total: 3.72s	remaining: 4.03s
# 24:	learn: 1658.8092255	total: 3.88s	remaining: 3.88s
# 25:	learn: 1652.8230278	total: 4.03s	remaining: 3.72s
# 26:	learn: 1648.6579582	total: 4.19s	remaining: 3.57s
# 27:	learn: 1645.3505786	total: 4.36s	remaining: 3.42s
# 28:	learn: 1643.4516314	total: 4.51s	remaining: 3.27s
# 29:	learn: 1639.1745071	total: 4.66s	remaining: 3.11s
# 30:	learn: 1634.5330963	total: 4.81s	remaining: 2.95s
# 31:	learn: 1631.1828428	total: 4.96s	remaining: 2.79s
# 32:	learn: 1628.7074794	total: 5.12s	remaining: 2.64s
# 33:	learn: 1623.8085367	total: 5.27s	remaining: 2.48s
# 34:	learn: 1621.1495118	total: 5.42s	remaining: 2.32s
# 35:	learn: 1617.9654469	total: 5.58s	remaining: 2.17s
# 36:	learn: 1614.7082237	total: 5.73s	remaining: 2.01s
# 37:	learn: 1611.8086206	total: 5.89s	remaining: 1.86s
# 38:	learn: 1607.1079499	total: 6.04s	remaining: 1.7s
# 39:	learn: 1605.4335430	total: 6.18s	remaining: 1.54s
# 40:	learn: 1603.4723821	total: 6.34s	remaining: 1.39s
# 41:	learn: 1601.0097351	total: 6.49s	remaining: 1.24s
# 42:	learn: 1598.8555636	total: 6.64s	remaining: 1.08s
# 43:	learn: 1595.5801148	total: 6.79s	remaining: 926ms
# 44:	learn: 1593.0664301	total: 6.94s	remaining: 771ms
# 45:	learn: 1591.2943023	total: 7.1s	remaining: 617ms
# 46:	learn: 1588.3751706	total: 7.25s	remaining: 463ms
# 47:	learn: 1585.5041484	total: 7.4s	remaining: 308ms
# 48:	learn: 1583.5097079	total: 7.55s	remaining: 154ms
# 49:	learn: 1581.0082632	total: 7.7s	remaining: 0us
# 0:	learn: 3191.5200125	total: 199ms	remaining: 9.76s
# 1:	learn: 2483.1695911	total: 378ms	remaining: 9.08s
# 2:	learn: 2180.7749092	total: 528ms	remaining: 8.27s
# 3:	learn: 2023.6667942	total: 708ms	remaining: 8.14s
# 4:	learn: 1948.0991511	total: 925ms	remaining: 8.32s
# 5:	learn: 1892.4401428	total: 1.07s	remaining: 7.88s
# 6:	learn: 1854.3686977	total: 1.24s	remaining: 7.62s
# 7:	learn: 1825.1382679	total: 1.4s	remaining: 7.36s
# 8:	learn: 1807.6823481	total: 1.56s	remaining: 7.1s
# 9:	learn: 1782.9759112	total: 1.72s	remaining: 6.86s
# 10:	learn: 1770.0990813	total: 1.87s	remaining: 6.63s
# 11:	learn: 1752.9327720	total: 2.03s	remaining: 6.43s
# 12:	learn: 1742.7776114	total: 2.2s	remaining: 6.27s
# 13:	learn: 1730.5295051	total: 2.36s	remaining: 6.08s
# 14:	learn: 1718.1952869	total: 2.53s	remaining: 5.89s
# 15:	learn: 1711.6299168	total: 2.69s	remaining: 5.71s
# 16:	learn: 1704.4597062	total: 2.84s	remaining: 5.52s
# 17:	learn: 1699.3739498	total: 2.99s	remaining: 5.32s
# 18:	learn: 1688.0183497	total: 3.14s	remaining: 5.13s
# 19:	learn: 1681.3133663	total: 3.3s	remaining: 4.95s
# 20:	learn: 1677.3415734	total: 3.45s	remaining: 4.77s
# 21:	learn: 1670.2146970	total: 3.6s	remaining: 4.59s
# 22:	learn: 1664.2446826	total: 3.76s	remaining: 4.42s
# 23:	learn: 1661.1698357	total: 3.91s	remaining: 4.24s
# 24:	learn: 1656.1509454	total: 4.06s	remaining: 4.06s
# 25:	learn: 1649.5551780	total: 4.21s	remaining: 3.89s
# 26:	learn: 1643.4444715	total: 4.38s	remaining: 3.73s
# 27:	learn: 1639.5193643	total: 4.54s	remaining: 3.56s
# 28:	learn: 1637.4069379	total: 4.7s	remaining: 3.4s
# 29:	learn: 1632.5829709	total: 4.85s	remaining: 3.23s
# 30:	learn: 1628.9720857	total: 5s	remaining: 3.07s
# 31:	learn: 1626.3539587	total: 5.16s	remaining: 2.9s
# 32:	learn: 1622.3146652	total: 5.32s	remaining: 2.74s
# 33:	learn: 1616.8194479	total: 5.47s	remaining: 2.57s
# 34:	learn: 1611.2548377	total: 5.62s	remaining: 2.41s
# 35:	learn: 1609.0526739	total: 5.77s	remaining: 2.24s
# 36:	learn: 1605.2045534	total: 5.92s	remaining: 2.08s
# 37:	learn: 1601.7590015	total: 6.07s	remaining: 1.92s
# 38:	learn: 1597.8603804	total: 6.22s	remaining: 1.75s
# 39:	learn: 1595.8100602	total: 6.35s	remaining: 1.59s
# 40:	learn: 1591.5148547	total: 6.51s	remaining: 1.43s
# 41:	learn: 1587.5431127	total: 6.66s	remaining: 1.27s
# 42:	learn: 1584.8566699	total: 6.82s	remaining: 1.11s
# 43:	learn: 1581.1848062	total: 6.97s	remaining: 950ms
# 44:	learn: 1578.7787096	total: 7.13s	remaining: 792ms
# 45:	learn: 1576.8791847	total: 7.28s	remaining: 633ms
# 46:	learn: 1574.1247711	total: 7.44s	remaining: 475ms
# 47:	learn: 1573.3939087	total: 7.59s	remaining: 316ms
# 48:	learn: 1570.8477874	total: 7.74s	remaining: 158ms
# 49:	learn: 1570.0283423	total: 7.89s	remaining: 0us
# 0:	learn: 4329.4207103	total: 180ms	remaining: 8.84s
# 1:	learn: 4038.9226259	total: 329ms	remaining: 7.9s
# 2:	learn: 3781.8660002	total: 489ms	remaining: 7.66s
# 3:	learn: 3551.4830193	total: 645ms	remaining: 7.42s
# 4:	learn: 3351.4660203	total: 792ms	remaining: 7.13s
# 5:	learn: 3175.2829003	total: 950ms	remaining: 6.96s
# 6:	learn: 3019.8211997	total: 1.1s	remaining: 6.78s
# 7:	learn: 2878.3894228	total: 1.25s	remaining: 6.54s
# 8:	learn: 2755.7993648	total: 1.42s	remaining: 6.47s
# 9:	learn: 2645.1853736	total: 1.57s	remaining: 6.27s
# 10:	learn: 2546.8939122	total: 1.73s	remaining: 6.12s
# 11:	learn: 2464.2360028	total: 1.88s	remaining: 5.95s
# 12:	learn: 2389.4302089	total: 2.03s	remaining: 5.79s
# 13:	learn: 2323.4826104	total: 2.18s	remaining: 5.61s
# 14:	learn: 2265.0903022	total: 2.34s	remaining: 5.46s
# 15:	learn: 2211.5019810	total: 2.49s	remaining: 5.29s
# 16:	learn: 2165.5331277	total: 2.65s	remaining: 5.14s
# 17:	learn: 2124.3701394	total: 2.8s	remaining: 4.98s
# 18:	learn: 2091.7419695	total: 2.96s	remaining: 4.83s
# 19:	learn: 2059.3792635	total: 3.11s	remaining: 4.67s
# 20:	learn: 2029.7047843	total: 3.27s	remaining: 4.52s
# 21:	learn: 2004.9917823	total: 3.43s	remaining: 4.37s
# 22:	learn: 1984.0842253	total: 3.58s	remaining: 4.21s
# 23:	learn: 1964.5158691	total: 3.74s	remaining: 4.05s
# 24:	learn: 1946.8316239	total: 3.89s	remaining: 3.89s
# 25:	learn: 1931.5498471	total: 4.05s	remaining: 3.74s
# 26:	learn: 1915.6765619	total: 4.2s	remaining: 3.58s
# 27:	learn: 1902.1748075	total: 4.35s	remaining: 3.42s
# 28:	learn: 1890.5178197	total: 4.5s	remaining: 3.26s
# 29:	learn: 1880.7367411	total: 4.67s	remaining: 3.11s
# 30:	learn: 1871.1323863	total: 4.83s	remaining: 2.96s
# 31:	learn: 1862.2397772	total: 4.98s	remaining: 2.8s
# 32:	learn: 1854.8113401	total: 5.13s	remaining: 2.64s
# 33:	learn: 1844.1385840	total: 5.28s	remaining: 2.48s
# 34:	learn: 1836.7181387	total: 5.44s	remaining: 2.33s
# 35:	learn: 1828.8494900	total: 5.59s	remaining: 2.17s
# 36:	learn: 1821.3921246	total: 5.75s	remaining: 2.02s
# 37:	learn: 1815.2129234	total: 5.9s	remaining: 1.86s
# 38:	learn: 1808.9176988	total: 6.05s	remaining: 1.71s
# 39:	learn: 1802.2643983	total: 6.2s	remaining: 1.55s
# 40:	learn: 1796.4312747	total: 6.36s	remaining: 1.4s
# 41:	learn: 1790.4710087	total: 6.51s	remaining: 1.24s
# 42:	learn: 1785.2479547	total: 6.69s	remaining: 1.09s
# 43:	learn: 1781.6476512	total: 6.85s	remaining: 934ms
# 44:	learn: 1777.8493921	total: 7s	remaining: 778ms
# 45:	learn: 1773.5704682	total: 7.15s	remaining: 622ms
# 46:	learn: 1769.8968535	total: 7.3s	remaining: 466ms
# 47:	learn: 1766.1491582	total: 7.45s	remaining: 310ms
# 48:	learn: 1762.5923790	total: 7.61s	remaining: 155ms
# 49:	learn: 1758.5344060	total: 7.75s	remaining: 0us
# 0:	learn: 4323.3500201	total: 203ms	remaining: 9.94s
# 1:	learn: 4035.9176567	total: 354ms	remaining: 8.5s
# 2:	learn: 3781.5252065	total: 514ms	remaining: 8.06s
# 3:	learn: 3555.3912082	total: 671ms	remaining: 7.71s
# 4:	learn: 3356.8104641	total: 828ms	remaining: 7.45s
# 5:	learn: 3177.7074221	total: 982ms	remaining: 7.2s
# 6:	learn: 3018.8348284	total: 1.14s	remaining: 7s
# 7:	learn: 2883.9725410	total: 1.28s	remaining: 6.74s
# 8:	learn: 2759.2573201	total: 1.46s	remaining: 6.66s
# 9:	learn: 2651.2527008	total: 1.61s	remaining: 6.46s
# 10:	learn: 2554.5845511	total: 1.77s	remaining: 6.28s
# 11:	learn: 2469.8284882	total: 1.92s	remaining: 6.09s
# 12:	learn: 2394.2031397	total: 2.08s	remaining: 5.91s
# 13:	learn: 2325.6523079	total: 2.23s	remaining: 5.72s
# 14:	learn: 2266.7946846	total: 2.37s	remaining: 5.54s
# 15:	learn: 2214.6600102	total: 2.53s	remaining: 5.37s
# 16:	learn: 2168.7646476	total: 2.68s	remaining: 5.2s
# 17:	learn: 2125.7418676	total: 2.84s	remaining: 5.05s
# 18:	learn: 2088.9975571	total: 3s	remaining: 4.89s
# 19:	learn: 2056.7965988	total: 3.15s	remaining: 4.73s
# 20:	learn: 2028.4894344	total: 3.29s	remaining: 4.55s
# 21:	learn: 2003.5450449	total: 3.44s	remaining: 4.38s
# 22:	learn: 1979.9414239	total: 3.6s	remaining: 4.23s
# 23:	learn: 1959.2992745	total: 3.76s	remaining: 4.07s
# 24:	learn: 1941.2405083	total: 3.92s	remaining: 3.92s
# 25:	learn: 1924.8804564	total: 4.09s	remaining: 3.78s
# 26:	learn: 1910.0779060	total: 4.26s	remaining: 3.63s
# 27:	learn: 1898.0322450	total: 4.42s	remaining: 3.47s
# 28:	learn: 1886.0073560	total: 4.58s	remaining: 3.31s
# 29:	learn: 1875.7066306	total: 4.73s	remaining: 3.15s
# 30:	learn: 1865.9219969	total: 4.88s	remaining: 2.99s
# 31:	learn: 1853.4736864	total: 5.03s	remaining: 2.83s
# 32:	learn: 1845.0287162	total: 5.18s	remaining: 2.67s
# 33:	learn: 1836.5620915	total: 5.33s	remaining: 2.51s
# 34:	learn: 1828.9932636	total: 5.49s	remaining: 2.35s
# 35:	learn: 1821.6931761	total: 5.64s	remaining: 2.19s
# 36:	learn: 1814.7587845	total: 5.79s	remaining: 2.03s
# 37:	learn: 1807.6045311	total: 5.92s	remaining: 1.87s
# 38:	learn: 1799.7197107	total: 6.09s	remaining: 1.72s
# 39:	learn: 1793.1102355	total: 6.25s	remaining: 1.56s
# 40:	learn: 1787.2760850	total: 6.41s	remaining: 1.41s
# 41:	learn: 1782.0440247	total: 6.56s	remaining: 1.25s
# 42:	learn: 1777.5936742	total: 6.72s	remaining: 1.09s
# 43:	learn: 1773.0315413	total: 6.87s	remaining: 937ms
# 44:	learn: 1769.3432528	total: 7.02s	remaining: 780ms
# 45:	learn: 1763.7094952	total: 7.17s	remaining: 623ms
# 46:	learn: 1759.4392596	total: 7.32s	remaining: 467ms
# 47:	learn: 1754.9994494	total: 7.48s	remaining: 312ms
# 48:	learn: 1751.4019560	total: 7.63s	remaining: 156ms
# 49:	learn: 1748.1981019	total: 7.78s	remaining: 0us
# 0:	learn: 4344.0740567	total: 175ms	remaining: 8.57s
# 1:	learn: 4056.4798444	total: 341ms	remaining: 8.18s
# 2:	learn: 3790.8112124	total: 493ms	remaining: 7.72s
# 3:	learn: 3560.7705590	total: 649ms	remaining: 7.47s
# 4:	learn: 3354.4742340	total: 813ms	remaining: 7.32s
# 5:	learn: 3174.3014075	total: 964ms	remaining: 7.07s
# 6:	learn: 3014.5854651	total: 1.12s	remaining: 6.87s
# 7:	learn: 2877.0747652	total: 1.27s	remaining: 6.7s
# 8:	learn: 2750.2908120	total: 1.44s	remaining: 6.57s
# 9:	learn: 2639.8087906	total: 1.62s	remaining: 6.48s
# 10:	learn: 2544.0279130	total: 1.77s	remaining: 6.28s
# 11:	learn: 2460.1218189	total: 1.92s	remaining: 6.09s
# 12:	learn: 2380.5927101	total: 2.08s	remaining: 5.93s
# 13:	learn: 2317.8813072	total: 2.24s	remaining: 5.75s
# 14:	learn: 2258.8923623	total: 2.39s	remaining: 5.58s
# 15:	learn: 2208.2195348	total: 2.54s	remaining: 5.41s
# 16:	learn: 2163.2195934	total: 2.7s	remaining: 5.24s
# 17:	learn: 2121.2910235	total: 2.85s	remaining: 5.06s
# 18:	learn: 2085.3607570	total: 3s	remaining: 4.89s
# 19:	learn: 2052.6316799	total: 3.15s	remaining: 4.73s
# 20:	learn: 2024.3384796	total: 3.33s	remaining: 4.59s
# 21:	learn: 1998.9786243	total: 3.49s	remaining: 4.44s
# 22:	learn: 1976.2038358	total: 3.64s	remaining: 4.27s
# 23:	learn: 1955.4011056	total: 3.79s	remaining: 4.11s
# 24:	learn: 1935.4785330	total: 3.95s	remaining: 3.95s
# 25:	learn: 1918.9593013	total: 4.11s	remaining: 3.79s
# 26:	learn: 1904.0882282	total: 4.26s	remaining: 3.63s
# 27:	learn: 1889.9192345	total: 4.41s	remaining: 3.46s
# 28:	learn: 1874.6133792	total: 4.56s	remaining: 3.3s
# 29:	learn: 1863.9451026	total: 4.71s	remaining: 3.14s
# 30:	learn: 1854.0203448	total: 4.87s	remaining: 2.99s
# 31:	learn: 1844.4989264	total: 5.02s	remaining: 2.83s
# 32:	learn: 1836.6628030	total: 5.19s	remaining: 2.68s
# 33:	learn: 1829.6392718	total: 5.35s	remaining: 2.52s
# 34:	learn: 1822.6251236	total: 5.52s	remaining: 2.36s
# 35:	learn: 1814.8955806	total: 5.66s	remaining: 2.2s
# 36:	learn: 1807.8585787	total: 5.83s	remaining: 2.05s
# 37:	learn: 1799.2740443	total: 5.98s	remaining: 1.89s
# 38:	learn: 1791.7271876	total: 6.14s	remaining: 1.73s
# 39:	learn: 1783.4110976	total: 6.29s	remaining: 1.57s
# 40:	learn: 1778.6216857	total: 6.45s	remaining: 1.42s
# 41:	learn: 1773.6845929	total: 6.6s	remaining: 1.26s
# 42:	learn: 1768.3468334	total: 6.75s	remaining: 1.1s
# 43:	learn: 1763.2993342	total: 6.9s	remaining: 941ms
# 44:	learn: 1759.5777496	total: 7.06s	remaining: 784ms
# 45:	learn: 1756.2448165	total: 7.21s	remaining: 627ms
# 46:	learn: 1751.5629768	total: 7.36s	remaining: 470ms
# 47:	learn: 1748.5263247	total: 7.51s	remaining: 313ms
# 48:	learn: 1743.8983679	total: 7.67s	remaining: 156ms
# 49:	learn: 1740.7240948	total: 7.82s	remaining: 0us
# 0:	learn: 3060.6439806	total: 233ms	remaining: 2.1s
# 1:	learn: 2352.4336263	total: 446ms	remaining: 1.78s
# 2:	learn: 2034.6720069	total: 656ms	remaining: 1.53s
# 3:	learn: 1892.7391829	total: 888ms	remaining: 1.33s
# 4:	learn: 1830.8013377	total: 1.1s	remaining: 1.1s
# 5:	learn: 1791.1906901	total: 1.31s	remaining: 873ms
# 6:	learn: 1765.6068802	total: 1.52s	remaining: 653ms
# 7:	learn: 1744.4806198	total: 1.74s	remaining: 434ms
# 8:	learn: 1724.4019335	total: 1.96s	remaining: 218ms
# 9:	learn: 1710.0607769	total: 2.16s	remaining: 0us
# 0:	learn: 3065.2491896	total: 220ms	remaining: 1.98s
# 1:	learn: 2362.9103792	total: 438ms	remaining: 1.75s
# 2:	learn: 2051.9483985	total: 646ms	remaining: 1.51s
# 3:	learn: 1913.4711751	total: 870ms	remaining: 1.3s
# 4:	learn: 1844.3096409	total: 1.1s	remaining: 1.1s
# 5:	learn: 1804.1934344	total: 1.31s	remaining: 873ms
# 6:	learn: 1778.1491018	total: 1.51s	remaining: 647ms
# 7:	learn: 1749.2836259	total: 1.71s	remaining: 428ms
# 8:	learn: 1716.3226677	total: 1.91s	remaining: 212ms
# 9:	learn: 1703.2513215	total: 2.12s	remaining: 0us
# 0:	learn: 3080.0102944	total: 275ms	remaining: 2.47s
# 1:	learn: 2354.0926999	total: 496ms	remaining: 1.98s
# 2:	learn: 2045.9225238	total: 689ms	remaining: 1.61s
# 3:	learn: 1885.5951345	total: 865ms	remaining: 1.3s
# 4:	learn: 1823.3966618	total: 1.05s	remaining: 1.05s
# 5:	learn: 1777.8056284	total: 1.25s	remaining: 837ms
# 6:	learn: 1743.3099571	total: 1.47s	remaining: 632ms
# 7:	learn: 1718.4921092	total: 1.69s	remaining: 422ms
# 8:	learn: 1702.0269041	total: 1.88s	remaining: 209ms
# 9:	learn: 1682.9349308	total: 2.06s	remaining: 0us
# 0:	learn: 4311.7232108	total: 233ms	remaining: 2.09s
# 1:	learn: 4004.2015560	total: 453ms	remaining: 1.81s
# 2:	learn: 3731.7333632	total: 658ms	remaining: 1.53s
# 3:	learn: 3491.0833685	total: 867ms	remaining: 1.3s
# 4:	learn: 3280.6586847	total: 1.07s	remaining: 1.07s
# 5:	learn: 3086.2147919	total: 1.28s	remaining: 857ms
# 6:	learn: 2919.7371204	total: 1.51s	remaining: 646ms
# 7:	learn: 2777.6583764	total: 1.75s	remaining: 438ms
# 8:	learn: 2644.7774576	total: 1.95s	remaining: 217ms
# 9:	learn: 2532.2449488	total: 2.16s	remaining: 0us
# 0:	learn: 4305.8444853	total: 251ms	remaining: 2.26s
# 1:	learn: 3999.3826376	total: 465ms	remaining: 1.86s
# 2:	learn: 3730.1675338	total: 671ms	remaining: 1.56s
# 3:	learn: 3489.4600077	total: 884ms	remaining: 1.33s
# 4:	learn: 3277.2928066	total: 1.08s	remaining: 1.08s
# 5:	learn: 3094.5828837	total: 1.29s	remaining: 863ms
# 6:	learn: 2927.3227784	total: 1.47s	remaining: 631ms
# 7:	learn: 2780.7744773	total: 1.64s	remaining: 411ms
# 8:	learn: 2650.1737873	total: 1.85s	remaining: 206ms
# 9:	learn: 2538.1810277	total: 2.09s	remaining: 0us
# 0:	learn: 4323.6445211	total: 234ms	remaining: 2.1s
# 1:	learn: 4014.2674091	total: 445ms	remaining: 1.78s
# 2:	learn: 3743.2202324	total: 653ms	remaining: 1.52s
# 3:	learn: 3501.0465222	total: 862ms	remaining: 1.29s
# 4:	learn: 3288.2386738	total: 1.06s	remaining: 1.06s
# 5:	learn: 3096.3741482	total: 1.27s	remaining: 845ms
# 6:	learn: 2929.2513179	total: 1.45s	remaining: 620ms
# 7:	learn: 2779.6532452	total: 1.65s	remaining: 411ms
# 8:	learn: 2645.7084707	total: 1.82s	remaining: 203ms
# 9:	learn: 2528.8665320	total: 1.99s	remaining: 0us
# 0:	learn: 3063.7619815	total: 237ms	remaining: 2.13s
# 1:	learn: 2355.6093025	total: 454ms	remaining: 1.82s
# 2:	learn: 2037.5888994	total: 673ms	remaining: 1.57s
# 3:	learn: 1895.3197615	total: 883ms	remaining: 1.32s
# 4:	learn: 1833.6729403	total: 1.09s	remaining: 1.09s
# 5:	learn: 1794.9034962	total: 1.29s	remaining: 858ms
# 6:	learn: 1764.6251917	total: 1.5s	remaining: 641ms
# 7:	learn: 1748.5687328	total: 1.67s	remaining: 418ms
# 8:	learn: 1725.2606419	total: 1.86s	remaining: 207ms
# 9:	learn: 1705.4506354	total: 2.07s	remaining: 0us
# 0:	learn: 3068.0945499	total: 245ms	remaining: 2.21s
# 1:	learn: 2365.3060571	total: 490ms	remaining: 1.96s
# 2:	learn: 2054.8254343	total: 666ms	remaining: 1.55s
# 3:	learn: 1916.2560681	total: 882ms	remaining: 1.32s
# 4:	learn: 1847.2419277	total: 1.09s	remaining: 1.09s
# 5:	learn: 1807.6701232	total: 1.3s	remaining: 868ms
# 6:	learn: 1767.6681123	total: 1.5s	remaining: 642ms
# 7:	learn: 1749.2524196	total: 1.7s	remaining: 425ms
# 8:	learn: 1730.1053104	total: 1.91s	remaining: 212ms
# 9:	learn: 1716.3342213	total: 2.11s	remaining: 0us
# 0:	learn: 3082.0994051	total: 224ms	remaining: 2.01s
# 1:	learn: 2356.3293547	total: 437ms	remaining: 1.75s
# 2:	learn: 2048.7209603	total: 649ms	remaining: 1.51s
# 3:	learn: 1888.4341661	total: 844ms	remaining: 1.26s
# 4:	learn: 1825.9369858	total: 1.04s	remaining: 1.04s
# 5:	learn: 1780.6966605	total: 1.26s	remaining: 841ms
# 6:	learn: 1746.6140027	total: 1.5s	remaining: 642ms
# 7:	learn: 1721.8687472	total: 1.73s	remaining: 433ms
# 8:	learn: 1705.2272343	total: 1.93s	remaining: 214ms
# 9:	learn: 1687.3201352	total: 2.14s	remaining: 0us
# 0:	learn: 4312.4830077	total: 236ms	remaining: 2.12s
# 1:	learn: 4005.6167739	total: 465ms	remaining: 1.86s
# 2:	learn: 3733.6242796	total: 673ms	remaining: 1.57s
# 3:	learn: 3493.4086698	total: 928ms	remaining: 1.39s
# 4:	learn: 3283.1906226	total: 1.14s	remaining: 1.14s
# 5:	learn: 3090.0263470	total: 1.35s	remaining: 902ms
# 6:	learn: 2923.6483874	total: 1.55s	remaining: 665ms
# 7:	learn: 2777.9393720	total: 1.76s	remaining: 441ms
# 8:	learn: 2647.5623423	total: 1.97s	remaining: 219ms
# 9:	learn: 2531.8267858	total: 2.18s	remaining: 0us
# 0:	learn: 4306.5551823	total: 235ms	remaining: 2.11s
# 1:	learn: 4000.7660240	total: 446ms	remaining: 1.78s
# 2:	learn: 3731.9380340	total: 649ms	remaining: 1.51s
# 3:	learn: 3491.5085305	total: 856ms	remaining: 1.28s
# 4:	learn: 3279.5922440	total: 1.08s	remaining: 1.08s
# 5:	learn: 3097.0948172	total: 1.29s	remaining: 859ms
# 6:	learn: 2929.9111173	total: 1.52s	remaining: 651ms
# 7:	learn: 2783.4774746	total: 1.72s	remaining: 430ms
# 8:	learn: 2652.9481953	total: 1.96s	remaining: 218ms
# 9:	learn: 2540.9351524	total: 2.17s	remaining: 0us
# 0:	learn: 4324.1667172	total: 227ms	remaining: 2.05s
# 1:	learn: 4015.2535381	total: 454ms	remaining: 1.82s
# 2:	learn: 3743.9299620	total: 663ms	remaining: 1.55s
# 3:	learn: 3502.3138547	total: 870ms	remaining: 1.3s
# 4:	learn: 3289.2565597	total: 1.09s	remaining: 1.09s
# 5:	learn: 3102.6785463	total: 1.3s	remaining: 865ms
# 6:	learn: 2936.5267111	total: 1.5s	remaining: 645ms
# 7:	learn: 2782.6939729	total: 1.72s	remaining: 429ms
# 8:	learn: 2647.5079343	total: 1.91s	remaining: 213ms
# 9:	learn: 2532.3151863	total: 2.1s	remaining: 0us
# 0:	learn: 3060.6439806	total: 231ms	remaining: 11.3s
# 1:	learn: 2352.4336263	total: 447ms	remaining: 10.7s
# 2:	learn: 2034.6720069	total: 675ms	remaining: 10.6s
# 3:	learn: 1892.7391829	total: 871ms	remaining: 10s
# 4:	learn: 1830.8013377	total: 1.05s	remaining: 9.5s
# 5:	learn: 1791.1906901	total: 1.26s	remaining: 9.23s
# 6:	learn: 1765.6068802	total: 1.47s	remaining: 9.03s
# 7:	learn: 1744.4806198	total: 1.68s	remaining: 8.83s
# 8:	learn: 1724.4019335	total: 1.85s	remaining: 8.42s
# 9:	learn: 1710.0607769	total: 2.03s	remaining: 8.14s
# 10:	learn: 1697.2783492	total: 2.28s	remaining: 8.08s
# 11:	learn: 1680.9424951	total: 2.46s	remaining: 7.79s
# 12:	learn: 1671.6333515	total: 2.65s	remaining: 7.55s
# 13:	learn: 1658.1391310	total: 2.83s	remaining: 7.27s
# 14:	learn: 1648.4577676	total: 3s	remaining: 6.99s
# 15:	learn: 1639.0428013	total: 3.21s	remaining: 6.82s
# 16:	learn: 1634.6924178	total: 3.41s	remaining: 6.63s
# 17:	learn: 1625.0775528	total: 3.63s	remaining: 6.45s
# 18:	learn: 1621.0823884	total: 3.83s	remaining: 6.25s
# 19:	learn: 1615.0883887	total: 4.02s	remaining: 6.03s
# 20:	learn: 1608.8525344	total: 4.18s	remaining: 5.78s
# 21:	learn: 1602.3965814	total: 4.35s	remaining: 5.53s
# 22:	learn: 1597.2582100	total: 4.52s	remaining: 5.3s
# 23:	learn: 1588.5027676	total: 4.68s	remaining: 5.08s
# 24:	learn: 1585.0092792	total: 4.86s	remaining: 4.86s
# 25:	learn: 1581.0030454	total: 5.07s	remaining: 4.68s
# 26:	learn: 1571.6426759	total: 5.27s	remaining: 4.49s
# 27:	learn: 1568.9136971	total: 5.5s	remaining: 4.32s
# 28:	learn: 1563.9594112	total: 5.71s	remaining: 4.13s
# 29:	learn: 1559.7193084	total: 5.92s	remaining: 3.94s
# 30:	learn: 1556.2277789	total: 6.13s	remaining: 3.75s
# 31:	learn: 1552.8207059	total: 6.32s	remaining: 3.56s
# 32:	learn: 1549.1803941	total: 6.52s	remaining: 3.36s
# 33:	learn: 1546.4485698	total: 6.73s	remaining: 3.17s
# 34:	learn: 1543.3140863	total: 6.9s	remaining: 2.96s
# 35:	learn: 1536.8725708	total: 7.12s	remaining: 2.77s
# 36:	learn: 1532.7257453	total: 7.35s	remaining: 2.58s
# 37:	learn: 1531.2819232	total: 7.56s	remaining: 2.39s
# 38:	learn: 1529.1682473	total: 7.77s	remaining: 2.19s
# 39:	learn: 1526.8727504	total: 7.94s	remaining: 1.99s
# 40:	learn: 1523.9846118	total: 8.15s	remaining: 1.79s
# 41:	learn: 1521.7515211	total: 8.37s	remaining: 1.59s
# 42:	learn: 1516.7327056	total: 8.59s	remaining: 1.4s
# 43:	learn: 1515.0968473	total: 8.8s	remaining: 1.2s
# 44:	learn: 1512.3735099	total: 8.99s	remaining: 999ms
# 45:	learn: 1510.6340441	total: 9.18s	remaining: 799ms
# 46:	learn: 1508.2654028	total: 9.39s	remaining: 600ms
# 47:	learn: 1506.0541735	total: 9.56s	remaining: 398ms
# 48:	learn: 1503.1135079	total: 9.77s	remaining: 199ms
# 49:	learn: 1499.7684669	total: 9.96s	remaining: 0us
# 0:	learn: 3065.2491896	total: 257ms	remaining: 12.6s
# 1:	learn: 2362.9103792	total: 469ms	remaining: 11.3s
# 2:	learn: 2051.9483985	total: 686ms	remaining: 10.7s
# 3:	learn: 1913.4711751	total: 920ms	remaining: 10.6s
# 4:	learn: 1844.3096409	total: 1.1s	remaining: 9.95s
# 5:	learn: 1804.1934344	total: 1.3s	remaining: 9.54s
# 6:	learn: 1778.1491018	total: 1.47s	remaining: 9.05s
# 7:	learn: 1749.2836259	total: 1.69s	remaining: 8.87s
# 8:	learn: 1716.3226677	total: 1.91s	remaining: 8.71s
# 9:	learn: 1703.2513215	total: 2.12s	remaining: 8.48s
# ...
# 1:	learn: 2298.5097460	total: 564ms	remaining: 13.5s
# 2:	learn: 1973.5504344	total: 842ms	remaining: 13.2s
# 3:	learn: 1825.9298554	total: 1.11s	remaining: 12.7s
# 4:	learn: 1753.3066220	total: 1.33s	remaining: 12s
# 5:	learn: 1712.5266499	total: 1.59s	remaining: 11.7s
# 6:	learn: 1679.7957314	total: 1.87s	remaining: 11.5s
# 7:	learn: 1651.3301098	total: 2.14s	remaining: 11.2s
# 8:	learn: 1638.4678887	total: 2.36s	remaining: 10.7s
# 9:	learn: 1623.3183327	total: 2.63s	remaining: 10.5s
# 10:	learn: 1611.1630938	total: 2.9s	remaining: 10.3s
# 11:	learn: 1601.5800683	total: 3.16s	remaining: 10s
# 12:	learn: 1586.9117964	total: 3.41s	remaining: 9.7s
# 13:	learn: 1577.1794754	total: 3.68s	remaining: 9.46s
# 14:	learn: 1570.1906860	total: 3.93s	remaining: 9.16s
# 15:	learn: 1560.0749885	total: 4.2s	remaining: 8.93s
# 16:	learn: 1553.2070924	total: 4.47s	remaining: 8.69s
# 17:	learn: 1547.0022912	total: 4.73s	remaining: 8.4s
# 18:	learn: 1538.4198971	total: 4.94s	remaining: 8.05s
# 19:	learn: 1533.6163784	total: 5.2s	remaining: 7.79s
# 20:	learn: 1525.6591748	total: 5.48s	remaining: 7.57s
# 21:	learn: 1519.1043622	total: 5.75s	remaining: 7.32s
# 22:	learn: 1514.5465302	total: 6.02s	remaining: 7.07s
# 23:	learn: 1507.9747816	total: 6.33s	remaining: 6.85s
# 24:	learn: 1502.9113842	total: 6.6s	remaining: 6.6s
# 25:	learn: 1498.9307431	total: 6.82s	remaining: 6.29s
# 26:	learn: 1496.3146993	total: 7.05s	remaining: 6s
# 27:	learn: 1492.8424556	total: 7.31s	remaining: 5.75s
# 28:	learn: 1487.9465264	total: 7.57s	remaining: 5.48s
# 29:	learn: 1484.9192653	total: 7.91s	remaining: 5.28s
# 30:	learn: 1478.2232291	total: 8.18s	remaining: 5.01s
# 31:	learn: 1473.6763113	total: 8.4s	remaining: 4.73s
# 32:	learn: 1469.6564568	total: 8.62s	remaining: 4.44s
# 33:	learn: 1466.4565753	total: 8.88s	remaining: 4.18s
# 34:	learn: 1464.2708634	total: 9.15s	remaining: 3.92s
# 35:	learn: 1461.5815214	total: 9.36s	remaining: 3.64s
# 36:	learn: 1457.2168282	total: 9.65s	remaining: 3.39s
# 37:	learn: 1455.5120663	total: 9.91s	remaining: 3.13s
# 38:	learn: 1450.8061338	total: 10.2s	remaining: 2.87s
# 39:	learn: 1448.6863562	total: 10.4s	remaining: 2.6s
# 40:	learn: 1444.8248130	total: 10.6s	remaining: 2.33s
# 41:	learn: 1442.7130209	total: 10.9s	remaining: 2.07s
# 42:	learn: 1438.4125096	total: 11.2s	remaining: 1.82s
# 43:	learn: 1435.9315276	total: 11.4s	remaining: 1.56s
# 44:	learn: 1433.7955340	total: 11.7s	remaining: 1.3s
# 45:	learn: 1432.0628683	total: 12s	remaining: 1.04s
# 46:	learn: 1428.0357398	total: 12.2s	remaining: 780ms
# 47:	learn: 1426.3359756	total: 12.4s	remaining: 518ms
# 48:	learn: 1425.1418367	total: 12.6s	remaining: 258ms
# 49:	learn: 1419.7658021	total: 12.9s	remaining: 0us
# 0:	learn: 3007.7681419	total: 292ms	remaining: 14.3s
# 1:	learn: 2282.4905834	total: 560ms	remaining: 13.4s
# 2:	learn: 1942.2778702	total: 801ms	remaining: 12.6s
# 3:	learn: 1809.7924746	total: 1.04s	remaining: 12s
# 4:	learn: 1737.6465926	total: 1.31s	remaining: 11.8s
# 5:	learn: 1696.9047812	total: 1.54s	remaining: 11.3s
# 6:	learn: 1661.2149317	total: 1.79s	remaining: 11s
# 7:	learn: 1636.4705348	total: 2.07s	remaining: 10.9s
# 8:	learn: 1621.4234716	total: 2.34s	remaining: 10.7s
# 9:	learn: 1600.9031159	total: 2.62s	remaining: 10.5s
# 10:	learn: 1589.0435181	total: 2.88s	remaining: 10.2s
# 11:	learn: 1579.5408159	total: 3.2s	remaining: 10.1s
# 12:	learn: 1573.0242864	total: 3.47s	remaining: 9.87s
# 13:	learn: 1565.4625407	total: 3.71s	remaining: 9.53s
# 14:	learn: 1556.0158674	total: 3.97s	remaining: 9.26s
# 15:	learn: 1549.6929434	total: 4.2s	remaining: 8.93s
# 16:	learn: 1540.6737135	total: 4.43s	remaining: 8.59s
# 17:	learn: 1535.8456397	total: 4.69s	remaining: 8.34s
# 18:	learn: 1528.9070373	total: 4.97s	remaining: 8.1s
# 19:	learn: 1524.8463515	total: 5.24s	remaining: 7.86s
# 20:	learn: 1519.9417289	total: 5.52s	remaining: 7.63s
# 21:	learn: 1512.9793284	total: 5.72s	remaining: 7.29s
# 22:	learn: 1507.8551336	total: 5.94s	remaining: 6.97s
# 23:	learn: 1500.6377340	total: 6.14s	remaining: 6.65s
# 24:	learn: 1497.6117874	total: 6.39s	remaining: 6.39s
# 25:	learn: 1497.6117684	total: 6.45s	remaining: 5.95s
# 26:	learn: 1488.0317354	total: 6.7s	remaining: 5.71s
# 27:	learn: 1483.6831346	total: 6.95s	remaining: 5.46s
# 28:	learn: 1478.6919566	total: 7.24s	remaining: 5.24s
# 29:	learn: 1473.2747194	total: 7.55s	remaining: 5.04s
# 30:	learn: 1468.0950869	total: 7.83s	remaining: 4.8s
# 31:	learn: 1465.6018964	total: 8.05s	remaining: 4.53s
# 32:	learn: 1461.4323206	total: 8.25s	remaining: 4.25s
# 33:	learn: 1459.1658009	total: 8.47s	remaining: 3.98s
# 34:	learn: 1458.9322701	total: 8.71s	remaining: 3.73s
# 35:	learn: 1456.4386119	total: 8.96s	remaining: 3.48s
# 36:	learn: 1451.6208600	total: 9.24s	remaining: 3.25s
# 37:	learn: 1448.1559556	total: 9.51s	remaining: 3s
# 38:	learn: 1445.4104445	total: 9.79s	remaining: 2.76s
# 39:	learn: 1441.1331180	total: 10.1s	remaining: 2.51s
# 40:	learn: 1438.4751630	total: 10.3s	remaining: 2.27s
# 41:	learn: 1435.5847044	total: 10.6s	remaining: 2.02s
# 42:	learn: 1432.2629982	total: 10.9s	remaining: 1.77s
# 43:	learn: 1430.0889179	total: 11.1s	remaining: 1.52s
# 44:	learn: 1427.0995455	total: 11.4s	remaining: 1.26s
# 45:	learn: 1424.9569900	total: 11.7s	remaining: 1.01s
# 46:	learn: 1422.4052710	total: 11.9s	remaining: 762ms
# 47:	learn: 1420.3282470	total: 12.2s	remaining: 508ms
# 48:	learn: 1419.0789139	total: 12.5s	remaining: 254ms
# 49:	learn: 1416.3178150	total: 12.7s	remaining: 0us
# 0:	learn: 4309.5706483	total: 293ms	remaining: 14.4s
# 1:	learn: 3991.4941424	total: 580ms	remaining: 13.9s
# 2:	learn: 3710.4416268	total: 846ms	remaining: 13.3s
# 3:	learn: 3462.8210324	total: 1.11s	remaining: 12.8s
# 4:	learn: 3249.7234114	total: 1.39s	remaining: 12.5s
# 5:	learn: 3052.7949188	total: 1.65s	remaining: 12.1s
# 6:	learn: 2880.8192144	total: 1.92s	remaining: 11.8s
# 7:	learn: 2727.5392463	total: 2.19s	remaining: 11.5s
# 8:	learn: 2596.3098151	total: 2.46s	remaining: 11.2s
# 9:	learn: 2481.3662932	total: 2.73s	remaining: 10.9s
# 10:	learn: 2378.3502573	total: 3s	remaining: 10.7s
# 11:	learn: 2290.0350079	total: 3.28s	remaining: 10.4s
# 12:	learn: 2211.4458368	total: 3.55s	remaining: 10.1s
# 13:	learn: 2143.9189076	total: 3.81s	remaining: 9.81s
# 14:	learn: 2083.2965563	total: 4.1s	remaining: 9.56s
# 15:	learn: 2031.0431673	total: 4.37s	remaining: 9.28s
# 16:	learn: 1985.5613406	total: 4.64s	remaining: 9s
# 17:	learn: 1948.1115779	total: 4.89s	remaining: 8.7s
# 18:	learn: 1913.7639520	total: 5.15s	remaining: 8.4s
# 19:	learn: 1884.2984377	total: 5.43s	remaining: 8.15s
# 20:	learn: 1858.6415807	total: 5.68s	remaining: 7.84s
# 21:	learn: 1834.7788398	total: 5.95s	remaining: 7.57s
# 22:	learn: 1814.5316337	total: 6.18s	remaining: 7.25s
# 23:	learn: 1797.8336090	total: 6.45s	remaining: 6.99s
# 24:	learn: 1779.0939093	total: 6.73s	remaining: 6.73s
# 25:	learn: 1764.7639153	total: 7s	remaining: 6.46s
# 26:	learn: 1751.7523541	total: 7.23s	remaining: 6.16s
# 27:	learn: 1739.9993841	total: 7.5s	remaining: 5.89s
# 28:	learn: 1726.3466874	total: 7.77s	remaining: 5.63s
# 29:	learn: 1717.3651182	total: 8.06s	remaining: 5.37s
# 30:	learn: 1708.4487957	total: 8.32s	remaining: 5.1s
# 31:	learn: 1698.0988912	total: 8.59s	remaining: 4.83s
# 32:	learn: 1690.3873582	total: 8.86s	remaining: 4.56s
# 33:	learn: 1680.9229554	total: 9.14s	remaining: 4.3s
# 34:	learn: 1674.1365552	total: 9.39s	remaining: 4.03s
# 35:	learn: 1668.0038010	total: 9.65s	remaining: 3.75s
# 36:	learn: 1661.2203815	total: 9.94s	remaining: 3.49s
# 37:	learn: 1653.0739884	total: 10.2s	remaining: 3.23s
# 38:	learn: 1646.3819284	total: 10.5s	remaining: 2.96s
# 39:	learn: 1642.2726037	total: 10.8s	remaining: 2.69s
# 40:	learn: 1637.3389329	total: 11s	remaining: 2.42s
# 41:	learn: 1634.0027283	total: 11.3s	remaining: 2.15s
# 42:	learn: 1630.3306508	total: 11.6s	remaining: 1.88s
# 43:	learn: 1623.5953905	total: 11.8s	remaining: 1.61s
# 44:	learn: 1618.9786676	total: 12.1s	remaining: 1.35s
# 45:	learn: 1616.3791022	total: 12.4s	remaining: 1.08s
# 46:	learn: 1613.5948417	total: 12.7s	remaining: 809ms
# 47:	learn: 1611.1008192	total: 12.9s	remaining: 540ms
# 48:	learn: 1608.7896925	total: 13.2s	remaining: 270ms
# 49:	learn: 1604.9631506	total: 13.5s	remaining: 0us
# 0:	learn: 4303.6018919	total: 302ms	remaining: 14.8s
# 1:	learn: 3986.9333856	total: 565ms	remaining: 13.6s
# 2:	learn: 3706.0647496	total: 841ms	remaining: 13.2s
# 3:	learn: 3457.0300965	total: 1.1s	remaining: 12.6s
# 4:	learn: 3233.7591687	total: 1.35s	remaining: 12.2s
# 5:	learn: 3041.9527257	total: 1.63s	remaining: 11.9s
# 6:	learn: 2870.1543435	total: 1.89s	remaining: 11.6s
# 7:	learn: 2720.2290288	total: 2.15s	remaining: 11.3s
# 8:	learn: 2587.1372008	total: 2.42s	remaining: 11s
# 9:	learn: 2469.6562728	total: 2.69s	remaining: 10.8s
# 10:	learn: 2363.9226607	total: 2.97s	remaining: 10.5s
# 11:	learn: 2272.6696297	total: 3.24s	remaining: 10.3s
# 12:	learn: 2194.1045426	total: 3.49s	remaining: 9.93s
# 13:	learn: 2125.0528053	total: 3.77s	remaining: 9.7s
# 14:	learn: 2066.2753812	total: 4.04s	remaining: 9.42s
# 15:	learn: 2013.0594274	total: 4.29s	remaining: 9.12s
# 16:	learn: 1966.6404847	total: 4.56s	remaining: 8.85s
# 17:	learn: 1929.5647882	total: 4.83s	remaining: 8.59s
# 18:	learn: 1896.3133050	total: 5.08s	remaining: 8.29s
# 19:	learn: 1867.0935446	total: 5.35s	remaining: 8.02s
# 20:	learn: 1841.2564965	total: 5.62s	remaining: 7.76s
# 21:	learn: 1815.4061790	total: 5.84s	remaining: 7.44s
# 22:	learn: 1795.5468537	total: 6.09s	remaining: 7.15s
# 23:	learn: 1774.3684936	total: 6.37s	remaining: 6.9s
# 24:	learn: 1757.8450608	total: 6.64s	remaining: 6.64s
# 25:	learn: 1743.3735251	total: 6.9s	remaining: 6.37s
# 26:	learn: 1730.6149045	total: 7.14s	remaining: 6.08s
# 27:	learn: 1718.0184886	total: 7.41s	remaining: 5.82s
# 28:	learn: 1707.9999793	total: 7.69s	remaining: 5.57s
# 29:	learn: 1698.9224408	total: 7.96s	remaining: 5.3s
# 30:	learn: 1690.5703362	total: 8.17s	remaining: 5.01s
# 31:	learn: 1683.3048433	total: 8.4s	remaining: 4.72s
# 32:	learn: 1674.9940321	total: 8.68s	remaining: 4.47s
# 33:	learn: 1669.7637281	total: 8.92s	remaining: 4.2s
# 34:	learn: 1661.7805527	total: 9.19s	remaining: 3.94s
# 35:	learn: 1654.3198791	total: 9.46s	remaining: 3.68s
# 36:	learn: 1647.9508752	total: 9.76s	remaining: 3.43s
# 37:	learn: 1640.6711323	total: 10s	remaining: 3.17s
# 38:	learn: 1635.0305463	total: 10.3s	remaining: 2.91s
# 39:	learn: 1630.3335968	total: 10.6s	remaining: 2.64s
# 40:	learn: 1625.9385194	total: 10.8s	remaining: 2.38s
# 41:	learn: 1620.0953133	total: 11.1s	remaining: 2.11s
# 42:	learn: 1616.8502946	total: 11.4s	remaining: 1.85s
# 43:	learn: 1610.9728712	total: 11.6s	remaining: 1.58s
# 44:	learn: 1607.3401772	total: 11.9s	remaining: 1.32s
# 45:	learn: 1604.0849014	total: 12.2s	remaining: 1.06s
# 46:	learn: 1599.4062216	total: 12.5s	remaining: 795ms
# 47:	learn: 1596.4902703	total: 12.7s	remaining: 530ms
# 48:	learn: 1593.6352819	total: 13s	remaining: 265ms
# 49:	learn: 1590.4964880	total: 13.3s	remaining: 0us
# 0:	learn: 4311.4160395	total: 281ms	remaining: 13.7s
# 1:	learn: 3994.1494147	total: 543ms	remaining: 13s
# 2:	learn: 3710.6393612	total: 816ms	remaining: 12.8s
# 3:	learn: 3462.6026427	total: 1.09s	remaining: 12.5s
# 4:	learn: 3237.2510050	total: 1.37s	remaining: 12.3s
# 5:	learn: 3042.9299282	total: 1.65s	remaining: 12.1s
# 6:	learn: 2868.4600974	total: 1.92s	remaining: 11.8s
# 7:	learn: 2718.0183936	total: 2.21s	remaining: 11.6s
# 8:	learn: 2585.8955392	total: 2.44s	remaining: 11.1s
# 9:	learn: 2466.4355658	total: 2.65s	remaining: 10.6s
# 10:	learn: 2363.3587252	total: 2.91s	remaining: 10.3s
# 11:	learn: 2273.9386641	total: 3.18s	remaining: 10.1s
# 12:	learn: 2193.7498273	total: 3.44s	remaining: 9.8s
# 13:	learn: 2126.4274909	total: 3.71s	remaining: 9.55s
# 14:	learn: 2069.8820142	total: 3.98s	remaining: 9.28s
# 15:	learn: 2019.7267476	total: 4.25s	remaining: 9.04s
# 16:	learn: 1970.2550450	total: 4.52s	remaining: 8.78s
# 17:	learn: 1929.3134842	total: 4.76s	remaining: 8.46s
# 18:	learn: 1894.4615241	total: 5.03s	remaining: 8.2s
# 19:	learn: 1864.3425510	total: 5.3s	remaining: 7.94s
# 20:	learn: 1836.4728970	total: 5.57s	remaining: 7.69s
# 21:	learn: 1810.0408446	total: 5.85s	remaining: 7.45s
# 22:	learn: 1787.9738458	total: 6.14s	remaining: 7.2s
# 23:	learn: 1769.4764594	total: 6.4s	remaining: 6.94s
# 24:	learn: 1754.3299698	total: 6.63s	remaining: 6.63s
# 25:	learn: 1739.0497615	total: 6.89s	remaining: 6.36s
# 26:	learn: 1726.4939270	total: 7.16s	remaining: 6.1s
# 27:	learn: 1714.8571143	total: 7.42s	remaining: 5.83s
# 28:	learn: 1705.1495300	total: 7.69s	remaining: 5.57s
# 29:	learn: 1697.2852566	total: 7.95s	remaining: 5.3s
# 30:	learn: 1687.5165798	total: 8.21s	remaining: 5.03s
# 31:	learn: 1677.7291116	total: 8.46s	remaining: 4.76s
# 32:	learn: 1670.8720937	total: 8.68s	remaining: 4.47s
# 33:	learn: 1663.5142617	total: 8.97s	remaining: 4.22s
# 34:	learn: 1655.4728018	total: 9.24s	remaining: 3.96s
# 35:	learn: 1647.6573740	total: 9.5s	remaining: 3.69s
# 36:	learn: 1641.6193244	total: 9.75s	remaining: 3.43s
# 37:	learn: 1634.7021852	total: 10s	remaining: 3.16s
# 38:	learn: 1625.8304448	total: 10.3s	remaining: 2.9s
# 39:	learn: 1621.2978844	total: 10.5s	remaining: 2.64s
# 40:	learn: 1615.5377679	total: 10.8s	remaining: 2.37s
# 41:	learn: 1611.7050650	total: 11.1s	remaining: 2.11s
# 42:	learn: 1608.0481638	total: 11.3s	remaining: 1.85s
# 43:	learn: 1605.0261112	total: 11.6s	remaining: 1.58s
# 44:	learn: 1601.7029689	total: 11.9s	remaining: 1.32s
# 45:	learn: 1598.0199014	total: 12.1s	remaining: 1.05s
# 46:	learn: 1593.8367126	total: 12.4s	remaining: 793ms
# 47:	learn: 1590.0795168	total: 12.7s	remaining: 529ms
# 48:	learn: 1587.1672851	total: 12.9s	remaining: 264ms
# 49:	learn: 1583.6828635	total: 13.2s	remaining: 0us
# 0:	learn: 3014.0255569	total: 448ms	remaining: 21.9s
# 1:	learn: 2275.5552538	total: 820ms	remaining: 19.7s
# 2:	learn: 1947.7892942	total: 1.27s	remaining: 19.9s
# 3:	learn: 1817.7779943	total: 1.67s	remaining: 19.2s
# 4:	learn: 1758.2782710	total: 2.08s	remaining: 18.7s
# 5:	learn: 1706.9228014	total: 2.48s	remaining: 18.2s
# 6:	learn: 1676.7200031	total: 2.85s	remaining: 17.5s
# 7:	learn: 1654.8136081	total: 3.24s	remaining: 17s
# 8:	learn: 1632.8117955	total: 3.64s	remaining: 16.6s
# 9:	learn: 1622.7491596	total: 4.04s	remaining: 16.2s
# 10:	learn: 1602.5335847	total: 4.43s	remaining: 15.7s
# 11:	learn: 1594.0452358	total: 4.83s	remaining: 15.3s
# 12:	learn: 1582.4901623	total: 5.27s	remaining: 15s
# 13:	learn: 1566.8558039	total: 5.68s	remaining: 14.6s
# 14:	learn: 1557.8485646	total: 6.07s	remaining: 14.2s
# 15:	learn: 1548.5326875	total: 6.44s	remaining: 13.7s
# 16:	learn: 1541.7870407	total: 6.84s	remaining: 13.3s
# 17:	learn: 1535.1642950	total: 7.26s	remaining: 12.9s
# 18:	learn: 1528.5878985	total: 7.63s	remaining: 12.5s
# 19:	learn: 1523.1268583	total: 8.04s	remaining: 12.1s
# 20:	learn: 1516.3515948	total: 8.44s	remaining: 11.7s
# 21:	learn: 1509.8246024	total: 8.83s	remaining: 11.2s
# 22:	learn: 1507.0455007	total: 9.24s	remaining: 10.8s
# 23:	learn: 1504.7602114	total: 9.64s	remaining: 10.4s
# 24:	learn: 1501.2346069	total: 10s	remaining: 10s
# 25:	learn: 1496.8936521	total: 10.4s	remaining: 9.63s
# 26:	learn: 1492.2760338	total: 10.8s	remaining: 9.21s
# 27:	learn: 1487.7320551	total: 11.2s	remaining: 8.81s
# 28:	learn: 1484.2741151	total: 11.6s	remaining: 8.4s
# 29:	learn: 1479.3485879	total: 12s	remaining: 8.01s
# 30:	learn: 1474.7653949	total: 12.4s	remaining: 7.61s
# 31:	learn: 1469.1863031	total: 12.8s	remaining: 7.21s
# 32:	learn: 1465.8375099	total: 13.2s	remaining: 6.81s
# 33:	learn: 1462.1999477	total: 13.6s	remaining: 6.4s
# 34:	learn: 1459.0969628	total: 14s	remaining: 5.98s
# 35:	learn: 1453.7510727	total: 14.3s	remaining: 5.58s
# 36:	learn: 1450.9816324	total: 14.7s	remaining: 5.18s
# 37:	learn: 1447.8986320	total: 15.1s	remaining: 4.78s
# 38:	learn: 1444.3123548	total: 15.5s	remaining: 4.38s
# 39:	learn: 1441.3728040	total: 15.9s	remaining: 3.97s
# 40:	learn: 1436.6076824	total: 16.2s	remaining: 3.56s
# 41:	learn: 1433.6409200	total: 16.6s	remaining: 3.16s
# 42:	learn: 1431.6400282	total: 17s	remaining: 2.77s
# 43:	learn: 1429.3785713	total: 17.4s	remaining: 2.37s
# 44:	learn: 1428.1037005	total: 17.8s	remaining: 1.98s
# 45:	learn: 1424.3123351	total: 18.2s	remaining: 1.58s
# 46:	learn: 1422.5043313	total: 18.6s	remaining: 1.19s
# 47:	learn: 1419.6432808	total: 19s	remaining: 791ms
# 48:	learn: 1418.4048968	total: 19.4s	remaining: 396ms
# 49:	learn: 1413.3915231	total: 19.8s	remaining: 0us

# %% [markdown]
# We can print out the best hyperparameter settings for our model

# %%
print('Best score across all searched parameters', grid.best_score_)
print('Best parameters:', best_par)
# Out:
# Best score across all searched parameters -1525.683316147072
# Best parameters: {'depth': 10, 'iterations': 50, 'l2_leaf_reg': 2, 'learning_rate': 0.5, 'loss_function': 'RMSE', 'random_seed': 12345}

# %% [markdown]
# Next, we train our CatBoost Regressor model using the best hyperparameter settings. Also, we note the time of the process.

# %%
#CatBoost Model training 

CBR_model = CatBoostRegressor(depth = best_par['depth'],
                              iterations = best_par['iterations'],
                              l2_leaf_reg = 4,
                              learning_rate = 0.1,
                              loss_function = 'RMSE', 
                              random_seed = random_state)

# %time CBR_model.fit(f_train_gbm, t_train_gbm, cat_features = dat_features, verbose = False, plot = False)
# Out:
# CPU times: user 20.5 s, sys: 60 ms, total: 20.5 s
# Wall time: 20.7 s

# %%
#CatBoost Model Predictions

# %time CBR_model_pred = CBR_model.predict(f_test_gbm)
# Out:
# CPU times: user 194 ms, sys: 13 µs, total: 194 ms
# Wall time: 197 ms

# %% [markdown]
# RMSE Calculation:

# %%
CBR_rmse = rmse(t_test_gbm, CBR_model_pred)

CBR_rmse
# Out:
# 1600.6077108376792

# %% [markdown]
# We got an RMSE of 1600.607. This RMSE is higher than our baseline model

# %% [markdown]
# ## LightGBM Regressor

# %% [markdown]
# The LightGBM model does not require encoding. We will still be performing hyperparameter tuning similar to the way we did for CatBoost, except we will be dealing with different hyperparameters.
# One thing to note about LightGBM is that our categorical features have to be of the 'category' type before feeding it to LightGBM.
# LightGBM does not accept 'object' type or anything else. So we will need to do so both for the training set and the test set.

# %%
#Converting all training features to "category" type

obj_feat = list(f_train_gbm.loc[:, f_train_gbm.dtypes == 'object'].columns.values)

for feature in obj_feat:
    f_train_gbm[feature] = pd.Series(f_train_gbm[feature], dtype="category")

model_GBM = LGBMRegressor()
parameters = {'num_leaves': [10, 20, 30],
              'learning_rate': [0.5, 0.1],
              'n_estimators': [10, 20],
              'random_state': [random_state],
              'objective': ['rmse']}

grid = GridSearchCV(estimator = model_GBM, param_grid = parameters, scoring = scorer, cv=3, n_jobs=-1)
grid.fit(f_train_gbm, t_train_gbm)
best_param = grid.best_params_
# Out:
# /tmp/ipykernel_68/2124378442.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_train_gbm[feature] = pd.Series(f_train_gbm[feature], dtype="category")

# %% [markdown]
# Getting our best hyperparameter setting:

# %%
print('Best score across all searched parameters', grid.best_score_)
print('Best parameters:', best_param)
# Out:
# Best score across all searched parameters -1579.8335124962603
# Best parameters: {'learning_rate': 0.5, 'n_estimators': 20, 'num_leaves': 30, 'objective': 'rmse', 'random_state': 12345}

# %% [markdown]
# Next, we will train and test our LightGBM model using the hyperparameter settings above, while timing the process.

# %%
#LightGBM model training

LGBM_model = LGBMRegressor(learning = 0.1,
                           n_estimators = 10,
                           num_leaves = 10,
                           objective = 'rmse',
                           random_state = random_state)

# %time LGBM_model.fit(f_train_gbm, t_train_gbm)
# Out:
# CPU times: user 837 ms, sys: 0 ns, total: 837 ms
# Wall time: 805 ms
# LGBMRegressor(learning=0.1, n_estimators=10, num_leaves=10, objective='rmse',
#               random_state=12345)

# %%
#Converting all test features to "category" type

obj_feat = list(f_test_gbm.loc[:, f_test_gbm.dtypes == 'object'].columns.values)

for feature in obj_feat:
    f_test_gbm[feature] = pd.Series(f_test_gbm[feature], dtype="category")

#LightGBM model predictions
# %time LGBM_pred = LGBM_model.predict(f_test_gbm)
# Out:
# CPU times: user 60.4 ms, sys: 4 µs, total: 60.4 ms
# Wall time: 56.5 ms
# /tmp/ipykernel_68/4195612490.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_test_gbm[feature] = pd.Series(f_test_gbm[feature], dtype="category")

# %% [markdown]
# RMSE Calculcation:

# %%
LGBM_rmse = rmse(LGBM_pred, t_test_gbm)

LGBM_rmse

#def rmse(pred, target):
# Out:
# 2686.3654327660724

# %% [markdown]
# The RMSE of 2686.36 is much better than the RMSE of the baseline model

# %% [markdown]
# ## Model analysis

# %% [markdown]
# To analyze the model, we prepare a table showing the different models, their training and prediction times (in milliseconds) and RMSEs

# %%
index = ['LR', 'DTR', 'RFR', 'CBM', 'LGBM']

total_summary = pd.DataFrame(data = {'training_time(ms)': [144, 1100, 39700, 20700, 805],
                                     'prediction_time(ms)': [15.2, 14.9, 710, 197, 56.5],
                                     'RMSE': [3025, 1741, 1457, 1600, 2686]},
                            index = index)
                                     
                                    
total_summary
# Out:
#       training_time(ms)  prediction_time(ms)  RMSE
# LR                  144                 15.2  3025
# DTR                1100                 14.9  1741
# RFR               39700                710.0  1457
# CBM               20700                197.0  1600
# LGBM                805                 56.5  2686

# %% [markdown]
# Takeaways:
#
# - Linear Regression had the best training time (144 ms) while the worst goes to Random Forest (39700 ms)
#
# - Linear Regression had the best prediction time (15.2 ms) while the worst goes to Random Forest (710 ms)
#
# - Random Forest had the best RMSE (1457) while the worst goes to Linear Regression (3025)

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment</b>
#
# Excellent! You tried a few different models, tuned their hyperparameters using cross-validation and evaluated the final models on the test set. It's nice that you separately measured training and prediction time!
#
# </div>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This project was done to develop an app to attract new customers for Rusty Bargain. Several models were built to determine the value of the cars. We have successfully cleaned and prepared the data and used it to train models. Linear Regression has the best training time (144 ms) while the worst is Random Forest (39700 ms). Also, Linear Regression has the best prediction time of 15.2 ms while the Random Forest Model has the worst, 710 ms.
#
# Random Forest has the best RMSE of 1457. However, the time taken for training and prediction is highest. The CatBoost model takes about half the time of the Random Forest model for training, and about four times less than the Random Forest Model for making predictions. Therefore, we will recommend with the CatBoost model.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Reviewer's comment</b>
#
# Conclusion mostly makes sense, though the difference between 6 seconds and 3 seconds training doesn't seem that dramatic :)
#
# </div>

# %% [markdown]
# # Checklist

# %% [markdown]
# Type 'x' to check. Then press Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook is open
# - [ ]  Code is error free
# - [ ]  The cells with the code have been arranged in order of execution
# - [ ]  The data has been downloaded and prepared
# - [ ]  The models have been trained
# - [ ]  The analysis of speed and quality of the models has been performed
